# %% [markdown]
# # Begin jeopardy peeps processing
#
# The scraping code deliberately left seprate from this notebook so as to not accidentially hit the j-archive servers 9k times.
#
# This script roughly does the following:
#
# 1. Intakes the soccode file and assembles structures containing soccode information.
#     1. Some hand curated occupation information has been added. The codes for these contain raw text and are at the end of the file.
# 2. Reads in the player files and constructs a dictionary of player information.
# 3. Reads through the players and attempts to match occupation information.  Adds list of occ stuff to playerdict if found, added as `False` otherwise.
# 4. Prepares the playerdict for csv output.
# 5. Remaining code is me whacking at doing some analysis of code.

# %%
#various imports, etc.
import re
import csv
from os import listdir
from os.path import isfile, join
from pprint import pprint

# %%
# dump all text into one bigass string for quick checking
with open('scripts-soccodes.csv','rU') as f:
    pass #soctext = f.read()
    
#soctext= soctext.lower()

# %% [markdown]
# # Begin soccode processing
#
# Read through the soccodes csv file.  Read in each line as a list.  Kill off the last element in the csv, as it is useless.
#
# Soccodes themselves have two elements: a core and a subset code.  Subsets belong to cores.
#
# * `soccodes` becomes a list of all the soccodes, this needs to be deprecated and chagned to the socdict
# * `socdict` becomes a dictionary of key=code and value=[core title,specific title]
# * `soccores` becomes a dictionary of just the core code values, key=core code, value=core name

# %%
#PROCESS ALL THE SOCCODE THINGS

#Opens the soccodes csv file and processes the rows into a list
#Removes the last element of each row (not used for this project)
soccodes = []
with open('scripts-soccodes.csv','rU') as f:
    f_csv = csv.reader(f)
    headers = next(f_csv)
    for row in f_csv:
    	soccodes.append(row[:-1]) # killing off the last element in rows
        
# make a dictionary of soccodes because looking up in lists is insanity
socdict = {}
for each in soccodes:
    socdict[each[0]] = each[1:]

# make a dictionary of just the core codes for easy lookup
soccores = {}
for each in soccodes:
    code = each[0].split("-")
    if code[0] not in soccores:
        soccores[code[0]] = each[1]

# %% [markdown]
# # Begin basic helper functions
#
# Made `printdict` and then reminded of pprint.
#
# * `finduniqueoccs` will return a dictionary of tallied occupations. Designed to be fed the playerdict.
# * `filterdict` used to return a dictionary of only people with matched occupations.
# * `findmorethan` convenience way to take in a tallied dictionary and return a new dictionary of only items over a tally threshold.
# * `prettyprintdict` is a shit name.  Prepares the playerdict for dictwriter output.  Purposefully leaving it undynamic, because other stuff needs to be updated if the structure of playerdict changes.
# * `countFalses` reporting on the number of falses and basic stats
# * `listfailures` lists failures.  I kind of forgot why I wrote this.

# %%
# Defining helper functions

# pretty print a dictionary
def printdict(dict):
    for key, value in dict.iteritems():
        print key, value
        
# function to find unique occupations
# should update to require occ element position
def finduniqueoccs(dict):
    uniques= {}
    for key,value in dict.iteritems():
        if value[0] in uniques:
            uniques[value[0]] +=1
        else:
            uniques[value[0]] = 1
    return uniques

# Filters through player dict and returns a dictionary with only
# players with matching soccode results
def filterdict(dict):
    """returns only players with occupation matches"""
    clean = {}
    for key, value in dict.iteritems():
        if value[2] != False:
            clean[key] = value
    return clean

# function to process the tallied list of occupations and return
# a dictionary with occupations having num or more occurances
def findmorethan(dict,num):
    newdict = {}
    for key, value in dict.iteritems():
        if value >= num:
            newdict[key] = value
        else:
            continue
    return newdict

# function to process playerdict and prepare it for csv output
# format needs to be a list of dictionaries, key=header and value=value
# [{head:value, head:value}]
def prettyprintdict(dict,headers):
    list = []
    for key, value in dict.iteritems():
        tempdict = {}
        tempdict[headers[0]] = key
        tempdict[headers[1]] = value[0]
        tempdict[headers[2]] = value[1]
        if value[2] == False:
            tempdict[headers[3]] = False
        else:
            tempdict[headers[3]] = value[2][0]
            tempdict[headers[4]] = value[2][1]
            tempdict[headers[5]] = value[2][2]
        list.append(tempdict)
    return list

def countFalses(dict):
    falsesum = 0
    seen = 0
    for key,value in dict.iteritems():
        if value[2] == False:
            falsesum += 1
        seen += 1
    print "falses seen",falsesum,"out of",seen,"yielding",str(int((float(falsesum)/float(seen))*100))+"%", "failure"
    
def listfailures(dict):
    countdict= {}
    for key, value in dict.iteritems():
        if value[2] != False: 
            continue
        if value[0] in countdict:
            countdict[value[0]] +=1
        else:
            countdict[value[0]] = 1
    return countdict

# %% [markdown]
# # Begin player processing
#
# Files are contianed within the players2 folder for stupid reasons.
#
# 1. Read through the files
# 2. Attempt to find the name and occupations
#     1. If the common format of occupation phrase can't be matched, just grab the whole thing.
#     2. If neither of those work, report the match as failed.
# 3. Create the playerdict
#
# TODO:
#
# * Add support for location
# * Do something fancy with composite occupational phrases.
# * Snag some basic game count info.

# %%
# Part 1: Construct player dictionary

# read through the files, find the phrases, add them to a dictionary

#find all the file names
mypath = 'players2/'
players = [ f for f in listdir(mypath) if isfile(join(mypath,f)) and f[0] != '.' ]

#compile name and occ regex patterns
occupation = re.compile(r'<p class="player_occupation_and_origin">(?:an? *)?(.+?)(?:originally\s*)?from.+?</p>',re.IGNORECASE)
occupationfailed = re.compile(r'<p class="player_occupation_and_origin">(.+?)</p>',re.IGNORECASE)
name = re.compile(r'<p class="player_full_name">(.+?)</p>',re.IGNORECASE)

#create empty dictionary
playerdict = {}

#loop through the list of files
for each in players:
    #find the player number in the file name
    playernum = re.findall(r'[0-9]+',each)[0]
    #read through the file
    with open("players2/" + each,'rb') as player:
        player = player.readlines()
        # read through the lines
        for each in player:
            if 'player_occupation_and_origin' in each:
                # create empty player record in the dictionary
                playerdict[playernum] = []
                try:
                    try:
                        # if the elegant regex doesn't snag anything
                        playerdict[playernum].append(re.findall(occupation,each)[0].strip())
                    except:
                        # just snag all the things
                        playerdict[playernum].append(re.findall(occupationfailed,each)[0].strip())
                    # name just snags all the things
                    playerdict[playernum].append(re.findall(name,each)[0].strip())
                except:
                    # if either occupation occupationfailed fail, mark as failed
                    playerdict[playernum].append('FAILED')

# %% [markdown]
# ## Basic sanity checks
#
# Reports the length of the soccodes and playerdicts.  Sanity checks before continuing on.
#
# Should be something like:
# ```
#     6597
#     9112
#     2```

# %%
print len(soccodes)
print len(playerdict)
print len(playerdict['100'])

for row in soccodes:
    if row[0] == 'MiscTeacher':
        print soccodes.index(row)
        
soccodes[6597]
# Out:
# 6615
# 9112
# 2
# ['Unemployed', 'Unemployed', 'Homemaker']

# %% [markdown]
# # Begin soccode snagging procesures
#
# This block will loop through the players and search for their occupations in the list of soccodes.
#
# Matches are added to the playerdict.
#
# You'll note that there are some manual checks after that.  These are to account for composite or insane occupational phrases that don't match anything in particular.
#
# Evaluation for this will take ~ 2 min.
#
# Because this is using append to add information to the playerdict, it first checks if you are using a playerdict that has already been processed.  The loop will break and print out an error message if this is true.
#
# Todo:  the elifs are getting unruly.  Need to make those a dictionary and add in another loop.

# %%
# Part 2: Join Soccode information to the players

# processing the players and soccodes together
# will append the matching soc phrase to the player entry
# if not found, will append False

#looping through dictionary
count = 0
for key, value in playerdict.iteritems():
    if len(value) > 2:
        print "Remake the playerdict" #because this is using append, needs to not already have stuff
        break
    #boolean to see if a soccode has been found
    found = False
    #process through the soccode rows
    count = 0
    #if value[0] in soctext:
    for row in soccodes:
        # value[0] is the occ string for the human
        # row[2] is the specific occ string in the soccodes
        # lowercases both and checks for equality
        if value[0].lower() == row[2].lower():
            # if equal, add the soccode row to the player's record
            playerdict[key].append(row)
            # mark that is has been found
            found = True
            break
        elif 'graduate student' in value[0].lower():
            playerdict[key].append(soccodes[6593])
            found = True
            break
        elif 'teacher' in value[0].lower():
            playerdict[key].append(soccodes[6596])
            found = True
            break
        elif 'lawyer' in value[0].lower():
            playerdict[key].append(soccodes[6602])
            found = True
            break
        elif 'attorney' in value[0].lower():
            playerdict[key].append(soccodes[6602])
            found = True
            break
        elif 'instructor' in value[0].lower():
            playerdict[key].append(soccodes[6602])
            found = True
            break
        # keeping student at the end, as it is the least descriptive of the compisite occs
        elif "senior at " in value[0].lower():
            playerdict[key].append(soccodes[6597])
            found = True
            break
        elif "junior at " in value[0].lower():
            playerdict[key].append(soccodes[6598])
            found = True
            break
        elif "sophomore at " in value[0].lower():
            playerdict[key].append(soccodes[6599])
            found = True
            break
        elif "freshman at " in value[0].lower():
            playerdict[key].append(soccodes[6600])
            found = True
            break
        elif 'student' in value[0].lower():
            playerdict[key].append(soccodes[6601])
            found = True
            break
    if found == False:
        # if finished looping through soccodes and not found, mark as false
        playerdict[key].append(False)
    #print key, value
#from pprint import pprint       
#pprint(playerdict)

countFalses(playerdict)

# %% [markdown]
# ## Testing scratch area

# %%
#fails =  listfailures(playerdict)
countFalses(playerdict)
from pprint import pprint
#pprint(fails)

# print printdict(fails)
            
for key, value in playerdict.iteritems():
    if value[2] == False:
        print key, value
# Out:
# falses seen 4729 out of 9112 yielding 51% failure
# 5988 ['state fair coordinator', 'Peter Latouf', False]
# 5989 ['park ranger', 'Evelyn Chester', False]
# 5982 ['homemaker and volunteer', 'Sue Romberg', False]
# 5981 ['software project manager', 'Stefanie Tomko', False]
# 5987 ['foreign service officer', 'Liz Murphy', False]
# 5984 ['tea salesman', 'Wright Polak', False]
# 5985 ['United Methodist pastor', 'Melanie Baker-Streevy', False]
# 6797 ['telecommunications consultant', 'Ken Starnes', False]
# 6794 ['fashion designer and TV personality', 'Isaac Mizrahi', False]
# 6790 ['author and actor', 'Hill Harper', False]
# 6791 ["future Women's Basketball Hall of Famer and ESPN analyst", 'Rebecca Lobo', False]
# 272 ['office automation specialist', 'Robert Slaven', False]
# 274 ['retired military Air Force officer', 'John Kelly', False]
# 277 ['actuary', 'Bob Blake', False]
# 279 ['customer service representative', 'Regina Sutton', False]
# 2143 ['computer consultant and trainer', 'Linda Lin', False]
# 2142 ['lexicographer', 'James Kossuth', False]
# 3516 ['technical representative', 'Judy Taisch', False]
# 3515 ['benefits consultant', 'Lori Wright', False]
# 2688 ['financial secretary and bartender', 'Connie Toohey', False]
# 2689 ['purchasing manager', 'Jim Spilman', False]
# 2684 ['teen novelist', 'Gillian Chan', False]
# 2685 ['social worker', 'Susan Turi', False]
# 2680 ['sales executive', 'Jack Campion', False]
# 2681 ['assistant professor', 'Chris Mazurek', False]
# 2683 ['youth minister', 'Joan Nelson', False]
# 92 ['newspaper editor', 'Jennifer Peebles', False]
# 1177 ['psychologist', 'Joel Silbert', False]
# 1171 ['from Irvine, California...', 'Aman Birk', False]
# 1170 ['from Roselle, Illinois...', 'Veronica Fazio', False]
# 1179 ['private tutor', 'Kim Strassburger', False]
# 1178 ['health care consultant', 'Luis Gutierrez', False]
# 7189 ['stay at home mother', 'Mai Do-Burrous', False]
# 7180 ['pizza maker', 'Johnny Marigliano', False]
# 7182 ['poker impresario', 'Ron Roberts', False]
# 7183 ['night court clerk', 'Molly Rosenbusch', False]
# 7186 ['proposal writer', 'Kristi Springer', False]
# 623 ['assistant editor', 'Fred Ramen', False]
# 622 ['TV quiz show host', 'Brad Rutter', False]
# 621 ['Teen Tournament winner', 'Matt Zielenski', False]
# 873 ['retired police sergeant', "Jim O'Malley", False]
# 8549 ['script reader', 'Tory Metzger', False]
# 8548 ['public librarian', 'Stacie Larson', False]
# 8018 ['administrative assistant', 'Matt Bibb', False]
# 8017 ['bookstore manager', 'Jennifer Hughs', False]
# 627 ['industrial training director', 'Bob Devlin', False]
# 8015 ['assistant principal', 'Craig Chern', False]
# 8012 ['history professor', 'Stephanie Jass', False]
# 7454 ['university development writer', 'Maggie Diamond', False]
# 7455 ['educator', 'Edgar Mihelic', False]
# 625 ['law firm purchasing agent', 'Ren\xe9 Garcia', False]
# 2036 ['consultant', 'Amy Rosier', False]
# 624 ['consultant', 'Brian Weikle', False]
# 7459 ['geographic information systems analyst', 'Amy George', False]
# 4849 ['pilot', 'Eddie Gillan', False]
# 4594 ['homemaker and freelance editor', 'Christa Franklin Ishino', False]
# 2749 ['part-time newsstand clerk', 'Lionel Goldbart', False]
# 4599 ['financial manager', 'Michael Guard', False]
# 4734 ['university administrator and event planner', 'Jake Marini', False]
# 8290 ['managing editor', 'Anne Ellis', False]
# 4735 ['U.S. Air Force pilot', 'Tim Bobinski', False]
# 8293 ['office supply sales assistant', 'Rebecca Rider', False]
# 8292 ['court officer lieutenant', 'Tom Carroll', False]
# 2038 ['immigration counselor', 'Tanya Knight', False]
# 4738 ['freelance editor and graphic designer', 'Mandy Loy', False]
# 8297 ['independent filmmaker', 'Michael Carvaines', False]
# 1987 ['interactive project manager', 'Tricia Barreiro', False]
# 393 ['executive secretary', 'Ann Taliaferro Curtaz', False]
# 397 ['civil servant', 'Barbara-Anne Eddy', False]
# 396 ['plumbing contractor', 'Lindsay Peet', False]
# 395 ['customer service representative', 'Christian De Jong', False]
# 399 ['retired Air Force officer', 'John Kelly', False]
# 2308 ['editor', 'Julie Dock', False]
# 4729 ['software developer', 'Robin Woods', False]
# 4728 ['freelance magazine writer', 'Gretchen Wahl', False]
# 2301 ['software quality analyst', 'Bob Bearse', False]
# 2305 ['computer consultant', 'Mark Wasley', False]
# 2304 ['director of banquets', 'Steven McKenna', False]
# 2306 ['public relations consultant', 'Maggie Walker', False]
# 5845 ['production assistant', 'Andrew Woolsey', False]
# 5844 ['journalist', 'James Pethokoukis', False]
# 5843 ['software engineer', 'Amanda Waterman', False]
# 5841 ['architect', 'Richard Wiggs', False]
# 5840 ['medical editor', 'Sarah Smee', False]
# 5849 ['associate professor', 'Laura Dickinson', False]
# 5848 ['account manager', 'Thom Morrissey', False]
# 3748 ['government representative', 'Anthony DiMarco', False]
# 3749 ['systems developer', 'Nicole Stouder', False]
# 3747 ['communications director', 'Beth White', False]
# 3744 ['retail manager', "Sharon O'Quinn", False]
# 3745 ['marriage educator', 'Jamil Muhammad', False]
# 3742 ['business manager', 'Bill Wilson', False]
# 3743 ['legal technology manager', 'Carol Gerber', False]
# 4620 ['software engineer', 'Eugene Hung', False]
# 4621 ['historic preservationist', 'Andrew Sprouse', False]
# 4625 ['sales associate', 'Chris Dixon', False]
# 4626 ['public affairs specialist', 'Jennah Durant', False]
# 4627 ['Sunday school director', 'Lisa Fritsche', False]
# 177 ['system manager', 'Stephen McNamara', False]
# 176 ['pollution control board member', 'Kathleen Hennessey', False]
# 175 ['recent law school graduate', 'Catherine Ewen', False]
# 173 ['data coordinator', 'Eric Swanson', False]
# 6215 ['comedian and actor', 'Hal Sparks', False]
# 6214 ['host and actress', 'Paige Davis', False]
# 6211 ['gift card production designer', 'Alyssa McRae', False]
# 6219 ['actor, comedian and singer', 'Wayne Brady', False]
# 6819 ['operations engineer', 'Buddy Wright', False]
# 6810 ['software consultant', 'Kevin Porter', False]
# 6813 ['office manager', 'Brett Garner', False]
# 6812 ['content coordinator', 'Gabe Hernandez', False]
# 6815 ['freelance story analyst', 'Francis Hambidge', False]
# 6817 ['stamp dealer', 'Marvin Shinkman', False]
# 1115 ['medical communications consultant', 'Thaddeus Grimes-Gruczka', False]
# 8913 ['academic director for a test preparation company', 'Bob Verini', False]
# 8848 ['merchandising manager', 'Lee May', False]
# 8840 ['academic tutor and performer', 'Rachel Samberg', False]
# 8841 ['project coordinator', 'Sarah Olson', False]
# 8842 ['documentary-film editor', 'Mary Manhardt', False]
# 8844 ['antiquarian bookseller', 'Andrew Nelson', False]
# 8845 ['workforce development manager', 'Carolyn Gawlik', False]
# 8846 ['vice president of production', 'Julia Dye', False]
# 8847 ['postdoctoral fellow and university lecturer', 'Dinu Nesan', False]
# 7668 ['business news writer', 'Bruce Vale', False]
# 7660 ['writer and trivia hostess', 'Molly Newman', False]
# 7665 ['financial analyst', 'Taylor Cope', False]
# 7667 ['former video store owner', 'Rhonda Hammons', False]
# 7666 ['soldier and a physician', 'Brendan Graham', False]
# 1760 ['graduate teaching assistant', 'Piper Huguley', False]
# 1766 ['college professor', 'Patty Leginus', False]
# 1544 ['video buyer', 'David Achar', False]
# 1543 ['travel marketer', 'Dave Halliday', False]
# 1541 ['systems analyst', 'Linda Desmond', False]
# 698 ['grocery store cashier', 'Sara Maikowski', False]
# 699 ['industrial sculptor', 'Leland Kennedy', False]
# 1549 ['consultant', 'Jared Poppel', False]
# 8715 ['architect', 'Damian Henri', False]
# 8716 ['web producer', 'Jason Idalski', False]
# 8719 ['restaurant manager', 'Kathy Johnson', False]
# 1982 ['software engineer', 'Michael Cryer', False]
# 5618 ['retirement representative', 'Kari Caven', False]
# 5619 ['appraiser', 'Charlotte Renshaw', False]
# 5613 ['recent grad', 'Durant Gipson', False]
# 5611 ['U.S. Navy flight officer', 'Carl Brady', False]
# 5616 ['writer and actor', 'Jeff Fowler', False]
# 5617 ['Boys & Girls Club director', 'Joe Ingoglia', False]
# 7116 ['search engine optimization writer', 'Teresa Lane', False]
# 7118 ['eco-tour guide', 'Bob Fulmer', False]
# 6779 ['administrative assistant', 'Karla Ruksys', False]
# 6774 ['high school guidance counselor', 'Nancy West', False]
# 6777 ['guybrarian', 'David Hoskins', False]
# 6772 ['refinery planning manager', 'Gary Gambino', False]
# 6773 ['mom', 'Laura Hughes', False]
# 254 ['computer operations analyst', 'Bruce Cox', False]
# 3683 ['from Columbus, Ohio...', 'Sue Wright', False]
# 3682 ['from Alabama...', 'George Keller', False]
# 3686 ['international trade analyst', 'Dana Mermelstein', False]
# 3685 ['freelance writer', 'Barbara James', False]
# 3684 ['project manager', 'Andrew Garen', False]
# 2518 ['mother of twins', 'Lindley Henson', False]
# 2519 ['production assistant', 'Jay Marx', False]
# 2514 ['physics research intern', 'Robert Gomma', False]
# 2510 ['program director', 'Timothy Benston', False]
# 2512 ['publishing data manager', 'Meighan Larbi', False]
# 3530 ['mortgage loan analyst', 'Jason Sass', False]
# 3532 ['software tester', 'Nathan Chan', False]
# 3537 ['practice support coordinator', 'Jonathan Cole', False]
# 3536 ['freelance tutor', 'Ellen Green', False]
# 5054 ['author and pirate', 'John Baur', False]
# 3538 ['production coordinator', 'Christina Kim', False]
# 5050 ['researcher', 'Dorothy Farrell', False]
# 5051 ['real estate developer', 'Tom Koch', False]
# 5053 ['business information analyst', 'Kathleen Ryan', False]
# 1159 ['from West Chester, Pennsylvania...', 'Charlotte Darby', False]
# 1158 ['from Williamsville, New York...', 'Jon Er', False]
# 1154 ['instructional designer', 'Robin Carroll', False]
# 1157 ['from Escondido, California...', 'Matt Tick', False]
# 1151 ['from Montgomery, Texas...', 'Madison Ball', False]
# 1150 ['from Derwood, Maryland...', 'Brady Newell', False]
# 1153 ['actor and copy editor', 'India Cooper', False]
# 1152 ['history professor at Prairie View A&M University', 'Babu Srinivasan', False]
# 8034 ['e-commerce consultant', 'Susan Petracco', False]
# 8037 ['bakery owner and caterer', 'Sarah Hayden Williams', False]
# 8036 ['research chemist', 'Keith Whitener', False]
# 8031 ['volunteer storyteller', 'Betsy Chisolm', False]
# 8033 ['chemical engineer', 'Martin Powell', False]
# 8039 ['grocery merchandiser', 'Meredith Bateman', False]
# 8038 ['medical magazine editor', 'Erik Greb', False]
# 8529 ['college administrator', 'Justin Culkowski', False]
# 8528 ['sales representative', 'Sheila Halko', False]
# 8522 ['I.T. consultant', 'Ben Ingram', False]
# 8521 ['administrative assistant', 'Jacob Laux', False]
# 8520 ['legislative assistant', 'Jonathan Fellows', False]
# 8527 ['legislative aide', 'Dan Weber', False]
# 8525 ['political analyst', 'Rick Grimes', False]
# 8524 ['financial analyst', 'Leif Torkelsen', False]
# 8536 ['orthopedic nurse', 'Alice Kelly', False]
# 4299 ['account planning manager', 'Kelly Sherer', False]
# 1324 ['aerospace systems engineer', 'Leo Jones', False]
# 4742 ['salesperson', 'Hillary Wootton', False]
# 4741 ['insurance specialist', 'Jason Kaczor', False]
# 4747 ['homeschool mom', 'Ren\xe9e Mathis', False]
# 9006 ['research chemist', 'Keith Whitener', False]
# 8537 ['graphic designer and computer salesperson', 'Carlos Hernandez Fisher', False]
# 2183 ['national park ranger', "Bill O'Donnell", False]
# 2182 ['mortgage banker', 'Brian Scheetz', False]
# 2180 ['stay-at-home dad', 'Luke Fontano', False]
# 2187 ['veterinarian', 'Sidney Tison', False]
# 2186 ['managing editor', 'Lisa McAdam', False]
# 2184 ['user service consultant', 'Jaclyn Whitehorn', False]
# 2188 ['editor', 'Cait Murphy', False]
# 6907 ['TV director and producer', 'Dave Streit', False]
# 6906 ['freelance copy editor', 'Irene Dennis', False]
# 6905 ['eleven-year-old', 'John Farley', False]
# 6904 ['ten-year-old', 'Surabhi Iyer', False]
# 6903 ['eleven-year-old', 'Kyle Ziemnick', False]
# 6902 ['planning and evaluation manager', 'Aaron Wicks', False]
# 152 ['engineer', 'Hugh Price', False]
# 154 ['public relations executive', 'Elaine Lang', False]
# 157 ['fashion editor', 'Brent Winter', False]
# 159 ['journalist', 'Eric Berman', False]
# 8135 ['research assistant', 'Michele Myers Beuerlein', False]
# 8689 ['English professor', 'James Mardock', False]
# 6187 ['eleven-year-old', 'Sam Daub', False]
# 6186 ['twelve-year-old', 'Tory Gilliam', False]
# 6185 ['eleven-year-old', 'Nicole Savin', False]
# 6184 ['ten-year-old', 'Maxwell Baldi', False]
# 6183 ['ten-year-old', 'Anissa Chitour', False]
# 6182 ['ten-year-old', 'Neal Freyman', False]
# 6181 ['eleven-year-old', 'Elena Botella', False]
# 6180 ['eleven-year-old', 'Billy Hackenson', False]
# 8133 ['underwriter', 'Ashok Poozhikunnel', False]
# 6189 ["children's book author", 'Tui Sutherland', False]
# 2727 ['seller of antique prints and maps', 'Jane Toczek', False]
# 2726 ['writer and editor', 'Eileen Oshinsky', False]
# 2725 ['forensic accountant', 'Bob Peck', False]
# 2720 ['former bank manager', 'Marian Evans Melnick', False]
# 2729 ['twelve-year-old', 'William Tarpeh', False]
# 2728 ['professor of landscape architecture', 'Cobra Becerra', False]
# 7235 ['inventory control manager', 'Quinn McDonald', False]
# 7232 ['mutual funds analyst', 'Joe Mastroeni', False]
# 6955 ['research associate', 'Bill Gellert', False]
# 7238 ['Army ammunition inspector', 'Tim Maas', False]
# 7239 ['media coordinator', 'Kevin Dunn', False]
# 692 ['film distribution consultant', 'Ben Camack', False]
# 6239 ['12-year-old', 'Rachel Mills', False]
# 6238 ['10-year-old', 'Zachary Baumgartner', False]
# 6235 ['12-year-old', 'Scotty Ballard', False]
# 6234 ['11-year-old', 'Jimmy Miotto', False]
# 6237 ['11-year-old', 'Jacob Joyner', False]
# 6236 ['11-year-old', 'Sophia Marianiello', False]
# 6233 ['12-year-old', 'Savannah Morgan', False]
# 693 ['college professor', 'Deborah Kelly', False]
# 7815 ['anchor and reporter', 'David Faber', False]
# 7932 ['fundraiser', 'Carol Ann Hilton', False]
# 8866 ['records management consultant', 'Priscilla Emery', False]
# 8867 ['software-development manager', 'Jon McGuire', False]
# 690 ['network administrator', 'Brad Rutter', False]
# 8862 ['law clerk', 'Gudrun Juffer', False]
# 8863 ['public radio host', 'Geoff Norcross', False]
# 810 ['newspaper copy editor', 'Donna Brutkoski', False]
# 812 ['senior medical officer', 'Steinar Madsen', False]
# 813 ['assistant lecturer', 'Elena Kislenkova', False]
# 814 ['creative director', 'Soren Wedderkopp', False]
# 816 ['pharmaceutical dispenser', 'Mandi Hale', False]
# 817 ['banker', 'Hasib Yildirim', False]
# 7819 ['Washington, D.C. anchor', 'Katty Kay', False]
# 1700 ['secretary', 'Judy Squires', False]
# 1701 ['head cashier', 'Lucretia Manning', False]
# 5265 ['home schooling mother of two', 'Laura Pierce', False]
# 1705 ['chairman and CEO of an investment firm', 'David Glickman', False]
# 1707 ['digital librarian', 'Elizabeth Bellas', False]
# 4574 ['campaign administrator', 'Mike Emerman', False]
# 4575 ['research specialist', 'Brad Schinstock', False]
# 8112 ['real estate agent', 'Mike Wallace', False]
# 3028 ['media planner', 'Kimberley Nash', False]
# 3027 ['stay-at-home dad', 'Jeremy Golden', False]
# 3026 ['college counselor', 'Kate Goodyear', False]
# 3025 ['journalist', 'Geoff Boucher', False]
# 3024 ['computer consultant', 'Larry Cloud', False]
# 3020 ['sales manager', 'Mark Bordley', False]
# 8738 ['marketing executive', 'Bill Tolany', False]
# 695 ['energy conservation manager', 'Karen Olson', False]
# 8732 ['lecturer and academic advisor', 'Jane Wanninger', False]
# 8730 ['State Department press advisor', 'Emily Horne', False]
# 4198 ['foreign affairs officer', 'Richard Johnson', False]
# 4196 ['CPA and stay-at-home mom', 'Ann Kupitz', False]
# 4197 ['emergency room physician', 'Kevin Martin', False]
# 4194 ['aspiring screenwriter', 'Vernon Martin', False]
# 4195 ['software developer', 'Greg Dwyer', False]
# 4192 ['customer service representative', 'Darren Millam', False]
# 4193 ['internet copywriter', 'Kate Lowe', False]
# 5671 ['chocolatier', 'Stevie Benson', False]
# 5673 ['Montessori teaching assistant', 'Carrie Hotchkiss', False]
# 5674 ['director of human resources', 'Rhonda Sherman', False]
# 5676 ['software engineer', 'Travis Troyer', False]
# 5677 ['grant specialist', 'Collette Ryder-Consugar', False]
# 5679 ['research consultant', 'Alex Gershman', False]
# 6436 ['emergency physician', 'Don Kraft', False]
# 6434 ['technical information specialist', 'Teresa McGervey', False]
# 6431 ['Peace Corps recruiter', 'Jen McFann', False]
# 8198 ['book publishing editor', 'Tracy Bernstein', False]
# 6752 ['computer engineer', 'Kristian Zoerhoff', False]
# 6753 ['radiology resident', 'Sarah Bright', False]
# 6750 ['actress, comedian, author and reality-show host', 'Aisha Tyler', False]
# 6751 ['anchor', 'Anderson Cooper', False]
# 6754 ['social media editor', 'Lisa Horowitz', False]
# 6755 ['writer and bookstore owner', 'Jonathan Sanchez', False]
# 237 ['podiatrist', 'Beverly Spurs', False]
# 231 ['financial analyst', 'Steve Willis', False]
# 8740 ['information management coordinator', 'Rose Adams', False]
# 2539 ['video and film editor', 'Shelley Smith', False]
# 2533 ['computer graphic designer', 'Chris Hackett', False]
# 2536 ['writer and editor', 'Sandra Ulbrich', False]
# 2537 ['reservations agent', 'Barbara Von Pagel', False]
# 2535 ['reporter', 'Steve Norton', False]
# 5078 ['admissions director', 'Elaine Cooper', False]
# 5076 ['proposal writer', 'Darryl Tahirali', False]
# 939 ['12-year-old', 'Alex Stambaugh', False]
# 938 ['12-year-old', 'Brian Cunningham', False]
# 933 ['defense analyst', 'Kim Marshall', False]
# 932 ['financial consultant', 'Paul Barry', False]
# 931 ['restaurant manager', 'Aaron Schnier', False]
# 930 ['dance/movement therapist', 'Britney Harris', False]
# 937 ['10-year-old', 'Sara Jansson', False]
# 936 ['11-year-old', 'Ivan Kleinfeld', False]
# 935 ['technical support manager', 'Dan Tick', False]
# 5380 ['veterinarian', 'Cathy Weber', False]
# 5381 ['executive coach and author', 'Miriam Bamberger', False]
# 5382 ['history lecturer', 'Bryan Givens', False]
# 5384 ['project manager', 'Chris Edwards', False]
# 5386 ['recent graduate', 'Cassie Hill', False]
# 2411 ['assistant security manager', 'Steve Mandella', False]
# 795 ['director of planning & building', 'Joe Roberts', False]
# 794 ['computer programmer and analyst', 'Bill Nyden', False]
# 793 ['psychologist', 'Fran Pipp', False]
# 791 ['freelance writer', 'John Smith', False]
# 2145 ['freelance writer and personal shopper', 'Betsy Archbold', False]
# 799 ['mother of three', "Christen O'Connor", False]
# 798 ['freelance writer', 'Mark McDermott', False]
# 2415 ['freelance proofreader', 'Amasa Wainwright', False]
# 1138 ['director of technical assistance', 'Eric Newhouse', False]
# 2141 ["worker's compensation consultant", 'Jacqui Sukie', False]
# 1132 ['lieutenant in the New York Police Department', 'Frank Spangenberg', False]
# 1131 ['history professor', 'Beth Andreasen', False]
# 1130 ['reporter and writer', 'Brad Williams', False]
# 1134 ['author, comedian, and radio commentator', 'Bob Harris', False]
# 2419 ['speechwriter', 'Arthur Phillips', False]
# 2418 ['computer trainer', 'Pam Mifflin', False]
# 7148 ['freelance copywriter', "Sally O'Rourke", False]
# 7149 ['grocery store clerk', 'Justin Braganza', False]
# 7146 ['marketing manager', 'Dana Gresko', False]
# 7147 ['restaurant manager', 'Dan Jensen', False]
# 7140 ['freelance artist', 'Steve Gratz', False]
# 7141 ['recent college graduate', 'Alex Marchyshyn', False]
# 7142 ['legislative aide', 'Melissa Nilles', False]
# 7143 ['mail room clerk', 'Erik Lang', False]
# 2149 ['computer technician and musician', 'Mark Whittinghill', False]
# 2148 ['administrator & outreach officer', 'Laura McShane', False]
# 8053 ['creative director and branding consultant', 'Colin Bodels', False]
# 8051 ['retired paralegal', 'Bobbi Hiltibidal', False]
# 8509 ['administrative assistant', 'Deedie Gustavson', False]
# 8508 ['fundraiser', 'Joe Carroll', False]
# 2880 ['registered nurse and Ph.D candidate', 'Walt Senterfitt', False]
# 2881 ['business communications representative', 'Leslie Miller', False]
# 7497 ['engineer', 'Bob Smith', False]
# 7494 ['staffer for a political organization', 'Katie Baker', False]
# 7495 ['interpreter', 'Lynn Evans', False]
# 2 ['editor and writer', 'J.D. Smith', False]
# 3276 ['freelance writer and editor', 'Ellen Cook', False]
# 3277 ['newspaper publisher', 'Bret Bradigan', False]
# 1922 ['pediatric cardiologist', 'Susan desJardins', False]
# 1923 ['firefighter', 'Myron West', False]
# 4760 ['Internet marketing copy writer', 'Andy Catsimanes', False]
# 4762 ['Internet search editor', 'Dave Sikula', False]
# 4767 ['rare bookseller', 'Ann Drourr', False]
# 4768 ['public relations professional', 'Matt Stull', False]
# 8767 ['burn and wound surgeon', 'Vimal Murthy', False]
# 5808 ['technology salesman', 'Steve Frost', False]
# 5803 ['freelance editor', 'Noah Tarnow', False]
# 5800 ['recent law school graduate', 'Dave Hiersekorn', False]
# 5806 ['journalist', 'Cynthia Astle', False]
# 5805 ['medical editor', 'Linda Tomsho', False]
# 5804 ['freelance writer', 'Jack Feerick', False]
# 686 ['public relations coordinator', 'Mary Bowers', False]
# 682 ['newspaper reporter', 'Richard Willing', False]
# 8023 ['medical research technician', 'Meredith Lowmaster', False]
# 4888 ['design center manager', 'Brad Golstein', False]
# 4889 ['communications consultant and homemaker', 'Karen Skochinski', False]
# 2708 ['administrative assistant', 'Pat Posner', False]
# 4880 ['distinguished actor and TV host', 'LeVar Burton', False]
# 4881 ['college professor', 'Tim Wilson', False]
# 2707 ['analyst', 'Robert Manuel', False]
# 2706 ['restaurant owner', "Ned O'Rourke", False]
# 2703 ['new home sales assistant', 'Martin Smith', False]
# 4887 ['system analyst', 'Jim Austgen', False]
# 7962 ['12-year-old', 'Matthew Cline', False]
# 7963 ['10-year-old', 'Anna Cambron', False]
# 7966 ['12-year-old', 'Injee Hong', False]
# 7967 ['11-year-old', 'Ryan Griffin', False]
# 7964 ['11-year-old', 'Mandy Berry', False]
# 7965 ['12-year-old', 'Arjun Malhotra', False]
# 7968 ['11-year-old', 'Partha Purushotham', False]
# 7969 ['11-year-old', 'Julia Martinez', False]
# 6259 ['12-year-old', 'Michael Bergen', False]
# 6258 ['12-year-old', 'Emily Moin', False]
# 6253 ['10-year-old', 'Akshai Raj', False]
# 6252 ['10-year-old', 'Heather Peden', False]
# 6251 ['11-year-old', 'Matthew Silski', False]
# 6250 ['12-year-old', 'Jacob Hambalek', False]
# 6257 ['12-year-old', 'Andrew Bryson', False]
# 6256 ['12-year-old', 'Cate Heine', False]
# 6255 ['12-year-old', 'Thulasi Seshan', False]
# 6254 ['12-year-old', 'Kevin Yokum', False]
# 8545 ['secretary', 'Melinda Brownfield', False]
# 8016 ['administrative coordinator', 'Felicia McGowan', False]
# 3476 ['grants coordinator', 'Claire Williams', False]
# 3470 ['human resources manager', 'Ramon Flores', False]
# 3473 ['research analyst', 'Hanley Baxter', False]
# 8884 ['scientific program administrator', 'Cesar Perez-Gonzalez', False]
# 838 ['mathematics educator', 'Morgan Chase', False]
# 839 ['training manager', 'Steve Clark', False]
# 3479 ['sales and marketing manager', 'Gordon Heady', False]
# 8543 ['medieval historian', 'Jonathan Couser', False]
# 8010 ['federal investigator', 'Mike Lonesky', False]
# 7457 ['computer engineer', 'Graig Zethner', False]
# 8687 ['waiter', 'David Epperson', False]
# 7453 ['retired emergency room physician', 'Linda Percy', False]
# 5249 ['foreign service officer', 'Heather Townsend', False]
# 5248 ['bartender and recent college graduate', 'Rob Kobman', False]
# 1728 ['software engineer', 'Eric Heaton', False]
# 1727 ['human resources assistant', 'Kate Miller', False]
# 1724 ['actor and director', 'Patrick Mahoney', False]
# 1725 ['customer service representative', 'Jamie Phillippe', False]
# 5241 ['romance novelist and travel writer', 'Laura Paquet', False]
# 1720 ['computer consultant', 'Greg Sanders', False]
# 1721 ['registered massage therapist', 'Ellen Yancey', False]
# 9004 ['editor for academic competitions', 'Larissa Kelly', False]
# 9003 ['university professor', 'Russ Schumacher', False]
# 9001 ['manager of corporate and foundation relations at a music school', 'Celeste DiNucci', False]
# 7930 ['music critic', 'Lisa Grean', False]
# 3005 ['administrative assistant', 'Betty Cohn', False]
# 3004 ['home inspector and minister', 'Glenn Woertz', False]
# 3007 ['newspaper copy editor', 'Bob Fleenor', False]
# 3006 ['telecommunications manager', 'Sean Burton', False]
# 3003 ['marketing manager', 'David Mayer', False]
# 7935 ['director of development', 'Sister Carol Cimino', False]
# 3313 ['woodworker', 'Jim Eddy', False]
# 3312 ['senior website producer', 'Al Cadena', False]
# 7937 ['mental health therapist', 'Elisa Leigan', False]
# 1582 ['waiter', 'Jeff Pilgreen', False]
# 1581 ['cooking writer', 'Steve Muni', False]
# 1586 ['medical writer and editor', 'Nancy Baron', False]
# 3314 ['art historian', 'Linda Schildkraut', False]
# 5481 ['adjunct professor', 'Art Borgemenke', False]
# 8633 ['12-year-old seventh grader', 'Skyler Hornback', False]
# 5658 ['recording specialist', 'Rich Smreker', False]
# 5656 ['pharmacist', 'Kathy Sahlmann', False]
# 5657 ['screenwriter', 'Geoff Moore', False]
# 5654 ['volunteer', 'Michele Frankl', False]
# 5652 ['Foreign Service officer', 'Greg Morrison', False]
# 5650 ['college English professor', 'Zac Showers', False]
# 5651 ['college counselor', 'Josie Dickson', False]
# 6419 ['Basketball Hall of Famer and all-time leading scorer', 'Kareem Abdul-Jabbar', False]
# 6418 ['anchor and special correspondent', "Soledad O'Brien", False]
# 6415 ['musician and computer programmer', 'James Rogers', False]
# 6414 ['quotation specialist', 'Carin House', False]
# 6417 ['Grammy winner, Oscar nominee and multi-talented performer', 'Michael McKean', False]
# 6416 ['gift shop manager', 'Susan Durham', False]
# 6411 ['managing editor', 'Wendy Ruopp', False]
# 6410 ['casino worker', 'Nancy Fink', False]
# 7776 ['knitting store owner', 'Mary Harris', False]
# 7773 ['academic advisor', 'Trevor Bryan', False]
# 7771 ['environmental consultant', 'Doug Zang', False]
# 3916 ['internet project manager', 'Dan Emberley', False]
# 3915 ['professor of history', 'Pam Tyler', False]
# 3914 ['golf course manager', 'John Chapman', False]
# 3913 ['foreign service officer', 'Chuck Forrest', False]
# 3911 ['programmer and analyst', 'Yael Sofaer', False]
# 3910 ['community college professor', 'Keith Kashiwada', False]
# 3919 ['sales representative', 'Roger Brown', False]
# 6730 ['library page', 'Karen Hoffman', False]
# 6731 ['foreign service officer', 'Kirby Nelson', False]
# 6732 ['editor and writer', 'Shelby Sadler', False]
# 6735 ['customer care representative', 'Cyd Musni', False]
# 6738 ['clinical research coordinator', 'Sarah Rubin', False]
# 6739 ['patent agent', 'Robert Knecht Schmidt', False]
# 8318 ['study hall supervisor and retail manager', 'Ryan McLaughlin', False]
# 8319 ['commercial photographer', 'Lee Karjala', False]
# 216 ['finance administrator', 'Patricia Perlowski', False]
# 212 ['marketing communication coordinator', 'Alex Rubington', False]
# 211 ['researcher', 'Jonathan Henke', False]
# 218 ['editor', 'Bud Humphrey', False]
# 219 ['software analyst', 'Barrett Hildreth', False]
# 6087 ['actor and comic', 'Michael McKean', False]
# 6083 ['tight end', 'Shannon Sharpe', False]
# 3648 ['editor', 'Mark Staloff', False]
# 3647 ['medical document courier', 'Patrick Burns', False]
# 3646 ['stockbroker', 'Carol Vincent', False]
# 3641 ['college teaching assistant', 'Laura Wimberley', False]
# 3640 ['revenue agent', 'Sandy Yates', False]
# 2551 ['college freshman', 'Alexandra Petri', False]
# 2553 ['software developer', 'Charlton Wilbur', False]
# 2554 ['freelance producer', 'Donna Deans', False]
# 2555 ['educational researcher', 'Eric Barela', False]
# 2556 ['naval officer', 'Janet Marnane', False]
# 2557 ['traffic director', 'Brenda Buchanan', False]
# 2559 ['11-year-old', 'David Hudson, Jr.', False]
# 5011 ['surgeon', 'Bret DeLone', False]
# 5014 ['executive editor', 'Traci Turnbaugh Siegel', False]
# 5015 ['naval officer', 'Danny Whitehurst', False]
# 5018 ['administrative assistant', 'Debbie Barnes', False]
# 69 ['11-year-old sixth grader', 'Patrick Zakem', False]
# 4419 ['assistant professor of clinical psychology', 'Penny Asay', False]
# 4418 ['TV writer', 'Lisa Klink', False]
# 4417 ['freelance writer and surtitlist', 'Jenna Wallis', False]
# 4416 ['dog walker', 'Andy Wyke', False]
# 4415 ['videographer', 'Cy Gardner', False]
# 4412 ['foreign service officer', 'Steve Giegerich', False]
# 919 ['writer and editor', 'Laurie Parker', False]
# 918 ['ATM repairman', 'Jeff Slike', False]
# 915 ['11-year-old', 'Whitney Dearden', False]
# 914 ['11-year-old', 'Aki Terasaki', False]
# 917 ['systems consultant', 'Candy Martinez', False]
# 916 ['engineer and consultant', 'Sam Longoria', False]
# 911 ['11-year-old', 'William Marengo', False]
# 910 ['12-year-old', 'Nicole Tantoco', False]
# 913 ['12-year-old', 'Eric Webb', False]
# 912 ['10-year-old', 'Katie Baxter', False]
# 7168 ['virtual assistant', 'Amanda Sonmor', False]
# 7162 ['TV lighting technician', 'Carrie Oken', False]
# 7163 ['author and hypnotherapist', 'Ali Binazir', False]
# 7161 ['high school English tutor', 'Claudia Kasvin', False]
# 7166 ['videographer  and elementary school librarian', 'Scott Harris', False]
# 7167 ['systems engineer', 'Julie Wolfson', False]
# 3701 ['call center manager', 'Shawn Freeman', False]
# 630 ['newspaper copy editor', 'Bob Fleenor', False]
# 631 ['marketing manager', 'Doug Lach', False]
# 8071 ['economics research analyst', 'Morgan Kruse', False]
# 8070 ['case manager', 'Dan Sims', False]
# 8073 ['retired school library media specialist', 'Mona Hatfield', False]
# 8077 ['swim coach', 'Beth Youngers', False]
# 633 ['office automation manager', 'Susan McGowan', False]
# 636 ['research assistant', 'Robin Carroll', False]
# 8637 ['12-year-old seventh grader', 'Xan Vessels', False]
# 637 ['director of academics for a national test preparation company', 'Bob Verini', False]
# 1112 ['public policy coordinator', 'Eric Newhouse', False]
# 1442 ['pharmacist', 'Marty Miller', False]
# 1117 ['taxpayer service representative', 'Richard Neale', False]
# 1119 ['landscaper', 'Justin Porter', False]
# 1449 ['waitress', 'Mary Keefe', False]
# 1448 ['accounts receivable manager', 'Bryan Adams', False]
# 8636 ["manufacturer's representative", 'Rich Kenney', False]
# 6780 ['research associate', 'Morgan Saxby', False]
# 4584 ['photographer & desktop publisher', 'Naomi Barell Urbaitel', False]
# 2009 ['software developer', 'Nathan Meyers', False]
# 8635 ['professional snake handler', 'Ken Freedman', False]
# 4852 ['editor', 'Laurie Utterback', False]
# 4725 ['university professor', 'Gwynne Ash', False]
# 6524 ['freelance business writer', 'Kim McShane', False]
# 8634 ['vice president and project director', 'Delores Teus', False]
# 6914 ['twelve-year-old', 'Thomas Horn', False]
# 4721 ['associate director', 'Justin Scupine', False]
# 4720 ['director of judicial affairs', 'Scott Lewis', False]
# 4789 ['English professor', 'Rich House', False]
# 4788 ['adjunct English professor', 'Jean Oswald', False]
# 4787 ['national security consultant', 'Bill Moore', False]
# 4785 ['marketing executive', 'Gil Bauer', False]
# 4783 ['Navy officer', 'Jeff McCollum', False]
# 5821 ['county government employee', 'Brandon Grace', False]
# 5826 ['internet editor', 'Robert Niles', False]
# 8885 ['compliance analyst and voiceover artist', 'Arthur Chu', False]
# 8632 ['12-year-old seventh grader', 'Thomas Hurley', False]
# 6916 ['twelve-year-old', 'Jessica Anderson', False]
# 8631 ['12-year-old seventh grader', 'Shuli Jones', False]
# 8630 ['artist', 'David Whitehorse', False]
# 195 ['technology manager', 'Maura Gatowski', False]
# 194 ['bookseller', 'Eric Schwendeman', False]
# 196 ['engineer', 'Doug Esker', False]
# 6912 ['eleven-year-old', 'Joli Millner', False]
# 2768 ['playwright and director', 'Alan Bailey', False]
# 2763 ['software engineer', 'Travis Troyer', False]
# 2762 ['sales manager', 'Mark Lee', False]
# 2761 ['personal success coach', 'Max Levaren', False]
# 2765 ['administrative assistant and father', 'Mark Brown', False]
# 2764 ['surgeon', 'Jackie Harrison', False]
# 7908 ['homemaker and missionary', 'Sophia Schwarz', False]
# 7909 ['computer game designer', 'Scott Pearson', False]
# 7900 ['analyst', 'Stephanie Fontaine', False]
# 7901 ['land protection specialist', 'Chris Sullivan', False]
# 6913 ['twelve-year-old', 'Molly Gier', False]
# 7903 ['retired public defender', 'Henry Doering', False]
# 7904 ['research editor', 'Janet DeLand', False]
# 7905 ['journalist', 'Bob Menaker', False]
# 7906 ['editorial director', 'Kelly Regan', False]
# 6273 ['Congressional aide', 'Zach Goldberg', False]
# 6272 ['travel agent and travel writer', 'Rosanne Coloccia', False]
# 6275 ['self-proclaimed gadabout', 'John Munson', False]
# 6277 ['13-year-old', 'Alycia Kennedy', False]
# 6276 ['12-year-old', 'Mike Kim', False]
# 6279 ['12-year-old', 'Matthew Cohn', False]
# 420 ['marketing executive', 'Sharon Paterson', False]
# 3450 ['morning show radio producer', 'Spencer Kane', False]
# 3451 ['college professor', 'Michele Mohr', False]
# 3457 ['computer materials manager', 'Lyle Hertzig', False]
# 3454 ['personal assistant', 'Hilary Waddles', False]
# 3455 ['airline and cruise scheduler', 'Steve Fried', False]
# 3459 ['railroad chef', 'Sam Varnado', False]
# 858 ['customer relations specialist', 'Teresa Grasso', False]
# 859 ['medical secretary', 'Jeff Corrigan', False]
# 6 ['information manager', 'Laura Gustafson', False]
# 8905 ['shovel bum', 'Leszek Pawlowicz', False]
# 5229 ['moderator', 'Tim Russert', False]
# 5228 ['former governor', 'Christie Whitman', False]
# 5223 ['author and radio talk show host', 'Al Franken', False]
# 5222 ['journalist', 'Gretchen Carlson', False]
# 5220 ['computer support technician', 'Richard Adams', False]
# 5226 ['network administrator', 'Cindy Reilly', False]
# 5225 ['writer and editor', 'Tanya Tyler', False]
# 5224 ['electronic publishing consultant', 'Doug Yasso', False]
# 616 ['College Tournament winner', 'Craig Barker', False]
# 3062 ['scientist', 'Kathryn Wildt', False]
# 3061 ['collections account manager', 'Rob Core', False]
# 3065 ['lieutenant commander in the U.S. Navy', 'Ernest Fagan', False]
# 3064 ['freelance writer', 'Abigail Strubel', False]
# 3069 ['economic consultant', 'Alex Kania', False]
# 3068 ['golf greenskeeper', 'Armando Martinez', False]
# 1300 ['civil servant', 'Jack Patton', False]
# 1301 ['director of information services', 'Doug Morrison', False]
# 1309 ['product developer & designer', 'Marlene Reiss', False]
# 498 ['metal artist and fabricator', 'Steve Northey', False]
# 495 ['newspaper editor', 'Ken Costa', False]
# 496 ['office manager', 'Lisa Van Every', False]
# 497 ['office manager', 'Denise Berger', False]
# 492 ['program manager', 'Kim Lynn', False]
# 493 ['screenwriter', 'Paul McCudden', False]
# 6471 ['newspaper reporter', 'Clay Wilson', False]
# 6470 ['clinical support specialist', 'Carolyn Zsoldos', False]
# 6915 ['twelve-year-old', 'Caroline Evans', False]
# 7758 ['social media consultant', 'Lisa Lyons', False]
# 7755 ['after-school program coach', 'Jesse Tow', False]
# 7754 ['contract specialist', 'Michael Tvaruzka', False]
# 7750 ['poet and professor', 'Randy Cauthen', False]
# 7753 ['assistant professor of biology', 'Tamara Tatum-Broughton', False]
# 3938 ['digital librarian', 'Karim Khan', False]
# 3934 ['hospice chaplain', 'Tom Traylor', False]
# 3931 ['communications director', 'Josh Kamensky', False]
# 3930 ['journalist', 'Rachael King', False]
# 8333 ['investment analyst', 'Tim Kleiman', False]
# 8330 ['engineer', 'Michael McRee', False]
# 8331 ['associate editor', 'Shana Aborn', False]
# 3265 ['senior account executive', 'Steve DiGiulio', False]
# 8337 ['defense consultant', 'Gary Roberts', False]
# 6718 ['box office manager', 'Anne Damon', False]
# 6719 ['architect', 'Julia Brown', False]
# 6716 ['comedian and actor', 'Cheech Marin', False]
# 6710 ['law clerk', 'Ben Auer', False]
# 6711 ['arts administrator', 'Rhonda Scarborough', False]
# 876 ['reporter', 'Matt Barakat', False]
# 4044 ['study abroad program coordinator', 'Marc Hirsh', False]
# 4045 ['quality control manager', 'Tom Bartanen', False]
# 4046 ['legal staffing specialist', 'Mike Monday', False]
# 4040 ['Ph.D. candidate and part-time bank teller', 'Jeannie Sanke', False]
# 4042 ['chef and hotel manager', 'Arrington Widemire', False]
# 4048 ['artist', 'Jeff Robinson', False]
# 4049 ['educator', 'Justin T. Bradford, Jr.', False]
# 3667 ['director of photography', 'Eric Trageser', False]
# 3666 ['executive', 'Laura Ewing-Moore', False]
# 3660 ['writer and producer', 'Lee Ritchey', False]
# 3669 ['director of communications', 'Michael Caro', False]
# 2572 ['catering coordinator', 'Lauren High', False]
# 2573 ['milliner', 'Suzette Mariotti', False]
# 2571 ['pediatrician', 'Ken Davis', False]
# 3591 ['chemical and materials engineer', 'Steve Snyder', False]
# 3590 ['legislative aide', 'Debbie Harris', False]
# 3596 ['administrator', 'Alison Fowler', False]
# 5038 ['from <i>Seinfeld</i>...', 'Jason Alexander', False]
# 3594 ['elementary school librarian', 'Leigh King', False]
# 5036 ["from <i>Veronica's Closet</i>...", 'Dan Cortese', False]
# 5037 ['from <i>The Carol Burnett Show</i>...', 'Carol Burnett', False]
# 5034 ['exhibit developer', 'Matt Phillips', False]
# 5035 ['costume shop supervisor', 'Doris Nash', False]
# 5032 ['science writer', 'Kara Gavin', False]
# 5030 ['investment manager', 'Jules Staniewicz', False]
# 5031 ['retired educator', 'Lucy Anne McKosky', False]
# 4433 ['health policy analyst', 'Craig Schneider', False]
# 4432 ['United States Marine Corps major', 'Garth Sturdevant', False]
# 4439 ['magazine editor', 'Scott Rogers', False]
# 975 ['senior personnel specialist', 'Sue Agos', False]
# 974 ['technical specialist', 'Bronwyn Noble', False]
# 971 ['financial analyst', 'Adam Green', False]
# 978 ['customer service representative', 'Kim Wells', False]
# 871 ['flight attendant', 'Marielsa Ruiz', False]
# 8756 ['administrative assistant', 'Rhea Hantelman', False]
# 8757 ['clinical social worker', 'Andrea Massar', False]
# 3384 ['assistant director', "Thompson O'Sullivan", False]
# 7100 ['museum education coordinator', "Jamie O'Hagin", False]
# 7101 ['emergency police dispatcher', 'Rich Zayatz', False]
# 7102 ['middle school librarian', 'Kate Palladino', False]
# 3385 ['engineer', 'Doug Schwartz', False]
# 7105 ['English professor and mom', 'Liz Maziarz', False]
# 7106 ['retail assistant manager', 'Eugene Henderson', False]
# 7107 ['granny nanny', 'Sandra McClellan', False]
# 7108 ['social worker', 'Keri McConaghy', False]
# 5410 ['music store manager', 'Judy MacLeod Reardon', False]
# 5411 ['bookseller', 'Nick Aretakis', False]
# 5413 ['financial planner', 'Wes Pierce', False]
# 1681 ['internet technical support advisor', 'Jordan Lees', False]
# 1680 ['customer service representative', 'Lawrence Brown', False]
# 1685 ['stand-up comedian', 'Reed Rankin', False]
# 1686 ['library technician', 'Mary Danieli', False]
# 1469 ['foreign service officer', 'Abby Aronson', False]
# 1468 ['police officer', 'Frank Spangenberg', False]
# 1465 ['freelance communications business consultant', 'David Grant', False]
# 1467 ['film executive', 'Steve Berman', False]
# 1461 ["taxpayers' service representative", 'Richard Neale', False]
# 1463 ['newspaper district manager', 'Phil Turnbull', False]
# 1462 ['government worker', 'Roxanne Smith', False]
# 4238 ['banker', 'Kari Elias', False]
# 4237 ['12-year-old', 'Kizzle Cote', False]
# 4236 ['10-year-old', 'Harry Haghanegi', False]
# 4235 ['11-year-old', 'Nicole Karrow', False]
# 4234 ['bank trust officer', 'Camille Brovold', False]
# 4233 ['technical service manager', 'Ted Miller', False]
# 4232 ['pharmacist', 'Cindy Nobles', False]
# 4231 ['cook', 'Mark Chapman', False]
# 5591 ['software engineer', 'John Eskew', False]
# 5590 ['professional musician', 'Donna Lee DePrille', False]
# 5593 ['director of operations', 'Andy Vandiver', False]
# 5592 ['college history professor', 'Sally Hadden', False]
# 5595 ['sales representative', "Kerri O'Neill", False]
# 5594 ['market researcher', 'Marilyn Mitchell', False]
# 5599 ['writer and editor', 'Alison Stern-Dunyan', False]
# 319 ['investment analyst', 'Sahir Islam', False]
# 318 ['writer and editor', 'Michael Arnone', False]
# 313 ['transit cop', 'Frank Spangenberg', False]
# 312 ['newsstand clerk', 'Lionel Goldbart', False]
# 311 ['police officer', 'Frank Epstein', False]
# 317 ['writer and internet specialist', 'David Sampugnaro', False]
# 316 ['consultant', 'Vinita Kailasanath', False]
# 315 ['writer and producer', 'Steve Robin', False]
# 314 ['research officer', 'Robert Slaven', False]
# 1335 ['trademark consultant', 'Marianna Johnson', False]
# 1336 ['poker player and dog walker', 'Charles Bagot', False]
# 1333 ['law enforcement analyst', 'Nina Ostrovitz', False]
# 1332 ['program manager', 'Todd Roshak', False]
# 8699 ['recycling operations specialist', 'Stephanie Femrite Stevens', False]
# 8129 ['refugee affairs officer', 'Allen Park', False]
# 2293 ['video game merchandiser', 'Eric Allen', False]
# 2292 ['pediatrician', 'Rebecca Pinchoff', False]
# 2291 ['11-year-old', 'Rachel Beckman', False]
# 2290 ['11-year-old', 'Bobby Bretz', False]
# 2296 ['freelance puzzle editor', 'Karen L. Jones', False]
# 2295 ['social worker and notary public', 'Lisa Llanes-Simpson', False]
# 2294 ['research scientist', 'Bruce Lin', False]
# 8695 ['financial analyst', 'Matt Volk', False]
# 8125 ['freelance writer', 'Sarah Shemkus', False]
# 8124 ['college registrar', 'Nichole Mancone', False]
# 8693 ['latent print examiner', 'Jen Yoak', False]
# 8139 ['actuary', 'Matt Ruprecht', False]
# 7290 ['interactive developer', 'Daniel Cohen', False]
# 7293 ['localization editor', 'Michelle Franklin', False]
# 7295 ['museum educator', 'Annie Douglass', False]
# 7296 ['community college professor of literature', 'Amy Fulton Stout', False]
# 7297 ['chemical engineer', 'Jim Fenton', False]
# 6299 ['artist and administrative assistant', 'Gina Ash', False]
# 6298 ['film industry analyst', 'Woods Gleason', False]
# 6296 ['from Van Nuys, California...', 'Joel Lewin', False]
# 6293 ['sportscaster', 'Greg Gumbel', False]
# 6292 ['sportscaster', 'Jim Lampley', False]
# 6291 ['sportscaster', 'Al Michaels', False]
# 6290 ['retail specialist', 'Chris Miller', False]
# 7708 ['classical violist', 'Andrew Knebel', False]
# 7709 ['writer and communications strategist', 'Susannah Rosenblatt', False]
# 8511 ['data analyst', 'Darryl Campbell', False]
# 879 ['international program administrator', 'Steve Kohl', False]
# 3430 ['bookseller', 'Jennifer Read', False]
# 2747 ['journalist', 'Richard Perez-Pe\xf1a', False]
# 4846 ['systems analyst', 'Terry Currin', False]
# 4847 ['computer training consultant', 'Sarah Simson', False]
# 4841 ['secretary and bookkeeper', 'Wendi Harrell', False]
# 4842 ['systems engineer', 'Tammy King', False]
# 4843 ['international freight forwarder', 'Joe Padavic', False]
# 5200 ['environmental policy analyst', 'Tom Kerr', False]
# 5203 ['administrative assistant', 'Nancy Jasinski', False]
# 5202 ['administrative assistant and father', 'Mark Brown', False]
# 5207 ['Army officer', 'Steve Dalzell', False]
# 5209 ['contributing editor', 'Peggy Noonan', False]
# 5208 ['author and co-host', 'Tucker Carlson', False]
# 3049 ['bus driver', 'Bob Moore', False]
# 3040 ['legislative director', 'Paul Kalomiris', False]
# 3043 ['think tank director', 'Dave Mills', False]
# 3042 ['professor and tutor', 'Jeff Schwartz', False]
# 3045 ['production assistant', 'Pamela Meneley', False]
# 3044 ['technology specialist', 'Julie Dunlevy', False]
# 7522 ['business manager', 'Lanny Timan', False]
# 1094 ['assistant professor and artist', 'Anne Connell', False]
# 1095 ['finance supervisor', 'Kate Weiss', False]
# 1098 ['labor and delivery registered nurse', 'Alison Beightol', False]
# 1915 ['communications consultant', 'Cathy Boggs', False]
# 1323 ['editor', 'Pam Wilson', False]
# 1321 ['proposal writer', 'Jenn Carlson', False]
# 1326 ['research analyst', 'Breck Jeffery', False]
# 1327 ['payroll specialist', 'Glenda Niemiec', False]
# 6451 ['engineering manager', 'Imran Arif Maskatia', False]
# 6454 ['overnight grocery stocker', 'William English', False]
# 6457 ['personal banking representative', 'Chris Rodrigues', False]
# 6458 ['public health professional', 'Roopa Kalyanaraman Marcello', False]
# 8136 ['international education specialist', 'Steve Money', False]
# 8137 ['project specialist', 'Wendy Hayes', False]
# 6909 ['twelve-year-old', 'Ethan Waldman', False]
# 6908 ['twelve-year-old', 'Will Walters', False]
# 7739 ['welder', 'Dennis Wright', False]
# 7733 ['caterer', 'Melanie Spratford', False]
# 7730 ['compliance analyst', 'Kyle Roll', False]
# 7737 ['newspaper insert writer and designer', 'Nick Bulum', False]
# 7734 ['law clerk', 'Greg Bentley', False]
# 3953 ['residence hall director', 'Lore Guilmartin', False]
# 3952 ['Ph.D. candidate', 'Jeremy Anderson', False]
# 3950 ['freelance writer', "Julie O'Keefe", False]
# 3956 ['computer trainer', 'Marguerite Hester', False]
# 3955 ['art center director', 'Mark Fields', False]
# 8358 ['claims processor', 'Christina Rodriguez', False]
# 8359 ['website producer', 'Andy Hermann', False]
# 8350 ['law clerk for a federal judge', 'Michael Ellis', False]
# 8355 ['writer and game designer', 'Brad Geagley', False]
# 4062 ['doctoral candidate', 'Wes Borucki', False]
# 4060 ['software support analyst', 'Dawn Alexander', False]
# 4061 ['Internet content editor', 'Kara McDermott', False]
# 4067 ['international educator', 'Jim Laden', False]
# 4064 ['financial consultant', 'Debbie Mamber', False]
# 4065 ['TV engineer', 'Brian Carlson', False]
# 4069 ['implementation specialist', 'David Jay', False]
# 5784 ['marketing executive', 'Laura Sturaitis', False]
# 5785 ['technology consultant', 'Marlon Shows', False]
# 5786 ['director of finance and administration', 'Rebecca Wilkinson', False]
# 5780 ['market researcher', 'Kali Klena', False]
# 5783 ['caterer at fairs', 'Patrick Morris', False]
# 5788 ['grant proposal writer', 'Lynne McKenna Frazier', False]
# 5789 ['software developer', 'Trevor Janes', False]
# 3606 ['member of the U.S. Army Field Band', 'Bill Gabbard', False]
# 3605 ['grant writer', 'Arlynda Boyer', False]
# 3604 ['bartender and actor', 'Steven Price', False]
# 4452 ['crisis intervention counselor', 'Manx Foster-Audlin', False]
# 4450 ['systems administrator', 'Arch Mott', False]
# 4459 ['bond trader', 'Bruce Pickett', False]
# 4458 ['flight attendant', 'Heidi Daniels', False]
# 958 ['retired stagehand', 'Barry Molitch', False]
# 6334 ['Army wife', 'Melanie Leon', False]
# 6335 ['newspaper ad salesman', 'Dave Sutherland', False]
# 6336 ['stay-at-home wife', 'Judy Nakamura', False]
# 6337 ['account manager', 'Michael Schlitzer', False]
# 6330 ['firefighter', 'Chris Serb', False]
# 6331 ['museum publicist', 'Elisabeth Flynn', False]
# 6332 ['oil filtration business developer', 'Enrique Machado', False]
# 6339 ['Air Force officer and helicopter pilot', 'Marcus Jackson', False]
# 8909 ['head of the Consumer Financial Protection Bureau', 'Richard Cordray', False]
# 8908 ['aerospace consultant', 'Tom Nosek', False]
# 8904 ['sports business writer', 'Andrew Westney', False]
# 8907 ['strategic market analyst', 'Leslie Shannon', False]
# 8900 ['food-bank coordinator', 'Tarn Allen', False]
# 4969 ['from <i>ER</i>...', 'Noah Wyle', False]
# 4968 ['from the Broadway revue <i>Putting It Together</i>...', 'Carol Burnett', False]
# 7128 ['video game reviewer', 'Ryan Vogt', False]
# 7124 ['account manager', 'Samantha Barry', False]
# 4965 ['freelance writer', 'Deborah Gronich Tate', False]
# 7121 ['sales marketing consultant', 'Danni Steiner', False]
# 1669 ['image consultant', 'Jenny Winslow', False]
# 1667 ['from Dallas, Texas...', 'Amber Key-Murphy', False]
# 1666 ['seventh-grader', 'Chad Mosher', False]
# 1665 ['twelve-year-old', 'Madeleine Schwartz', False]
# 1663 ['writer and entrepreneur', 'Deborah Melman-Clement', False]
# 1662 ['PC technician', 'Kim Clemmer', False]
# 1661 ['twelve-year-old seventh-grader', 'Jacob Collins', False]
# 1660 ['twelve-year-old seventh grader', 'Nina Garcia', False]
# 591 ['researcher', 'Robin Carroll', False]
# 593 ['developer', 'Charles Hubert', False]
# 592 ['journalist', 'Ted Kissell', False]
# 595 ['research biologist', 'Cecile Myers', False]
# 597 ['refugee resettlement coordinator', 'Aaron Gershowitz', False]
# 596 ['U.S. Customs manager', 'Henry Zanetti', False]
# 599 ['nursing assistant', 'Monica Nishida', False]
# 2829 ['human resources executive', 'Walter Grubbs', False]
# 2824 ['U.S. Secretary of Education', 'Hon. Margaret Spellings', False]
# 2825 ['actor, writer, and director', 'Michael McKean', False]
# 2827 ['training manager', 'Sharon Golembeski', False]
# 2821 ['composer and musical director', 'Paul Shaffer', False]
# 5414 ['Episcopal priest', 'Kit Carlson', False]
# 5415 ['legislative assistant', 'Jenny Miller', False]
# 3382 ['sales representative', 'Lynn Parana', False]
# 5412 ['housewife and writer', 'Lucinda Sabino', False]
# 3381 ['freelance copywriter', 'Otis Maxwell', False]
# ...
# 3148 ['media analyst', 'Matt Fairley', False]
# 5778 ['computer network manager', 'Tom Lundregan', False]
# 5770 ['freelance editor and writer', 'Michele Lee Amundsen', False]
# 5773 ['truck loader and bartender', 'Willie Holmes', False]
# 5772 ['university professor', 'Gadi Ben-Yehuda', False]
# 5775 ['software entrepreneur', 'Kyle Pope', False]
# 5777 ['insurance adjuster', 'Matt Davidson', False]
# 3967 ['medical missions coordinator', 'Amy Fuller', False]
# 7413 ['professor of medieval literature', 'Meg Price', False]
# 7410 ['arts education administrator', 'Dolores DeStefano', False]
# 7411 ['field education coordinator', 'Jeff Amoros', False]
# 7416 ['twelve-year-old', 'Charlotte Scott', False]
# 7417 ['eleven-year-old', 'Aria Gerson', False]
# 7418 ['twelve-year-old', 'Graham Doskoch', False]
# 7419 ['eleven-year-old', 'Meg Walker', False]
# 6612 ['engine assembler', 'Jason Zollinger', False]
# 6611 ['artist', 'Deepa Iyengar', False]
# 6610 ['database administrator', 'Bobby Goldstein', False]
# 3500 ['trial judge', 'Ben Studdard', False]
# 3501 ['account manager', 'Brendan Roche', False]
# 3506 ['emergency room physician', 'Steve Cirelli', False]
# 2347 ['financial consultant', 'Andrew Burtle', False]
# 2342 ['office automation specialist', 'Robert Slaven', False]
# 2349 ['policy analyst', 'Sasha Volokh', False]
# 2348 ['foreign service officer', 'Carolyn Christian', False]
# 3708 ['Lutheran pastor', 'Bill Shields', False]
# 3709 ['licensed veterinary technician', 'Diane Harvey', False]
# 1889 ['science analyst', 'Greg Little', False]
# 1886 ['artist & designer', 'Kristi Yacich', False]
# 1885 ['medical researcher', 'Bruce Monroe', False]
# 1882 ['sports reporter', 'Budd Bailey', False]
# 2121 ['professor of economics', 'Mary Hirschfeld', False]
# 2123 ['communications director', 'Mason Cole', False]
# 2122 ['permit coordinator', 'Kristine Bachand', False]
# 2126 ['medical doctor', 'David Ono', False]
# 4661 ['water service inspector', 'Ben Chaput', False]
# 4663 ['reference server', 'Katie Furlong', False]
# 6917 ['eleven-year-old', 'Sita Yerramsetti', False]
# 6910 ['twelve-year-old', 'Andrea Salt', False]
# 6911 ['twelve-year-old', 'Bryce Piotrowski', False]
# 5173 ['Social Security quality assessor', 'Mary Webster', False]
# 5170 ['direct marketing executive', 'Tom Grant', False]
# 5177 ['underwriter', 'Matt Olsen', False]
# 5176 ['winner of 2 Emmys', 'Robert Guillaume', False]
# 5175 ['6-time Emmy Award nominee', 'Ed Begley Jr.', False]
# 5174 ['comedienne', "Rosie O'Donnell", False]
# 5179 ['from Fredericksburg, Virginia...', 'Tucker Warner', False]
# 131 ['environmental policy specialist', 'Megan Susman', False]
# 136 ['software engineer', 'Robert Bowsher', False]
# 139 ['political science professor', 'Jerry Mayer', False]
# 7254 ['research director', 'Duncan Stewart', False]
# 7250 ['floral designer', 'Mary Linnenbringer', False]
# 7251 ['bank branch manager', 'Zack Azzam', False]
# 7253 ['professor[?]', 'Rick Filloy', False]
# 6855 ['transcriber', 'Jeff Johnson', False]
# 6857 ['loss mitigation consultant', 'Susan Thatcher', False]
# 6856 ['elections administrator', 'Gerry Cuddyer', False]
# 6851 ['editor for a business school', 'Cathy Melocik', False]
# 6850 ['program analyst for the Department of Navy', 'Aaron Ammerman', False]
# 6853 ['biomedical writer', 'Cheryl Parrott', False]
# 6859 ['newspaper reporter', 'J.R. Lind', False]
# 6858 ['project manager', 'Greg Lyon', False]
# 89 ['aspiring playwright', 'John Murray', False]
# 80 ['publisher', 'Sandy Grimwade', False]
# 81 ['historian', 'Brian Shipley', False]
# 86 ['documentation manager', 'Jennifer Knapp', False]
# 87 ['billing administrator', 'Jerry Taggart', False]
# 8804 ['web editor', 'Reem Fattouh', False]
# 8805 ['literary manager', 'Murray Weiss', False]
# 8807 ['process-automation engineer', 'Phil Lowe', False]
# 8800 ['business intelligence consultant', 'Tahne Aarnes', False]
# 8809 ['retired police officer', 'Donna Fairweather-Foley', False]
# 6583 ['surgeon', 'Judy Weisman', False]
# 6581 ['food stylist', 'Vince Camillo', False]
# 6587 ['scientist', 'Sergiu Sanielevici', False]
# 6586 ['administrative assistant', 'Jessica Stapp', False]
# 6585 ['purchasing agent', 'Chris Gleason', False]
# 8202 ['game merchant', 'Dave Leach', False]
# 8201 ['underwriter', 'Ashok Poozhikunnel', False]
# 7625 ['photographic representative', 'Charley Horan', False]
# 7624 ['fulfillment manager', 'Patrick Rostock', False]
# 7626 ['yogurt franchise operator', 'John Kirk', False]
# 7620 ['corporate controller', 'Andrea Bornschlegel', False]
# 7623 ['comedy writer', 'Lesley Tsina', False]
# 7629 ['software analyst', 'Dave Leach', False]
# 7628 ['educational marketer', 'Lisa Spardel-Krol', False]
# 7828 ['stand-up comedian', 'Lewis Black', False]
# 1502 ['coffee shop manager and trainer', 'Lisa Peabody', False]
# 1503 ['computer programmer & writer', 'John Kiernan', False]
# 1500 ['university lecturer', 'Evan Fletcher', False]
# 1501 ['software engineer', 'Marcus Jackson', False]
# 3089 ['project manager', "Robin O'Brien", False]
# 3088 ['human resources systems manager', 'Nancy Mitchell', False]
# 1505 ['congressional staff member', 'Scott Kearin', False]
# 3087 ['stagehand', 'Joe Collins', False]
# 3086 ['graduate teaching assistant', 'Darrell Hagler', False]
# 3080 ['vice president of sales', 'Jay Myer', False]
# 3082 ['call center representative', 'Jesse Lamovsky', False]
# 3369 ['information specialist', 'Molly McGowan', False]
# 3885 ['newspaper editor', 'Chris Carson', False]
# 3884 ['musician and contract manager', 'Dave Abbott', False]
# 3886 ['retired patient advocate', 'Rosemary Travis', False]
# 3881 ['musician and entertainer', 'Lew Taylor', False]
# 3880 ['literary agent and writer', 'Judson Knight', False]
# 3888 ['preacher and doctoral candidate', 'Faith Kirkham Hawkins', False]
# 8325 ['business manager', 'Karla Stahl', False]
# 8324 ['law clerk', 'Greg Haroutunian', False]
# 8327 ['consultant', 'Rick Muenchow', False]
# 8326 ['information technology consultant', 'Mary Ann McIntyre', False]
# 8323 ['global health consultant', 'Brad Tytel', False]
# 8322 ['analyst for the federal government', 'Diane Mezzanotte', False]
# 1291 ['stamp dealer', 'Marvin Shinkman', False]
# 6006 ['Air Force logistician', 'Wayne Byron', False]
# 6007 ['Navy lab technician', 'Beth Sanfilippo', False]
# 6004 ['Navy anesthesiology resident', 'Alex Meza', False]
# 6005 ['Marine Corps infantry officer', 'Thomas Citrano', False]
# 6002 ['Navy supply corps officer', 'Charles Hurst', False]
# 6003 ['Air Force action officer', 'Steve Dranchak', False]
# 6000 ['Marine Corps intelligence chief', 'Bill Wellman', False]
# 6001 ['Air Force air traffic controller', 'Karen Smith', False]
# 6008 ['Marine company commander', 'Ben Connable', False]
# 6009 ['Air Force weapons systems officer', 'Michael Arnold', False]
# 7395 ['oncologist', 'Jay Rhee', False]
# 7394 ['software architect', 'Steve Sobelman', False]
# 7397 ['director and writer of a sketch comedy theater', 'Scott Goldstein', False]
# 7391 ['stay-at-home mother', 'Lisa Longo', False]
# 7390 ['telecommunications manager', 'Guy Tonti', False]
# 7393 ['personal assistant', 'Danielle Harlow', False]
# 7392 ['foreign service officer', 'Stewart Tuttle', False]
# 7399 ['project manager', 'Kate Sparich', False]
# 7398 ['mom and volunteer', 'Julianna Suchard', False]
# 9098 ['consultant', 'Ethan Rasiel', False]
# 9096 ['dentist', 'Dylan Gaillard', False]
# 9097 ['law professor', 'Jeanne Kaiser', False]
# 9092 ['U.S. Air Force logistics readiness officer', 'Steve Martinez', False]
# 9093 ['media consultant', 'Simone Chavoor', False]
# 5098 ['author and comedian', 'Al Franken', False]
# 5099 ['former congresswoman', 'Pat Schroeder', False]
# 3579 ['sales representative', 'Sheryl Page', False]
# 3578 ['computer science professor', 'Scott Weiss', False]
# 5090 ['advertising creative director', 'Isaac Segal', False]
# 5092 ['tech salesman', 'Fred Henn', False]
# 5094 ['journalist', 'Dee Dee Myers', False]
# 5095 ['congressman', 'Jesse L. Jackson, Jr.', False]
# 5096 ['client services manager', 'Liz Basile', False]
# 4497 ['journalist', 'Adrian Higgins', False]
# 4494 ['investment portfolio manager', 'Greg Sondern', False]
# 4493 ['software engineer', 'Joe Maravillas', False]
# 4491 ['technical editor and writer', 'Robin Jones', False]
# 4498 ['airline salesperson', 'Margot Wiegele', False]
# 2938 ['editor', 'Tara Kolden', False]
# 2936 ['coffeehouse owner', 'Lorraine Mariz', False]
# 2934 ['realtor', 'John Gershkoff', False]
# 2932 ['freelance writer and stand-up comedian', 'Steve Calechman', False]
# 2931 ['recent college graduate', 'Quyen Luu', False]
# 5327 ['administrative assistant', 'Hope Weinman', False]
# 5324 ['cable television system manager', 'Danny Jobe', False]
# 5322 ['actor and copy editor', 'India Cooper', False]
# 5323 ['treasury associate', 'Elayna Kotsaftis', False]
# 5320 ['financial consultant', 'Kurt Kroboth', False]
# 3799 ['humanitarian advocate', 'Sarah Martin', False]
# 5328 ['freelance editor and writer', 'Joal Hetherington', False]
# 3796 ['brand strategist', 'Leigh Bachman', False]
# 3168 ['data processing consultant', 'Tom Daily', False]
# 3169 ['emergency room physician', 'Jeremy Simon', False]
# 3166 ['talent backer', 'Jessica Finkelberg', False]
# 3165 ['media affadavit specialist', 'Jeff DeVries', False]
# 3160 ['forensic engineer', 'Daniel Melcher', False]
# 731 ['freelance writer', 'Hal Akerman', False]
# 730 ['boat captain', 'Brian Perachet', False]
# 2157 ['director of communication', 'Kris MacCubbin', False]
# 737 ['Catholic priest', 'Tom Smolich', False]
# 739 ['marketing and strategy consultant', 'Mary Sue Hoban', False]
# 2150 ['Air Force officer', 'John Perez', False]
# 2152 ['environmental policy specialist', 'Amy Rosenfeld', False]
# 2153 ['state fraud manager', 'Earl Smith', False]
# 8566 ['theatrical production manager', 'Andrea Ladik', False]
# 8565 ['theater and opera lighting designer', 'Bradley King', False]
# 8564 ['library shelver and pet sitter', 'Deborah Stowell', False]
# 8561 ['administrative assistant', 'Libby Webber', False]
# 8560 ['commercial pilot', 'Toby Crew', False]
# 8568 ['public relations associate', 'Amanda Farrish', False]
# 7478 ['housing court judge', 'Anne Kenney Chaplin', False]
# 7479 ['forensics researcher', 'Ellen Mizio', False]
# 7472 ['educational publishing digital producer', 'Alex Liteplo', False]
# 7473 ['school receptionist', 'Beth Hermann', False]
# 7474 ['dairy machine operator', 'Patrick Sweaney', False]
# 7477 ['communications manager', 'Brian Lehman', False]
# 6639 ['public relations executive', 'Darryl Konter', False]
# 6630 ['cost accounting manager', 'Sue Shelly', False]
# 6632 ['health care application consultant', 'Ted Ahern', False]
# 6637 ['energy efficiency analyst', 'Jennifer Thorne', False]
# 4706 ['legal writer', 'Beth Holliday', False]
# 4705 ['play-by-play announcer', 'Bill Needle', False]
# 4702 ['fundraiser', 'Beth Looney', False]
# 4700 ['distribution manager', 'Steve Bennett', False]
# 2329 ['customer service supervisor', 'Ronda Barker', False]
# 2328 ['business owner', 'Helen Sporher', False]
# 4709 ['portfolio manager', 'Karen Rosenberg', False]
# 4708 ['pricing manager', 'Maria Campbell', False]
# 3760 ['nonprofit consultant', 'Bruce Leggat', False]
# 3761 ['bookseller', 'Carol Coltz', False]
# 3762 ['graduate assistant', 'James Clark', False]
# 3763 ['manager of marketing intelligence', 'Cindy Ladensack', False]
# 3764 ['snowcoach driver and hotel manager', 'Vic Sawyer', False]
# 2499 ['data conversion operator', 'Elizabeth Haines', False]
# 4642 ['research analyst', 'Rachel Stohl', False]
# 2490 ['telephone operator', 'Nick Lamelza', False]
# 4640 ['geographic information systems analyst', 'Lee Diveley', False]
# 4646 ['network administrator', 'Linda Ferrazzara', False]
# 7898 ['police officer', 'Bruce Wiley', False]
# 7892 ['public library director', 'Leslie Page', False]
# 7893 ['theme park ride operator', 'Leo Velazquez', False]
# 5158 ['retired advertising agent', 'Kathy Krieger', False]
# 5152 ['technical services representative', 'Gabriel Lyon', False]
# 5155 ['packaging consultant', 'George Schroeder', False]
# 5154 ['food editor', 'Ann Burger', False]
# 115 ['price protection manager', 'Sanda Kurtz', False]
# 114 ['IT consultant', 'Philip Graves', False]
# 111 ['editor', 'Dan Ford', False]
# 113 ['illustrations coordinator', 'Whitney Donaghy', False]
# 112 ['research associate', 'Lisa Buckhout', False]
# 3244 ['ecologist', 'Sharon Morgan', False]
# 118 ['theater director and stay-at-home dad', 'Rob Kimbro', False]
# 7273 ['adult education director', 'Ellen Dickens', False]
# 7270 ['sculptor and writer', 'Ted Sitting Crow Garner', False]
# 7276 ['creative project manager', 'Amanda Wallwin', False]
# 7277 ['British literature lecturer and lacrosse coach', 'J.D. Lopez', False]
# 7274 ['pub trivia editor', 'Christopher Short', False]
# 7275 ['law clerk', 'Mark Samburg', False]
# 7278 ['library worker', 'Tom Moosbrugger', False]
# 7279 ['realtor', 'Ko Otaka', False]
# 8557 ['sales manager', 'John Schroth', False]
# 6833 ['stay-at-home dad', 'Stephen Weingarten', False]
# 6837 ['Air Force intelligence officer', 'Joey Beachum', False]
# 6834 ['bookseller', 'Terry Linwood', False]
# 6839 ['video game tester', 'Stefan Goodreau', False]
# 6838 ['engine assembler', 'Jason Zollinger', False]
# 8005 ['Internet marketer', 'Erik Dresner', False]
# 8823 ['computer technician', 'Greg Munda', False]
# 8826 ['professional volunteer', 'Roxann Smith', False]
# 8827 ['law professor', 'Anthony Niblett', False]
# 8824 ['actuary', 'Larry White', False]
# 8825 ['youth minister', 'Kristina Lukach', False]
# 8828 ['navy wife and stay-at-home mom', 'Missy Flood', False]
# 8003 ['retail sales associate', 'Sara Lehmann', False]
# 7643 ['military charter flight attendant', 'Bryan Barnett', False]
# 7641 ['hockey arena announcer', 'Sean Norris', False]
# 7640 ['law clerk for a federal judge', 'Julie Podlesni', False]
# 7647 ['professor of media studies', 'Cindy Conaway', False]
# 7645 ['college soccer coach', 'Katy Stigers', False]
# 7644 ['strategy consultant', 'Vinayak Thiagarajan', False]
# 7649 ["men's clothing sales associate", 'Mike Hatch', False]
# 7648 ['actor and Phillie Phanstormer', 'Brandon Libby', False]
# 9014 ['senior managing editor', 'Michelle Leppert', False]
# 9015 ['director of compensation', 'Ed Hagar', False]
# 9016 ['translation coordinator', 'Sandie Baker', False]
# 9017 ['high-school campus director', 'Jonathan Kuehnle', False]
# 1744 ['project manager', 'Rick Bunch', False]
# 1747 ['choir accompanist', 'Katie Clark', False]
# 1742 ['contract coordinator', 'Jessica Liese', False]
# 1486 ['conservationist', 'Girish Bhat', False]
# 5495 ['association vice president', 'Lynn Olson', False]
# 1489 ['transcriber', 'Amanda Pompili', False]
# 1488 ['caterer', 'John Stratford', False]
# 7920 ['retired software developer', 'Liza Veeneman', False]
# 5490 ['psychologist', 'Marcia Hochberg', False]
# 7921 ['social worker', 'Ina Gail Goldberg', False]
# 5491 ['telecommunications manager', 'David Blakely', False]
# 1569 ['communications manager', 'Diane Tabbott', False]
# 1298 ['reference assistant', 'Pat Godwin', False]
# 5492 ['payroll administrator', 'Steffa Burke', False]
# 1294 ['database administrator', 'Wendy Stancer', False]
# 1295 ['investment specialist', 'Ben Davis', False]
# 7462 ['psychologist', 'Steve Burns', False]
# 5026 ['tour guide', 'Sujit Roy', False]
# 5638 ['sales manager', 'John Franklin', False]
# 5639 ['English professor', 'Barbara Liu', False]
# 5634 ['administrative coordinator', 'Layla Anson', False]
# 5635 ['senior clinical data coordinator', 'Amanda Potocky', False]
# 5636 ['campaign staffer', 'Rob Eingurt', False]
# 5630 ['director of employment services', 'Heather Hunter Smith', False]
# 5632 ['video editor', 'David Dayen', False]
# 8481 ['Ph.D. candidate in finance', 'Tom Hanson', False]
# 8482 ['data analyst', 'Judy Cole', False]
# 8484 ['musician and singer of classic American showtunes and love songs', 'Michael Feinstein', False]
# 8485 ['winner of a CableACE award and star of her own TV show', 'Paula Poundstone', False]
# 8486 ["television's favorite pychiatrist, Dr. Frasier Crane", 'Kelsey Grammer', False]
# 8487 ['Emmy award winner', 'Jay Thomas', False]
# 8488 ['news reporter and anchor', 'Tabitha Soren', False]
# 8489 ['Tony award winner and TV star', 'Jerry Orbach', False]
# 7464 ['freelance writer', 'Jack Lechner', False]

# %%
# Code to produce a list of tallied occupations
from pprint import pprint
onlyoccs= filterdict(playerdict)
findmorethan(finduniqueoccs(onlyoccs),5)

foundcodes = {}

for key, value in playerdict.iteritems():
    if value[2] !=False:
        code = value[2]
    else:
        continue
    
    if code[0] + " " + code[2] not in foundcodes:
        foundcodes[code[0] + " " + code[2]] = 1
    else:
        foundcodes[code[0] + " " + code[2]] += 1

pprint(findmorethan(foundcodes,30))
# Out:
# {'23-1011 Attorney': 315,
#  '23-1011 Lawyer': 94,
#  '25-MiscTeacher Teacher': 688,
#  '27-2011 Actress': 44,
#  'GradStu Graduate student': 307}

# %%
# Part 3: prepare the dictionary for output
# Run playerdict through the output prep function

headers = ['PlayerID','Occupation','Name','MatchedSocCode','MatchedSocCore','MatchedSocTitle']
dictforprinting = prettyprintdict(playerdict,headers)
#print dictforprinting

# %%
# Part 4: Write the processed playerdict to a csv
with open('playerout.csv','w') as f:
    f_csv = csv.DictWriter(f,headers)
    f_csv.writeheader()
    f_csv.writerows(dictforprinting)

# %%
print "foo"
# Out:
# foo

# %%
pprint(playerdict)
# Out:
# {'1': ['software engineer', 'Ken Jennings', False],
#  '10': ['writer', 'Bill Scheller', False],
#  '100': ['sophomore at Stanford University', 'Jeff Love', False],
#  '1000': ['senior', 'Peji Ghanouni', False],
#  '1001': ['senior', 'Andrew McGeorge', False],
#  '1002': ['teacher', 'Susan Davis', ['25-MiscTeacher', 'Teacher', 'Teacher']],
#  '1003': ['shopping mall manager', 'Dennis Shirilla', False],
#  '1004': ['lumber salesman', 'Larry Minton', False],
#  '1005': ['systems analyst', 'Freddye Silverman', False],
#  '1006': ['attorney', 'David Marcus', ['23-1011', 'Lawyers', 'Attorney']],
#  '1007': ['housewife', 'Isabel Leininger', False],
#  '1008': ['temporary secretary', 'Erik Larsen', False],
#  '1009': ['advertising copywriter',
#           'Kevin Gillogly',
#           ['27-3043', 'Writers and Authors', 'Advertising Copywriter']],
#  '101': ['sophomore at the University of Pittsburgh', 'Amanda Nowotny', False],
#  '1010': ['human resources management consultant', 'Mac Jones', False],
#  '1011': ['librarian', 'Barbara Lieberman', False],
#  '1012': ['writer & consultant', 'Jim Hennessy', False],
#  '1013': ['proofreader',
#           'Deborah Hummel',
#           ['43-9081', 'Proofreaders and Copy Markers', 'Proofreader']],
#  '1014': ['librarian', 'Lyn Payne', False],
#  '1015': ['high school French teacher',
#           'David Wyatt',
#           ['25-MiscTeacher', 'Teacher', 'Teacher']],
#  '1016': ['test systems analyst', 'Doug Antoniazzi', False],
#  '1017': ['computer specialist', 'Kathy Rice', False],
#  '1018': ['artist', 'Jerry Fried', False],
#  '1019': ['information officer', 'Gunther Freehill', False],
#  '102': ['junior at Georgetown University', 'Matt Bushell', False],
#  '1020': ['programmer and analyst', 'Keith Pickering', False],
#  '1021': ['physician', 'Elaine Zollner', False],
#  '1022': ['housewife & student', 'Gretchen Pruett', False],
#  '1023': ['advertising copywriter',
#           'Martin Gostanian',
#           ['27-3043', 'Writers and Authors', 'Advertising Copywriter']],
#  '1024': ['systems analyst', 'Kathy Donegan', False],
#  '1025': ['graduate student',
#           'Brannon Denning',
#           ['GradStu', 'Graduate student', 'Graduate student']],
#  '1026': ['attorney', 'David Bagley', ['23-1011', 'Lawyers', 'Attorney']],
#  '1027': ['writer', 'Sarah Stegall', False],
#  '1028': ['naval officer', 'Ken Mitchell', False],
#  '1029': ['attorney', 'Jamie Orenstein', ['23-1011', 'Lawyers', 'Attorney']],
#  '103': ['junior at West Virginia University', 'Kelley Burd', False],
#  '1030': ['teacher',
#           'Sharon Schwartz',
#           ['25-MiscTeacher', 'Teacher', 'Teacher']],
#  '1031': ['accountant',
#           'Michael Abracham',
#           ['13-2011', 'Accountants and Auditors', 'Accountant']],
#  '1032': ['color separator', 'Ken Sarajian', False],
#  '1033': ['curatorial assistant', 'Mary Beth Smalley', False],
#  '1034': ['political humorist', 'Bob Harris', False],
#  '1035': ['teacher',
#           'Gabriella Anderson',
#           ['25-MiscTeacher', 'Teacher', 'Teacher']],
#  '1036': ['hot dog vendor', 'John Cunningham', False],
#  '1037': ['marketer', 'Valerie Williams', False],
#  '1038': ['attorney', 'Willy Jay', ['23-1011', 'Lawyers', 'Attorney']],
#  '1039': ['student', 'Catie Camille', False],
#  '104': ['junior at the University of Missouri', 'Larry Marshall', False],
#  '1040': ['lawyer', 'Andrew Bernknopf', ['23-1011', 'Lawyers', 'Lawyer']],
#  '1041': ['teacher',
#           'Don McQuarrie',
#           ['25-MiscTeacher', 'Teacher', 'Teacher']],
#  '1042': ['graduate student',
#           'Matthew Luter',
#           ['GradStu', 'Graduate student', 'Graduate student']],
#  '1043': ['construction manager', 'Jennifer Buermann', False],
#  '1044': ['food service director',
#           'Paul Lenzi',
#           ['11-9051', 'Food Service Managers', 'Food Service Director']],
#  '1045': ['housewife', 'Glenda Wells', False],
#  '1046': ['marketing interviewer', 'John Shivers', False],
#  '1047': ["children's museum designer", 'Sharon Rupe', False],
#  '1048': ['pediatrician', 'Martha McKinney', False],
#  '1049': ['research scientist', 'Michael Shirts', False],
#  '105': ['senior at the University of Texas', 'Lindsey Hargrove', False],
#  '1050': ['legal text editor', 'Myles Rossi', False],
#  '1051': ['writer', 'Ardwight Chamberlain', False],
#  '1052': ['homemaker', 'Janet Kaufman', False],
#  '1053': ['production assistant', 'Eric Rosen', False],
#  '1054': ['real estate consultant', 'Andy Gedo', False],
#  '1055': ['senior account executive', 'Dan Ritey', False],
#  '1056': ['teacher',
#           'David Vanden Heuvel',
#           ['25-MiscTeacher', 'Teacher', 'Teacher']],
#  '1057': ['recent law school graduate', 'Mark Hinckley', False],
#  '1058': ['CPA and financial officer', 'Joel Goldberg', False],
#  '1059': ['musician',
#           'Victoria Groce',
#           ['27-2042', 'Musicians and Singers', 'Musician']],
#  '106': ['senior at Williams College', 'Ari Schoenholtz', False],
#  '1060': ['sailor',
#           'Steve Kaltenbaugh',
#           ['53-5011', 'Sailors and Marine Oilers', 'Sailor']],
#  '1061': ['retired advertising executive', 'Ray Freson', False],
#  '1062': ['instructor and writer', 'Stacey Swann', False],
#  '1063': ['supercomputer programmer', 'Ed Borasky', False],
#  '1064': ['public relations director',
#           'Anne King',
#           ['11-2031',
#            'Public Relations and Fundraising Managers',
#            'Public Relations Director']],
#  '1065': ['high school librarian',
#           'Carol Hager',
#           ['25-4021', 'Librarians', 'High School Librarian']],
#  '1066': ['air quality consultant', 'Mike Leger', False],
#  '1067': ["children's theater actor", 'Joel Silverman', False],
#  '1068': ['administrative assistant', 'Kerry Noonan', False],
#  '1069': ['adjunct professor and writer', 'Chris Hartley', False],
#  '107': ['junior at Columbia University', 'Lily Wang', False],
#  '1070': ['homemaker', 'Deborah Slattery', False],
#  '1071': ['history teacher',
#           'Jim George',
#           ['25-MiscTeacher', 'Teacher', 'Teacher']],
#  '1072': ['librarian', 'Liz Barnea', False],
#  '1073': ['agency manager', 'Steve Mueller', False],
#  '1074': ['writer', 'Heather Pharo', False],
#  '1075': ['student', 'Andrew Segal', False],
#  '1076': ['travel agency owner', 'Bette Greenfield', False],
#  '1077': ['lawyer', 'Dave McCarthy', ['23-1011', 'Lawyers', 'Lawyer']],
#  '1078': ['radio host',
#           'Melissa Ingells',
#           ['27-3011', 'Radio and Television Announcers', 'Radio Host']],
#  '1079': ['graduate student',
#           'Monica Vidrio',
#           ['GradStu', 'Graduate student', 'Graduate student']],
#  '108': ['senior at the University of Wisconsin - Green Bay',
#          'Christina Maes',
#          False],
#  '1080': ['management consultant',
#           'Beverly Davenport',
#           ['13-1111', 'Management Analysts', 'Management Consultant']],
#  '1081': ['U.S. Coast Guard officer', 'Pete Brown', False],
#  '1082': ['sales manager', 'Andy Rosenberg', False],
#  '1083': ['executive recruiter', 'Caleb Whitaker', False],
#  '1084': ['security inspector', 'Richard Dial', False],
#  '1085': ['apartment building manager', 'Bennett Crocker', False],
#  '1086': ['photographer', 'Dan Avila', False],
#  '1087': ['bankruptcy attorney', 'Eric Miller', False],
#  '1088': ['computer programmer',
#           'Ann Catlin',
#           ['15-1131', 'Computer Programmers', 'Computer Programmer']],
#  '1089': ['financial consultant', 'Robin Corkery', False],
#  '109': ['sophomore at Florida State', 'Brad Selvig', False],
#  '1090': ['graduate student',
#           'Carol Chaffee',
#           ['GradStu', 'Graduate student', 'Graduate student']],
#  '1091': ['real estate lawyer', 'Tom Streit', False],
#  '1092': ['student', 'Jeanie Kyle', False],
#  '1093': ['attorney and writer', 'Gary Klein', False],
#  '1094': ['assistant professor and artist', 'Anne Connell', False],
#  '1095': ['finance supervisor', 'Kate Weiss', False],
#  '1096': ['medical student', 'Guy Pugh', False],
#  '1097': ['bookkeeper',
#           'Paula Massengale',
#           ['43-3031',
#            'Bookkeeping, Accounting, and Auditing Clerks',
#            'Bookkeeper']],
#  '1098': ['labor and delivery registered nurse', 'Alison Beightol', False],
#  '1099': ['assistant teacher',
#           'Mark Barrett',
#           ['25-MiscTeacher', 'Teacher', 'Teacher']],
#  '11': ['attorney', 'Kollin Min', ['23-1011', 'Lawyers', 'Attorney']],
#  '110': ['sophomore at Dickinson College', 'Rachel McCool', False],
#  '1100': ['attorney', 'Robin Meyer', ['23-1011', 'Lawyers', 'Attorney']],
#  '1101': ['Naval officer', 'Mark Crouter', False],
#  '1102': ['attorney', 'Elizabeth Randisi', ['23-1011', 'Lawyers', 'Attorney']],
#  '1103': ['teacher', 'Will Hester', ['25-MiscTeacher', 'Teacher', 'Teacher']],
#  '1104': ['attorney', 'John Baird', ['23-1011', 'Lawyers', 'Attorney']],
#  '1105': ['human resources advisor', 'Doug Fisher', False],
#  '1106': ['office account manager', 'Michelle Collier', False],
#  '1107': ['homemaker', 'Brenda Bright', False],
#  '1108': ['pharmacy technician',
#           'Jason Richards',
#           ['29-2052', 'Pharmacy Technicians', 'Pharmacy Technician']],
#  '1109': ['marine biologist',
#           'Zeb Schobernd',
#           ['19-1023',
#            'Zoologists and Wildlife Biologists',
#            'Marine Biologist']],
#  '111': ['editor', 'Dan Ford', False],
#  '1110': ['cathecetical center associate director', 'Joe Esparza', False],
#  '1111': ['trial lawyer',
#           'Deborah Peters',
#           ['23-1011', 'Lawyers', 'Trial Lawyer']],
#  '1112': ['public policy coordinator', 'Eric Newhouse', False],
#  '1113': ['graduate student',
#           'Chris Capozzola',
#           ['GradStu', 'Graduate student', 'Graduate student']],
#  '1114': ['Harvard graduate whose musical was produced off-Broadway',
#           'David Javerbaum',
#           False],
#  '1115': ['medical communications consultant',
#           'Thaddeus Grimes-Gruczka',
#           False],
#  '1116': ['software engineer', 'Susan Daniels', False],
#  '1117': ['taxpayer service representative', 'Richard Neale', False],
#  '1118': ['real estate manager',
#           'Elaine Lavine',
#           ['11-9141',
#            'Property, Real Estate, and Community Association Managers',
#            'Real Estate Manager']],
#  '1119': ['landscaper', 'Justin Porter', False],
#  '112': ['research associate', 'Lisa Buckhout', False],
#  '1120': ['graduate student',
#           'Caren Chancey',
#           ['GradStu', 'Graduate student', 'Graduate student']],
#  '1121': ['editor and writer', 'Kent Rasmussen', False],
#  '1122': ['chief operations officer', 'Barbara Murray', False],
#  '1123': ['graduate student',
#           'Brendan Beier',
#           ['GradStu', 'Graduate student', 'Graduate student']],
#  '1124': ['freelance broadcast journalist', 'Helen Kaluzny', False],
#  '1125': ['writer', 'Mark Saltzman', False],
#  '1126': ['attorney', 'Tom Stimson', ['23-1011', 'Lawyers', 'Attorney']],
#  '1127': ['writer', 'Mike Clark', False],
#  '1128': ['teacher',
#           'Melissa Prepster',
#           ['25-MiscTeacher', 'Teacher', 'Teacher']],
#  '1129': ['physician', 'Ted Barnett', False],
#  '113': ['illustrations coordinator', 'Whitney Donaghy', False],
#  '1130': ['reporter and writer', 'Brad Williams', False],
#  '1131': ['history professor', 'Beth Andreasen', False],
#  '1132': ['lieutenant in the New York Police Department',
#           'Frank Spangenberg',
#           False],
#  '1133': ['lawyer with an international law firm', 'Rachael Schwartz', False],
#  '1134': ['author, comedian, and radio commentator', 'Bob Harris', False],
#  '1135': ['lawyer & financial analyst', 'Dan McBride', False],
#  '1136': ['graduate student',
#           'Steve Wang',
#           ['GradStu', 'Graduate student', 'Graduate student']],
#  '1137': ['librarian', 'Jo Ellen Eppink', False],
#  '1138': ['director of technical assistance', 'Eric Newhouse', False],
#  '1139': ['Spanish teacher',
#           'Leslie Frates',
#           ['25-MiscTeacher', 'Teacher', 'Teacher']],
#  '114': ['IT consultant', 'Philip Graves', False],
#  '1140': ['lawyer and CEO', 'Chuck Forrest', False],
#  '1141': ['film journalist and test prep teacher',
#           'Bob Verini',
#           ['25-MiscTeacher', 'Teacher', 'Teacher']],
#  '1142': ['sports reporter', 'Eddie Timanus', False],
#  '1143': ['manager of a research lab', 'Leslie Shannon', False],
#  '1144': ['from Yonkers, New York...', 'Andrew Vogl', False],
#  '1145': ['from Placentia, California...', 'Madeline Suchard', False],
#  '1146': ['from Centreville, Virginia...', 'Pranita Ramakrishnan', False],
#  '1147': ['audiologist',
#           'Maria Canavan',
#           ['29-1181', 'Audiologists', 'Audiologist']],
#  '1148': ["pathologist's assistant", 'Tisa Lawless', False],
#  '1149': ['from the Bronx, New York...', 'Dylan Smith', False],
#  '115': ['price protection manager', 'Sanda Kurtz', False],
#  '1150': ['from Derwood, Maryland...', 'Brady Newell', False],
#  '1151': ['from Montgomery, Texas...', 'Madison Ball', False],
#  '1152': ['history professor at Prairie View A&M University',
#           'Babu Srinivasan',
#           False],
#  '1153': ['actor and copy editor', 'India Cooper', False],
#  '1154': ['instructional designer', 'Robin Carroll', False],
#  '1155': ['attorney', 'Betty Fernandez', ['23-1011', 'Lawyers', 'Attorney']],
#  '1156': ['training specialist',
#           'Al Brokos',
#           ['13-1151',
#            'Training and Development Specialists',
#            'Training Specialist']],
#  '1157': ['from Escondido, California...', 'Matt Tick', False],
#  '1158': ['from Williamsville, New York...', 'Jon Er', False],
#  '1159': ['from West Chester, Pennsylvania...', 'Charlotte Darby', False],
#  '116': ['online high school teacher',
#          'Andrew Smith',
#          ['25-MiscTeacher', 'Teacher', 'Teacher']],
#  '1160': ['law librarian',
#           'Amy Comeau',
#           ['25-4021', 'Librarians', 'Law Librarian']],
#  '1161': ['professor of management', 'Chip Hunter', False],
#  '1162': ['from Madison, Wisconsin...', 'Mitchell Vogel', False],
#  '1163': ['from Tualatin, Oregon...', 'Hope Landsem', False],
#  '1164': ['from Avon, Connecticut...', 'Joseph Henares', False],
#  '1165': ['bank teller',
#           'John Fitzgibbon',
#           ['43-3071', 'Tellers', 'Bank Teller']],
#  '1166': ['high school teacher',
#           'Vince Mohan',
#           ['25-MiscTeacher', 'Teacher', 'Teacher']],
#  '1167': ['law librarian',
#           'Carol Reed',
#           ['25-4021', 'Librarians', 'Law Librarian']],
#  '1168': ['attorney', 'Rob Kalisch', ['23-1011', 'Lawyers', 'Attorney']],
#  '1169': ['from Indianapolis, Indiana...', 'Emily Zhang', False],
#  '117': ['physician', 'Kathi Fry', False],
#  '1170': ['from Roselle, Illinois...', 'Veronica Fazio', False],
#  '1171': ['from Irvine, California...', 'Aman Birk', False],
#  '1172': ['training specialist',
#           'Susan Goldsamt',
#           ['13-1151',
#            'Training and Development Specialists',
#            'Training Specialist']],
#  '1173': ['attorney', 'Glenn Jessee', ['23-1011', 'Lawyers', 'Attorney']],
#  '1174': ['elementary school principal',
#           'Barbara Walker',
#           ['11-9032',
#            'Education Administrators, Elementary and Secondary School',
#            'Elementary School Principal']],
#  '1175': ['office assistant',
#           'Paul Tavianini',
#           ['43-9061', 'Office Clerks, General', 'Office Assistant']],
#  '1176': ['writer', 'Stuart Nadler', False],
#  '1177': ['psychologist', 'Joel Silbert', False],
#  '1178': ['health care consultant', 'Luis Gutierrez', False],
#  '1179': ['private tutor', 'Kim Strassburger', False],
#  '118': ['theater director and stay-at-home dad', 'Rob Kimbro', False],
#  '1180': ['office clerk',
#           'Dominic Owen-Williams',
#           ['43-9061', 'Office Clerks, General', 'Office Clerk']],
#  '1181': ['underwriter', 'Dan Iacobazzi', False],
#  '1182': ['college instructor', 'Bill Dickenson', False],
#  '1183': ['attorney', 'Katie Miltich', ['23-1011', 'Lawyers', 'Attorney']],
#  '1184': ['communications consultant', "Steve O'Connor", False],
#  '1185': ['sixth grade teacher',
#           'Donna Christie',
#           ['25-MiscTeacher', 'Teacher', 'Teacher']],
#  '1186': ['part-time lawyer', 'Debby Herzberg Loomis', False],
#  '1187': ['waiter', 'Bob Johnson', False],
#  '1188': ['classical radio announcer', 'Lori Skelton', False],
#  '1189': ['attorney', 'Jack Ronner', ['23-1011', 'Lawyers', 'Attorney']],
#  '119': ['college student', 'David Hankins', False],
#  '1190': ['urban planning lawyer', 'Sandy Shapiro', False],
#  '1191': ['law student', 'Amanda Traphagan', False],
#  '1192': ['writer', 'Paulette Beete', False],
#  '1193': ['computer services administrator', 'Peter Williams', False],
#  '1194': ['sales clerk', 'Mary Lou Rodgers', False],
#  '1195': ['psychiatrist',
#           'John Thiel',
#           ['29-1066', 'Psychiatrists', 'Psychiatrist']],
#  '1196': ['math teacher',
#           'Mary Margaret Purvis',
#           ['25-MiscTeacher', 'Teacher', 'Teacher']],
#  '1197': ['athletic director', 'Murph Honea', False],
#  '1198': ['administrative assistant', "Claire O'Brien", False],
#  '1199': ['attorney', 'John Kelly', ['23-1011', 'Lawyers', 'Attorney']],
#  '12': ['biochemist',
#         'Bruce England',
#         ['19-1021', 'Biochemists and Biophysicists', 'Biochemist']],
#  '120': ['realtor', 'Nancy Zerg', False],
#  '1200': ['pastor', 'Diane Mettam', ['21-2011', 'Clergy', 'Pastor']],
#  '1201': ['loan consultant', 'Chris Jones', False],
#  '1202': ['graduate student',
#           'Michael Marion',
#           ['GradStu', 'Graduate student', 'Graduate student']],
#  '1203': ['art student', 'Robert Galvin', False],
#  '1204': ['teacher', 'Susan Klak', ['25-MiscTeacher', 'Teacher', 'Teacher']],
#  '1205': ['history teacher',
#           'Jeff Pandin',
#           ['25-MiscTeacher', 'Teacher', 'Teacher']],
#  '1206': ['library aide',
#           'Leigh Tomaszewski',
#           ['43-4121', 'Library Assistants, Clerical', 'Library Aide']],
#  '1207': ['scientist', 'David Bowen', False],
#  '1208': ['account manager', 'Jennifer Furlong', False],
#  '1209': ['actor and improviser', 'Joey Bland', False],
#  '121': ['wealth management project analyst', 'Katie Fitzgerald', False],
#  '1210': ['asset manager', 'Tim Lorch', False],
#  '1211': ['editor', 'Curtis Scott', False],
#  '1212': ['procurement manager',
#           'Gay Mollette',
#           ['11-3061', 'Purchasing Managers', 'Procurement Manager']],
#  '1213':
# ['environmental specialist', 'Laura Henne', False],
#  '1214': ['songwriter, vocalist, and graduate student',
#           'Alaric Smith',
#           ['GradStu', 'Graduate student', 'Graduate student']],
#  '1215': ['insurance executive', 'Sally Donovan', False],
#  '1216': ['attorney', 'Glenn Salzman', ['23-1011', 'Lawyers', 'Attorney']],
#  '1217': ['aspiring writer', 'Donna Craig', False],
#  '1218': ['horse shoer', 'Clark Adams', False],
#  '1219': ['radio broadcast producer', 'Steve Ostini', False],
#  '122': ['research assistant', 'Nathan Brownback', False],
#  '1220': ['teacher',
#           'Maria Wenglinsky',
#           ['25-MiscTeacher', 'Teacher', 'Teacher']],
#  '1221': ['research scientist', 'Rosemary Foster', False],
#  '1222': ['Army captain', 'Wade Markel', False],
#  '1223': ['attorney', 'Philip Huang', ['23-1011', 'Lawyers', 'Attorney']],
#  '1224': ['tech advisor', 'Jeremy Evans', False],
#  '1225': ['newspaper reporter', 'Brad Smith', False],
#  '1226': ['office manager', 'Cynthia Edmunds', False],
#  '1227': ['creative marketing consultant', "Leslie Burns-Dell'Acqua", False],
#  '1228': ['television producer',
#           'David Braxton',
#           ['27-2012', 'Producers and Directors', 'Television Producer']],
#  '1229': ['physician', 'Jeff Punim', False],
#  '123': ['homeland security consultant', 'Josh Kolchins', False],
#  '1230': ['accountant',
#           'Sheila Austin',
#           ['13-2011', 'Accountants and Auditors', 'Accountant']],
#  '1231': ['student and freelance bartender', 'Kingslea Bueltel', False],
#  '1232': ['printing salesman', 'Jim Gilcreast', False],
#  '1233': ['editor', 'Kari Russ', False],
#  '1234': ['psychotherapist',
#           'Shelley Fellner-Rosenberg',
#           ['19-3039', 'Psychologists, All Other', 'Psychotherapist']],
#  '1235': ['economist & software engineer', 'Stephen Gorin', False],
#  '1236': ['writer', 'Sandy Siegel', False],
#  '1237': ['homemaker', 'Jere Souza', False],
#  '1238': ['retail manager', 'Pat Gonzales', False],
#  '1239': ['sophomore at Purdue University', 'Antonia Wang', False],
#  '124': ['planning clerk', 'Sherri Benoun', False],
#  '1240': ['junior at Boston University', 'Beth Cimini', False],
#  '1241': ['sophomore at the University of North Carolina at Chapel Hill',
#           'Christopher Chilton',
#           False],
#  '1242': ['junior at the University of Maryland', 'Alison Jenik', False],
#  '1243': ['junior at Washington University in St. Louis',
#           'Jayanth Iyengar',
#           False],
#  '1244': ['senior at North Carolina Central University',
#           'Malisha Butts',
#           False],
#  '1245': ['substitute teacher & carpenter',
#           'Andy Jackson',
#           ['25-MiscTeacher', 'Teacher', 'Teacher']],
#  '1246': ['railroad conductor', 'Gene Ballesty', False],
#  '1247': ['junior at Gonzaga University', 'Amanda Walker', False],
#  '1248': ['sophomore at New York University', 'Ben Goldman', False],
#  '1249': ['senior at North Carolina State University', 'Peter Ellis', False],
#  '125': ['truck driver', 'Kord Heinemann', False],
#  '1250': ['textbook editor', 'Melissa Littman', False],
#  '1251': ['teacher',
#           'Peter Nielsen',
#           ['25-MiscTeacher', 'Teacher', 'Teacher']],
#  '1252': ['senior at the University of Alabama at Birmingham',
#           'Adam Pinson',
#           False],
#  '1253': ['sophomore at Duke University', 'Chelsea He', False],
#  '1254': ['sophomore at Princeton University', 'Chris Breen', False],
#  '1255': ['teacher and writer',
#           'Ronny Kaye',
#           ['25-MiscTeacher', 'Teacher', 'Teacher']],
#  '1256': ['technology & operations manager', 'Myretta Robens', False],
#  '1257': ['junior at Stanford University', 'Nico Martinez', False],
#  '1258': ['senior at the University of Rochester', 'Colin Brown', False],
#  '1259': ['junior at the University of Michigan at Dearborn',
#           'Anna Allie',
#           False],
#  '126': ['anesthesiologist',
#          'Pete DeBalli',
#          ['29-1061', 'Anesthesiologists', 'Anesthesiologist']],
#  '1260': ['writer', 'Lucy Shigemitsu', False],
#  '1261': ['physician', 'Irv Kaplan', False],
#  '1262': ['computer consultant', 'Tom Meenan', False],
#  '1263': ['attorney', 'Marina Matuzek', ['23-1011', 'Lawyers', 'Attorney']],
#  '1264': ['attorney', 'Barbara Jackson', ['23-1011', 'Lawyers', 'Attorney']],
#  '1265': ['journalist', 'Charlie Patton', False],
#  '1266': ['college student', 'Chris Sroka', False],
#  '1267': ['veterinarian', "Amy O'Brien", False],
#  '1268': ['attorney', 'Jon Woodman', ['23-1011', 'Lawyers', 'Attorney']],
#  '1269': ['grad student and substitute teacher',
#           'Dee Weber',
#           ['25-MiscTeacher', 'Teacher', 'Teacher']],
#  '127': ['graduate student',
#          'Andy Zimdars',
#          ['GradStu', 'Graduate student', 'Graduate student']],
#  '1270': ['production assistant', 'Harmony Jones', False],
#  '1271': ['attorney and educator', 'Pat Pauken', False],
#  '1272': ['medical resident', 'Chris Weltz', False],
#  '1273': ['recording engineer',
#           'Leo Gillis',
#           ['27-4014', 'Sound Engineering Technicians', 'Recording Engineer']],
#  '1274': ['multimedia consultant', 'Kecia Lynn', False],
#  '1275': ['college student', 'Mark Torma', False],
#  '1276': ['attorney', 'Ruth Thompson', ['23-1011', 'Lawyers', 'Attorney']],
#  '1277': ['computer scientist',
#           'Ted Senator',
#           ['15-1111',
#            'Computer and Information Research Scientists',
#            'Computer Scientist']],
#  '1278': ['college academic specialist', "Sara d'Anjou", False],
#  '1279': ['accelerator operator', 'Jeff Cuffee', False],
#  '128': ['engineer', 'Dennis Grace', False],
#  '1280': ['graduate student',
#           'Michael Cramer',
#           ['GradStu', 'Graduate student', 'Graduate student']],
#  '1281': ['writer', 'Mario Zaragoza', False],
#  '1282': ['community college professor', 'Cindy Giddle', False],
#  '1283': ['engineer', 'Jody Hart', False],
#  '1284': ['pop music critic', 'Claudia Perry', False],
#  '1285': ['attorney', 'Bill MacDonald', ['23-1011', 'Lawyers', 'Attorney']],
#  '1286': ['communications consultant', 'Jeanne McDougall', False],
#  '1287': ['industrial designer', 'Kurt Bodden', False],
#  '1288': ['medical administrator', 'Nancy Senter', False],
#  '1289': ['high school director', 'Scott Zimmerman', False],
#  '129': ['house painter',
#          'Shelley Singh',
#          ['47-2141',
#           'Painters, Construction and Maintenance',
#           'House Painter']],
#  '1290': ['Ph.D. student', 'Beth Chalecki', False],
#  '1291': ['stamp dealer', 'Marvin Shinkman', False],
#  '1292': ['law student', 'Chuck Forrest', False],
#  '1293': ['actor', 'Paul Rouffa', False],
#  '1294': ['database administrator', 'Wendy Stancer', False],
#  '1295': ['investment specialist', 'Ben Davis', False],
#  '1296': ['technical writer',
#           'Aimee Serafini',
#           ['27-3042', 'Technical Writers', 'Technical Writer']],
#  '1297': ['physician', 'Damon Raskin', False],
#  '1298': ['reference assistant', 'Pat Godwin', False],
#  '1299': ['attorney', 'Robert J. Lee', ['23-1011', 'Lawyers', 'Attorney']],
#  '13': ['writer and editor', 'Dana Dolan', False],
#  '130': ['library assistant',
#          'Jackie Cipa',
#          ['43-4121', 'Library Assistants, Clerical', 'Library Assistant']],
#  '1300': ['civil servant', 'Jack Patton', False],
#  '1301': ['director of information services', 'Doug Morrison', False],
#  '1302': ['college student', 'David Charlton, Jr.', False],
#  '1303': ['book editor', 'Steve Dhuey', ['27-3041', 'Editors', 'Book Editor']],
#  '1304': ['physician', 'Alan Kwaselow', False],
#  '1305': ['library assistant',
#           'Kathy Eckenroth',
#           ['43-4121', 'Library Assistants, Clerical', 'Library Assistant']],
#  '1306': ['medical student', 'Vik Vaz', False],
#  '1307': ['homemaker', 'Beth Doner', False],
#  '1308': ['attorney', 'Scott Miskimon', ['23-1011', 'Lawyers', 'Attorney']],
#  '1309': ['product developer & designer', 'Marlene Reiss', False],
#  '131': ['environmental policy specialist', 'Megan Susman', False],
#  '1310': ['history instructor', 'Mita Choudhury', False],
#  '1311': ['used bookstore owner', 'Peter Dent', False],
#  '1312': ['writer', 'Deena Banks', False],
#  '1313': ['emergency medical technician', 'Kelly Croissant', False],
#  '1314': ['assistant director', 'Julie Johnson', False],
#  '1315': ['college student', 'Doug Fitch', False],
#  '1316': ['student', 'Liz Lackey', False],
#  '1317': ['marketing communications consultant', 'Josh Danson', False],
#  '1318': ['personal trainer',
#           'Chris Kahn',
#           ['39-9031',
#            'Fitness Trainers and Aerobics Instructors',
#            'Personal Trainer']],
#  '1319': ['librarian assistant', 'Heidi Shultz', False],
#  '132': ['law student', 'Alex Bready', False],
#  '1320': ['graduate student',
#           'Adam Weinstein',
#           ['GradStu', 'Graduate student', 'Graduate student']],
#  '1321': ['proposal writer', 'Jenn Carlson', False],
#  '1322': ['office assistant',
#           'Bruce Bullock',
#           ['43-9061', 'Office Clerks, General', 'Office Assistant']],
#  '1323': ['editor', 'Pam Wilson', False],
#  '1324': ['aerospace systems engineer', 'Leo Jones', False],
#  '1325': ['law student', 'Kevin Jack', False],
#  '1326': ['research analyst', 'Breck Jeffery', False],
#  '1327': ['payroll specialist', 'Glenda Niemiec', False],
#  '1328': ['attorney', 'Michael Levitin', ['23-1011', 'Lawyers', 'Attorney']],
#  '1329': ['attorney and doctoral candidate', 'Pat Pauken', False],
#  '133': ['law student', 'Tom McCudden', False],
#  '1330': ['homemaker', 'Jennifer Wadsack', False],
#  '1331': ['school psychologist',
#           'Vicky Stanton',
#           ['19-3031',
#            'Clinical, Counseling, and School Psychologists',
#            'School Psychologist']],
#  '1332': ['program manager', 'Todd Roshak', False],
#  '1333': ['law enforcement analyst', 'Nina Ostrovitz', False],
#  '1334': ['graduate student & college English teacher',
#           'Tim Rosendale',
#           ['GradStu', 'Graduate student', 'Graduate student']],
#  '1335': ['trademark consultant', 'Marianna Johnson', False],
#  '1336': ['poker player and dog walker', 'Charles Bagot', False],
#  '1337': ['chemistry teacher',
#           'Pat Ostenburg',
#           ['25-MiscTeacher', 'Teacher', 'Teacher']],
#  '1338': ['satellite news producer', 'Chad Curtis', False],
#  '1339': ['freelance editor and proofreader', 'Laura Glassman', False],
#  '134': ['teacher',
#          'Karen Lafferty',
#          ['25-MiscTeacher', 'Teacher', 'Teacher']],
#  '1340': ['investigator', 'Bob Combs', False],
#  '1341': ['tax auditor', 'Mauricio Rivero', False],
#  '1342': ['sportswriter', 'James Quintong', False],
#  '1343': ['flight attendant', 'Christi Beard', False],
#  '1344': ['freelance editor and writer', 'Amy Loerch Strumolo', False],
#  '1345': ['real estate broker',
#           'Fred Walker',
#           ['41-9021', 'Real Estate Brokers', 'Real Estate Broker']],
#  '1346': ['communications coach', 'LeeAundra Temescu', False],
#  '1347': ['law student', 'Michael Salerno', False],
#  '1348': ["teacher's aide",
#           'Davia Worthen',
#           ['25-MiscTeacher', 'Teacher', 'Teacher']],
#  '1349': ['Ph.D. student', 'Randy Cohen', False],
#  '135': ['stay-at-home mom', 'Colette Moran', False],
#  '1350': ["children's encyclopedia editor", 'Elaine Henderson', False],
#  '1351': ['mom and assistant editor', 'Beth Klein', False],
#  '1352': ['English professor', 'Chris Borglum', False],
#  '1353': ['junior', 'Alex Rubalcava', False],
#  '1354': ['senior', "Tanis O'Connor", False],
#  '1355': ['junior', 'Josh Den Hartog', False],
#  '1356': ['college professor', 'Bryn Upton', False],
#  '1357': ['manager', 'Rich Way', False],
#  '1358': ['junior', 'Brandon Frantz', False],
#  '1359': ['junior', 'Pooja Dhume', False],
#  '136': ['software engineer', 'Robert Bowsher', False],
#  '1360': ['senior', 'Chad Bell', False],
#  '1361': ['junior', 'Faith Hillis', False],
#  '1362': ['junior', 'Audrey Droesch', False],
#  '1363': ['freshman', 'Matthew Burgess', False],
#  '1364': ['English teacher',
#           'Erin McGurgan',
#           ['25-MiscTeacher', 'Teacher', 'Teacher']],
#  '1365': ['hotel employee', 'Bill Crowley', False],
#  '1366': ['writer', 'James Reeves', False],
#  '1367': ['business writer', 'Amy Johnson', False],
#  '1368': ['sophomore', 'Rita Hamad', False],
#  '1369': ['junior', 'Akiva Fox', False],
#  '137': ['playwright',
#          'David Davalos',
#          ['27-3043', 'Writers and Authors', 'Playwright']],
#  '1370': ['junior', 'Sharon Druck', False],
#  '1371': ['junior', 'Justin Powell', False],
#  '1372': ['senior', 'Brian Joseph', False],
#  '1373': ['junior', 'Fran Bigman', False],
#  '1374': ['retired dentist', 'Mark Levin', False],
#  '1375': ['homemaker', 'Kathy Reiff', False],
#  '1376': ['law school graduate', 'Maria Kokiasmenos', False],
#  '1377': ['nonprofit director', 'Tim Ifill', False],
#  '1378': ['librarian', 'Laura McElfresh', False],
#  '1379': ['teacher',
#           "Brendan O'Connor",
#           ['25-MiscTeacher', 'Teacher', 'Teacher']],
#  '138': ['writer', 'Snow Tempest', False],
#  '1380': ['chemist', 'Rob Klepadlo', False],
#  '1381': ['high school guidance counselor', 'Debbie Chuba', False],
#  '1382': ['limousine driver',
#           'Jeff Lawrence',
#           ['53-3041', 'Taxi Drivers and Chauffeurs', 'Limousine Driver']],
#  '1383': ['high school teacher',
#           'Karen Spinale',
#           ['25-MiscTeacher', 'Teacher', 'Teacher']],
#  '1384': ['investigator and lawyer', 'Lisa Loiselle', False],
#  '1385': ['student', 'Josh Yost', False],
#  '1386': ['journalist', 'Peter Rubin', False],
#  '1387': ['police officer', 'Barbara Noyes', False],
#  '1388': ['student & writer', 'Erik Cansler', False],
#  '1389': ['writer & editor', 'Julie Connery', False],
#  '139': ['political science professor', 'Jerry Mayer', False],
#  '1390': ['humanities lecturer & artist', 'Claudia Traudt', False],
#  '1391': ['retired letter carrier', 'Michael Grinde', False],
#  '1392': ['aerospace engineer',
#           'Bob McDonald',
#           ['17-2011', 'Aerospace Engineers', 'Aerospace Engineer']],
#  '1393': ['writer', 'Julie Reynolds', False],
#  '1394': ['professor of accounting', 'Joan Friedman', False],
#  '1395': ['pediatric oncologist', 'Jim Fahner', False],
#  '1396': ['customer service manager', 'Greg Carbone', False],
#  '1397': ['mail carrier', 'Sharon Dorsey', False],
#  '1398': ['learning consultant', 'Rex Babiera', False],
#  '1399': ['crash avoidance engineer', 'Mark Mironer', False],
#  '14': ['real estate manager and actor', 'Robert Quinn', False],
#  '140': ['physician', 'Joel Kahn', False],
#  '1400': ['stamp dealer', 'Tina Carlson', False],
#  '1401': ['training and educational design specialist', 'Kevin Gomes', False],
#  '1402': ['educational director', 'Leslie Hickey', False],
#  '1403': ['graduate student instructor',
#           'Amit Ray',
#           ['GradStu', 'Graduate student', 'Graduate student']],
#  '1404': ['homemaker', 'Nancy Splane', False],
#  '1405': ['political consultant',
#           'Keara Depenbrock',
#           ['19-3094', 'Political Scientists', 'Political Consultant']],
#  '1406': ['writer', 'Tom Kavanaugh', False],
#  '1407': ['marketing manager and grad student', 'Lauren Dean', False],
#  '1408': ['registered nurse',
#           'Robert Bethard',
#           ['29-1141', 'Registered Nurses', 'Registered Nurse']],
#  '1409': ['downsize accountant', "Martha O'Malley", False],
#  '141': ['systems engineer', 'Maureen McKay', False],
#  '1410': ['part-time consultant', 'Laurent Ruseckas', False],
#  '1411': ['bookseller', 'Kathie Hoagland', False],
#  '1412': ['university professor', 'Greg Mayer', False],
#  '1413': ['law student', 'Jamie Hodari', False],
#  '1414': ['manager', 'Joan Tosh', False],
#  '1415': ['writer', 'Leslie Birdwell', False],
#  '1416': ['substitute teacher',
#           'James Calhoun',
#           ['25-MiscTeacher', 'Teacher', 'Teacher']],
#  '1417': ['legal editor', 'Jim Diggins', False],
#  '1418': ['association coordinator', 'Steven Lane', False],
#  '1419': ['physician', 'Timothy Hsieh', False],
#  '142': ['graduate student',
#          'Ethan de Seife',
#          ['GradStu', 'Graduate student', 'Graduate student']],
#  '1420': ['writer & consultant', 'Jenna Jackson', False],
#  '1421': ['financial consultant', 'Andy Gefen', False],
#  '1422': ['automotive engineer', 'Jim Burkhard', False],
#  '1423': ['physics student', 'Michael Thayer', False],
#  '1424': ['attorney', 'Dan Katz', ['23-1011', 'Lawyers', 'Attorney']],
#  '1425': ['actuary', 'Bob Blake', False],
#  '1426': ['school board member', 'Jeff Horton', False],
#  '1427': ['graduate student',
#           'Jude Theriot',
#           ['GradStu', 'Graduate student', 'Graduate student']],
#  '1428': ['translation coordinator', 'Stephanie Lutz', False],
#  '1429': ['musician',
#           'Craig Smith',
#           ['27-2042', 'Musicians and Singers', 'Musician']],
#  '143': ['trucking subcontractor', 'Cliff Kowalczyk', False],
#  '1430': ['attorney', 'Jim Selth', ['23-1011', 'Lawyers', 'Attorney']],
#  '1431': ['homemaker', 'Linda Slyer', False],
#  '1432': ['attorney', 'Joseph Willis', ['23-1011', 'Lawyers', 'Attorney']],
#  '1433': ['stay-at-home mom', 'Eve Bjork', False],
#  '1434': ['actor and musician', 'Vartan Merjanian', False],
#  '1435': ['substitute teacher',
#           'Pablo del Real',
#           ['25-MiscTeacher', 'Teacher', 'Teacher']],
#  '1436': ['computer trainer', 'Pam Mifflin', False],
#  '1437': ['correction officer',
#           'Carl Bryant',
#           ['33-3012',
#            'Correctional Officers and Jailers',
#            'Correction Officer']],
#  '1438': ["children's librarian",
#           'Margaret Walsh',
#           ['25-4021', 'Librarians', "Children's Librarian"]],
#  '1439': ['international security consultant', 'John Carroll', False],
#  '144': ['legal assistant',
#          'Grayson Holmes',
#          ['23-2011', 'Paralegals and Legal Assistants', 'Legal Assistant']],
#  '1440': ['accountant',
#           'Lisa Doak',
#           ['13-2011', 'Accountants and Auditors', 'Accountant']],
#  '1441': ['caregiver', 'Carolyn Proulx', False],
#  '1442': ['pharmacist', 'Marty Miller', False],
#  '1443': ['substitute teacher',
#           'Deb Abbey',
#           ['25-MiscTeacher', 'Teacher', 'Teacher']],
#  '1444': ['supervising deputy probation officer', 'Constance Swinger', False],
#  '1445': ['student', 'Kevin Marshall', False],
#  '1446': ['art director',
#           'Robert Van Newkirk',
#           ['27-1011', 'Art Directors', 'Art Director']],
#  '1447': ['writer', 'Kathy Petras', False],
#  '1448': ['accounts receivable manager', 'Bryan Adams', False],
#  '1449': ['waitress', 'Mary Keefe', False],
#  '145': ['retail manager', 'Harry Sering', False],
#  '1450': ['law student', 'Jon Bourgault', False],
#  '1451': ['teacher',
#           'Wendy Middleton',
#           ['25-MiscTeacher', 'Teacher', 'Teacher']],
#  '1452': ['teacher', 'George Soule', ['25-MiscTeacher', 'Teacher', 'Teacher']],
#  '1453': ['physician', 'Elaine Zollner', False],
#  '1454': ['foreign service officer', 'Eric Terzuolo', False],
#  '1455': ['computer programming student', 'Bob Willoughby', False],
#  '1456': ['film editor',
#           'Ann Jackman',
#           ['27-4032', 'Film and Video Editors', 'Film Editor']],
#  '1457': ['grad student', 'Jesse Liu', False],
#  '1458': ['editor', 'Kerri Griffith', False],
#  '1459': ['homemaker', 'Lisa Guay', False],
#  '146': ['library technician and stage manager', 'Jennifer West', False],
#  '1460': ['graduate student',
#           'Erik Larsen',
#           ['GradStu', 'Graduate student', 'Graduate student']],
#  '1461': ["taxpayers' service representative", 'Richard Neale', False],
#  '1462': ['government worker', 'Roxanne Smith', False],
#  '1463': ['newspaper district manager', 'Phil Turnbull', False],
#  '1464': ['stay-at-home mom', 'Michelle Hickman', False],
#  '1465': ['freelance communications business consultant',
#           'David Grant',
#           False],
#  '1466': ['writer', 'Andrew Bernknopf', False],
#  '1467': ['film executive', 'Steve Berman', False],
#  '1468': ['police officer', 'Frank Spangenberg', False],
#  '1469': ['foreign service officer', 'Abby Aronson', False],
#  '147': ['college professor', 'Lyle Brenner', False],
#  '1470': ['management consultant',
#           'Mushtaq Kapasi',
#           ['13-1111', 'Management Analysts', 'Management Consultant']],
#  '1471': ['home-sale account executive', 'Bill Hart', False],
#  '1472': ['personal trust officer', 'Mark Brennan', False],
#  '1473': ['marketing consultant',
#           'Ellen Simmons',
#           ['13-1161',
#            'Market Research Analysts and Marketing Specialists',
#            'Marketing Consultant']],
#  '1474': ['editor and writer', 'Stephen Heuser', False],
#  '1475': ['administrative assistant', 'Macee Damon', False],
#  '1476': ['history teacher',
#           'Rich Canedo',
#           ['25-MiscTeacher', 'Teacher', 'Teacher']],
#  '1477': ['attorney', 'Chris Casper', ['23-1011', 'Lawyers', 'Attorney']],
#  '1478': ['HR consultant', 'Merle Capello', False],
#  '1479': ['graduate student',
#           'Peter Higgins',
#           ['GradStu', 'Graduate student', 'Graduate student']],
#  '148': ['retired programmer', 'Michael Kalk', False],
#  '1480': ['retailer & importer', 'Jennifer Tobias-Turner', False],
#  '1481': ['travel agent',
#           'Emily Short',
#           ['41-3041', 'Travel Agents', 'Travel Agent']],
#  '1482':
# ['support center analyst', 'Brian Poole', False],
#  '1483': ['state filings analyst', 'John Nauss', False],
#  '1484': ['graduate student',
#           'Lisa McLendon',
#           ['GradStu', 'Graduate student', 'Graduate student']],
#  '1485': ["high school senior and winner of last year's Teen Tournament",
#           'Jamie Weiss',
#           False],
#  '1486': ['conservationist', 'Girish Bhat', False],
#  '1487': ['professor', 'Sheri Gravett', False],
#  '1488': ['caterer', 'John Stratford', False],
#  '1489': ['transcriber', 'Amanda Pompili', False],
#  '149': ['attorney', 'Emily Lawrence', ['23-1011', 'Lawyers', 'Attorney']],
#  '1490': ['decorating contractor', 'Bob Aumann', False],
#  '1491': ['dentist', 'Jeff Frankel', False],
#  '1492': ['Ph.D. candidate', 'Mickie Grover', False],
#  '1493': ['computer analyst', 'Larry McKnight', False],
#  '1494': ['administrative assistant', 'Mindy Eakin', False],
#  '1495': ['reservation sales representative', 'Fritz Gray', False],
#  '1496': ['substitute teacher and library clerk',
#           'Jeanne Perrier',
#           ['25-MiscTeacher', 'Teacher', 'Teacher']],
#  '1497': ['technical instructor', 'Rick Hoffman', False],
#  '1498': ['attorney', 'Jeff Bandman', ['23-1011', 'Lawyers', 'Attorney']],
#  '1499': ['psychotherapist & writer', 'Mark Hein', False],
#  '15': ['reporter', 'Kate Duffy', False],
#  '150': ['professor', 'Dale Masel', False],
#  '1500': ['university lecturer', 'Evan Fletcher', False],
#  '1501': ['software engineer', 'Marcus Jackson', False],
#  '1502': ['coffee shop manager and trainer', 'Lisa Peabody', False],
#  '1503': ['computer programmer & writer', 'John Kiernan', False],
#  '1504': ['voice teacher & accountant',
#           'Lee Morgan',
#           ['25-MiscTeacher', 'Teacher', 'Teacher']],
#  '1505': ['congressional staff member', 'Scott Kearin', False],
#  '1506': ['economics professor', 'Jeff Holt', False],
#  '1507': ['information developer', 'Laurie Kittle', False],
#  '1508': ['farmer', 'Chris Szymanski', False],
#  '1509': ['advertising sales representative', 'Mark Le Menager', False],
#  '151': ['student', 'David Camp', False],
#  '1510': ['graduate student',
#           'Brian Nafziger',
#           ['GradStu', 'Graduate student', 'Graduate student']],
#  '1511': ['index editor',
#           'Joy Luckabaugh',
#           ['27-3041', 'Editors', 'Index Editor']],
#  '1512': ['arts administrator', 'Bob Mesko', False],
#  '1513': ['curatorial assistant', 'Cynthia Pearson', False],
#  '1514': ['grad student', 'Nick Klaiber', False],
#  '1515': ['stay-at-home mom and online college professor',
#           'Wendy Kautz',
#           False],
#  '1516': ['Army officer', 'Peter Booker', False],
#  '1517': ['medical assistant', 'Margaret Mitchell', False],
#  '1518': ['training consultant', 'Lynda Pinnington', False],
#  '1519': ['Airborne infantry man', 'Roger Antaki', False],
#  '152': ['engineer', 'Hugh Price', False],
#  '1520': ['college teacher',
#           'Jonathan Brosin',
#           ['25-MiscTeacher', 'Teacher', 'Teacher']],
#  '1521': ['actor', 'Alex Oleksij', False],
#  '1522': ['nonprofit development director', 'Glenn Barnes', False],
#  '1523': ['copy editor',
#           'Miranda Schwartz',
#           ['27-3041', 'Editors', 'Copy Editor']],
#  '1524': ['"Mr. Mom"', 'Paul Slota', False],
#  '1525': ['finance manager', 'Cris Molles', False],
#  '1526': ['homemaker', 'Paul Canty', False],
#  '1527': ['federal IT specialist', 'Candy Murphy', False],
#  '1528': ['attorney', 'Andrew Lueder', ['23-1011', 'Lawyers', 'Attorney']],
#  '1529': ['homemaker', 'Ellen Kolb', False],
#  '153': ['lawyer', 'Andrew Locke', ['23-1011', 'Lawyers', 'Lawyer']],
#  '1530': ['deputy attorney general',
#           'Jim Cordi',
#           ['23-1011', 'Lawyers', 'Deputy Attorney General']],
#  '1531': ['businessman', 'Kevin McDermott', False],
#  '1532': ['waiter and writer', 'Kim Worth', False],
#  '1533': ['housewife', 'Lisa Newman', False],
#  '1534': ['teacher', 'Sarah Altier', ['25-MiscTeacher', 'Teacher', 'Teacher']],
#  '1535': ['brick manufacturer', 'William Love', False],
#  '1536': ['medical student', 'Eleanor Ainslie', False],
#  '1537': ['talk radio show host', 'John Moore', False],
#  '1538': ['electronics engineer', 'James Oldham', False],
#  '1539': ['library selection specialist', 'Natalia Mayer', False],
#  '154': ['public relations executive', 'Elaine Lang', False],
#  '1540': ['law student', 'Gerard Magliocca', False],
#  '1541': ['systems analyst', 'Linda Desmond', False],
#  '1542': ['attorney', 'Joanna Stromberg', ['23-1011', 'Lawyers', 'Attorney']],
#  '1543': ['travel marketer', 'Dave Halliday', False],
#  '1544': ['video buyer', 'David Achar', False],
#  '1545': ['housewife', 'Susan Lee', False],
#  '1546': ['teacher',
#           'Tawney Pearson',
#           ['25-MiscTeacher', 'Teacher', 'Teacher']],
#  '1547': ['accountant',
#           'Brick Barrientos',
#           ['13-2011', 'Accountants and Auditors', 'Accountant']],
#  '1548': ['attorney', 'Ken Rosenau', ['23-1011', 'Lawyers', 'Attorney']],
#  '1549': ['consultant', 'Jared Poppel', False],
#  '155': ['homemaker', 'Janine Menhennet', False],
#  '1550': ['college instructor', 'Jennifer Kelly', False],
#  '1551': ['American studies teacher',
#           'Barb Fuson',
#           ['25-MiscTeacher', 'Teacher', 'Teacher']],
#  '1552': ['math teacher',
#           'Peter Braxton',
#           ['25-MiscTeacher', 'Teacher', 'Teacher']],
#  '1553': ['lawyer', 'Debbie Beers', ['23-1011', 'Lawyers', 'Lawyer']],
#  '1554': ['chemist', 'Chris Morse', False],
#  '1555': ['analyst', 'Katie De Pitts', False],
#  '1556': ['writer', 'Jerome Vered', False],
#  '1557': ['advertising executive',
#           'Don Westrich',
#           ['11-2011',
#            'Advertising and Promotions Managers',
#            'Advertising Executive']],
#  '1558': ['civil engineering technician',
#           'Susan Kornblum',
#           ['17-3022',
#            'Civil Engineering Technicians',
#            'Civil Engineering Technician']],
#  '1559': ['engineer', 'Dennis DiNucci', False],
#  '156': ['homemaker', 'Nancy Moeller', False],
#  '1560': ['senior', 'Loren Loiacono', False],
#  '1561': ['senior', 'Andrew Kreitz', False],
#  '1562': ['senior', 'Sebastian Johnson', False],
#  '1563': ['medical & law student', 'Fazal Khan', False],
#  '1564': ['attorney', 'David Smith', ['23-1011', 'Lawyers', 'Attorney']],
#  '1565': ['senior', 'Lauren Romero', False],
#  '1566': ['senior', 'Matt Klein', False],
#  '1567': ['sophomore', 'Katie James', False],
#  '1568': ['public affairs director',
#           'Dan Dean',
#           ['11-2031',
#            'Public Relations and Fundraising Managers',
#            'Public Affairs Director']],
#  '1569': ['communications manager', 'Diane Tabbott', False],
#  '157': ['fashion editor', 'Brent Winter', False],
#  '1570': ['junior', 'Iddoshe Hirpa', False],
#  '1571': ['junior', 'Joseph Graumann', False],
#  '1572': ['senior', 'Camille Bullock', False],
#  '1573': ['student', 'Patrick Brannon', False],
#  '1574': ['reporter', 'Deborah Yaffe', False],
#  '1575': ['law student', 'Al Lin', False],
#  '1576': ['writer', 'Richard Dargan', False],
#  '1577': ['paralegal',
#           'Kim Simkins',
#           ['23-2011', 'Paralegals and Legal Assistants', 'Paralegal']],
#  '1578': ['junior', 'Kenny Schlax', False],
#  '1579': ['junior', 'Allison Pe\xf1a', False],
#  '158': ['tutor',
#          'Jessica Ayers',
#          ['25-3099', 'Teachers and Instructors, All Other', 'Tutor']],
#  '1580': ['sophomore', 'Papa Chakravarthy', False],
#  '1581': ['cooking writer', 'Steve Muni', False],
#  '1582': ['waiter', 'Jeff Pilgreen', False],
#  '1583': ['junior', 'Andrew Watkins', False],
#  '1584': ['senior', 'David Hoffelmeyer', False],
#  '1585': ['senior', 'Laura Ansley', False],
#  '1586': ['medical writer and editor', 'Nancy Baron', False],
#  '1587': ['attorney', 'Peter Fiske', ['23-1011', 'Lawyers', 'Attorney']],
#  '1588': ['law student', 'Greg Chernack', False],
#  '1589': ['editor', 'Penny Willis', False],
#  '159': ['journalist', 'Eric Berman', False],
#  '1590': ['technical writer',
#           'Kim Haase',
#           ['27-3042', 'Technical Writers', 'Technical Writer']],
#  '1591': ['attorney', 'Diane Mirabito', ['23-1011', 'Lawyers', 'Attorney']],
#  '1592': ['designer', 'Phil Duffy', False],
#  '1593': ['attorney', 'Jeff Barlow', ['23-1011', 'Lawyers', 'Attorney']],
#  '1594': ['independent graphic designer', 'Emily Scott', False],
#  '1595': ['scientist', 'Chris Moylan', False],
#  '1596': ['biochemist',
#           'Rick Rodgers',
#           ['19-1021', 'Biochemists and Biophysicists', 'Biochemist']],
#  '1597': ['attorney', 'Pete Kearns', ['23-1011', 'Lawyers', 'Attorney']],
#  '1598': ['lobbyist',
#           'Jim Melberg',
#           ['27-3031', 'Public Relations Specialists', 'Lobbyist']],
#  '1599': ['claims representative', 'Brad Miliauskas', False],
#  '16': ['consulting program manager', 'David Fishbach', False],
#  '160': ['writer', 'John Podhoretz', False],
#  '1600': ['sophomore', 'John van DeWeert', False],
#  '1601': ['sophomore', 'Eric Biber', False],
#  '1602': ['junior', 'Phoebe Juel', False],
# ...
#  '8999': ['chemical engineer consulting in renewable energy',
#           'Vijay Balse',
#           False],
#  '9': ['writer', 'Amy Helmes', False],
#  '90': ['college student', 'Leo Wolpert', False],
#  '900': ['educator', 'Audrey Golub', False],
#  '9000': ['writer', 'Tom Nissley', False],
#  '9001': ['manager of corporate and foundation relations at a music school',
#           'Celeste DiNucci',
#           False],
#  '9002': ['AP world history teacher',
#           'Colby Burnett',
#           ['25-MiscTeacher', 'Teacher', 'Teacher']],
#  '9003': ['university professor', 'Russ Schumacher', False],
#  '9004': ['editor for academic competitions', 'Larissa Kelly', False],
#  '9005': ['personal trainer, filmmaker, and singer', 'Tom Kavanaugh', False],
#  '9006': ['research chemist', 'Keith Whitener', False],
#  '9007': ['teacher',
#           'Maria Wenglinsky',
#           ['25-MiscTeacher', 'Teacher', 'Teacher']],
#  '9008': ['global health consultant', 'Dan Pawson', False],
#  '9009': ['attorney',
#           'Vinita Kailasanath',
#           ['23-1011', 'Lawyers', 'Attorney']],
#  '901': ['retiree', 'Kerry Towle', False],
#  '9010': ['writer', 'Ken Jennings', False],
#  '9011': ['junior high school math teacher',
#           'Michael Falk',
#           ['25-MiscTeacher', 'Teacher', 'Teacher']],
#  '9012': ['environmental compliance manager', 'Derrick Shivar', False],
#  '9013': ['benefits analyst',
#           'Annalisa Srivatsan',
#           ['13-1141',
#            'Compensation, Benefits, and Job Analysis Specialists',
#            'Benefits Analyst']],
#  '9014': ['senior managing editor', 'Michelle Leppert', False],
#  '9015': ['director of compensation', 'Ed Hagar', False],
#  '9016': ['translation coordinator', 'Sandie Baker', False],
#  '9017': ['high-school campus director', 'Jonathan Kuehnle', False],
#  '9018': ['entertainment litigation attorney', 'Jessica Guard', False],
#  '9019': ['justice of the peace',
#           'Bruce Leaman',
#           ['23-1021',
#            'Administrative Law Judges, Adjudicators, and Hearing Officers',
#            'Justice of The Peace']],
#  '902': ['attorney',
#          'Gordon Frankel Light',
#          ['23-1011', 'Lawyers', 'Attorney']],
#  '9020': ['nanny',
#           'Monique Aldred',
#           ['39-9011', 'Childcare Workers', 'Nanny']],
#  '9021': ['college history teacher',
#           'Rebecca Baird',
#           ['25-MiscTeacher', 'Teacher', 'Teacher']],
#  '9022': ['government secretary', 'Devin Baker', False],
#  '9023': ['librarian', 'Chrissy Swisher', False],
#  '9024': ['digital marketer', 'J.D. Lape', False],
#  '9025': ['copy editor',
#           'Jennie Crabbe',
#           ['27-3041', 'Editors', 'Copy Editor']],
#  '9026': ['from Royal Oak, Michigan...', 'Paul Thompson', False],
#  '9027': ['postal clerk',
#           'Alex Szabo',
#           ['43-5051', 'Postal Service Clerks', 'Postal Clerk']],
#  '9028': ['college professor', 'Norton Moses', False],
#  '9029': ['newspaper publisher & editor', 'Jane Gilman', False],
#  '903': ['attorney', 'Iris Woon', ['23-1011', 'Lawyers', 'Attorney']],
#  '9030': ['communications associate', 'Kathryn Schoenberger', False],
#  '9031': ['associate director of annual giving', 'Matt Farr', False],
#  '9032': ['attorney and municipal judge', 'E.A. Srere', False],
#  '9033': ['programmer and analyst', 'Jake Bryant', False],
#  '9034': ['foreign-service officer', 'Fr\xe9d\xe9rique Delapr\xe9e', False],
#  '9035': ['higher-education administrator', 'Kristin McAuliffe', False],
#  '9036': ['doctoral student', 'Kris Voss', False],
#  '9037': ['supply chain professional', 'Julia Collins', False],
#  '9038': ['criminal defense attorney', 'Donna Innes', False],
#  '9039': ['data scientist', 'Dilip Rajagopalan', False],
#  '904': ['recent college graduate', 'Rohan Virginkar', False],
#  '9040': ['distribution associate', 'Brad Wright', False],
#  '9041': ['I.T. consultant', 'Zia Jones', False],
#  '9042': ['veterinary technician', 'Hilary Gaughen', False],
#  '9043': ['recruiter', 'Aimee Seligstein', False],
#  '9044': ['writer', 'Grace Riley', False],
#  '9045': ['geophysicist',
#           'James Behrens',
#           ['19-2042',
#            'Geoscientists, Except Hydrologists and Geographers',
#            'Geophysicist']],
#  '9046': ['lawyer', 'Sarah Shody', ['23-1011', 'Lawyers', 'Lawyer']],
#  '9047': ['journalism professor',
#           'Bob Kochersberger',
#           ['25-1122',
#            'Communications Teachers, Postsecondary',
#            'Journalism Professor']],
#  '9048': ['firefighter', 'Nick Lemek', False],
#  '9049': ['retired teacher',
#           'Mary Twellman',
#           ['25-MiscTeacher', 'Teacher', 'Teacher']],
#  '905': ['laboratory supervisor', 'Jeremy Davis', False],
#  '9050': ['communications executive', 'John Ogden', False],
#  '9051': ['eighth-grade history teacher',
#           'Mallory Howe',
#           ['25-MiscTeacher', 'Teacher', 'Teacher']],
#  '9052': ['junior', 'Colin Rafferty', False],
#  '9053': ['sophomore', 'Becky Pawlowski', False],
#  '9054': ['senior', 'Patricia Larash', False],
#  '9055': ['junior', 'Anne Black', False],
#  '9056': ["children's book author", 'Elissa Burr', False],
#  '9057': ['library assistant',
#           'LaWanda London',
#           ['43-4121', 'Library Assistants, Clerical', 'Library Assistant']],
#  '9058': ['shelter advocate and caregiver', 'Michelle Flaherty', False],
#  '9059': ['sales representative', 'Marlon Morris', False],
#  '906': ['homemaker and substitute teacher',
#          'Jennifer Burrus',
#          ['25-MiscTeacher', 'Teacher', 'Teacher']],
#  '9060': ['student', 'Jim Bell', False],
#  '9061': ['artillery officer', 'Chas Wilson', False],
#  '9062': ['advertising executive',
#           'Steve Biddle',
#           ['11-2011',
#            'Advertising and Promotions Managers',
#            'Advertising Executive']],
#  '9063': ['international freight forwarder', 'Alec Iorio', False],
#  '9064': ['teacher', 'Scott Astle', ['25-MiscTeacher', 'Teacher', 'Teacher']],
#  '9065': ['clinical social worker', 'Steve Alper', False],
#  '9066': ['editor', 'Len Krisak', False],
#  '9067': ['law student', 'Wilson Mudge', False],
#  '9068': ['writer & publisher', 'Richard Scheffler', False],
#  '9069': ['administrative assistant', 'Albina Moran', False],
#  '907': ['attorney', 'Kate Brogan', ['23-1011', 'Lawyers', 'Attorney']],
#  '9070': ['American Red Cross manager', 'Kit Hope', False],
#  '9071': ['design engineer', 'Brian Clouse', False],
#  '9072': ['senior', 'Michael Musgrove', False],
#  '9073': ['junior', 'Steffanie Brown', False],
#  '9074': ['small business entrepreneur', 'Marilyn Newcomer', False],
#  '9075': ['teacher and cantor',
#           'Mike Kravitz',
#           ['25-MiscTeacher', 'Teacher', 'Teacher']],
#  '9076': ['transit policy analyst', 'Paul Carlson', False],
#  '9077': ['research scientist', 'James Herman', False],
#  '9078': ['political science professor', 'Leah Blumenfeld', False],
#  '9079': ['airline operations specialist', 'Clayton Walker', False],
#  '908': ['sales manager', 'Karen Arciero', False],
#  '9080': ['corporate librarian', 'Kate Hoffman', False],
#  '9081': ['strategic communications lead', 'Lara Brenckle Malmont', False],
#  '9082': ['business lawyer and consultant', 'Sirena Terr', False],
#  '9083': ['sports information director', 'Ryan Real', False],
#  '9084': ['auto repair shop service manager', 'Alex Tran', False],
#  '9085': ['student of sociology', 'Brandon Barnes', False],
#  '9086': ['attorney', 'Steve Buechner', ['23-1011', 'Lawyers', 'Attorney']],
#  '9087': ['senior', 'Mia Diamond', False],
#  '9088': ['senior', 'Mark Wong', False],
#  '9089': ['junior', 'David Javerbaum', False],
#  '909': ['screenwriter', 'Mark Murray', False],
#  '9090': ['senior', 'Stephanie Wulfesteig', False],
#  '9091': ['junior', 'Julie Robichaux', False],
#  '9092': ['U.S. Air Force logistics readiness officer',
#           'Steve Martinez',
#           False],
#  '9093': ['media consultant', 'Simone Chavoor', False],
#  '9094': ['senior', 'Gene Hayes', False],
#  '9095': ['senior', 'Sascha Dublin', False],
#  '9096': ['dentist', 'Dylan Gaillard', False],
#  '9097': ['law professor', 'Jeanne Kaiser', False],
#  '9098': ['consultant', 'Ethan Rasiel', False],
#  '9099': ['attorney', 'Linda DeBrango', ['23-1011', 'Lawyers', 'Attorney']],
#  '91': ['graduate student',
#         'Ryan Cook',
#         ['GradStu', 'Graduate student', 'Graduate student']],
#  '910': ['12-year-old', 'Nicole Tantoco', False],
#  '9100': ['aerospace engineer',
#           'Tom Nosek',
#           ['17-2011', 'Aerospace Engineers', 'Aerospace Engineer']],
#  '9101': ['junior', 'Chris Capozzola', False],
#  '9102': ['senior', 'Sarah Fanning', False],
#  '9103': ['senior', 'Jason Albert', False],
#  '9104': ['violin and viola teacher',
#           'Maggie Davis',
#           ['25-MiscTeacher', 'Teacher', 'Teacher']],
#  '9105': ['legal assistant',
#           'Manuel Berm\xfadez',
#           ['23-2011', 'Paralegals and Legal Assistants', 'Legal Assistant']],
#  '9106': ['senior', 'Eric Reid', False],
#  '9107': ['sophomore', 'Delaine Foss', False],
#  '9108': ['junior', 'Neil Gronowetter', False],
#  '9109': ['law student', 'FeiFei Jiang', False],
#  '911': ['11-year-old', 'William Marengo', False],
#  '9110': ['logistics coordinator',
#           'Matt Weldy',
#           ['13-1081', 'Logisticians', 'Logistics Coordinator']],
#  '9111': ['university librarian',
#           'Wendy Hardenberg',
#           ['25-4021', 'Librarians', 'University Librarian']],
#  '9112': ['professor of art history', 'Sami Siegelbaum', False],
#  '912': ['10-year-old', 'Katie Baxter', False],
#  '913': ['12-year-old', 'Eric Webb', False],
#  '914': ['11-year-old', 'Aki Terasaki', False],
#  '915': ['11-year-old', 'Whitney Dearden', False],
#  '916': ['engineer and consultant', 'Sam Longoria', False],
#  '917': ['systems consultant', 'Candy Martinez', False],
#  '918': ['ATM repairman', 'Jeff Slike', False],
#  '919': ['writer and editor', 'Laurie Parker', False],
#  '92': ['newspaper editor', 'Jennifer Peebles', False],
#  '920': ['Naval officer', 'Brian Pearson', False],
#  '921': ['horseback riding instructor',
#          'Margaret Rhodes',
#          ['25-3021',
#           'Self-Enrichment Education Teachers',
#           'Horseback Riding Instructor']],
#  '922': ['advertising copywriter',
#          'Richard Bernstein',
#          ['27-3043', 'Writers and Authors', 'Advertising Copywriter']],
#  '923': ['newspaper copy editor', 'Mark Stacy', False],
#  '924': ['health care systems specialist', 'Rob Vernon', False],
#  '925': ['billing analyst', 'Cara Colbert', False],
#  '926': ['prepress technician and ethics instructor',
#          'Ellyn Ritterskamp',
#          False],
#  '927': ['writer', 'Oscar Avila', False],
#  '928': ['author and physics teacher',
#          'Jenny Scharf',
#          ['25-MiscTeacher', 'Teacher', 'Teacher']],
#  '929': ['stay-at-home dad', 'Andrew Greenbaum', False],
#  '93': ['animator',
#         'Robert Kirkpatrick',
#         ['27-1014', 'Multimedia Artists and Animators', 'Animator']],
#  '930': ['dance/movement therapist', 'Britney Harris', False],
#  '931': ['restaurant manager', 'Aaron Schnier', False],
#  '932': ['financial consultant', 'Paul Barry', False],
#  '933': ['defense analyst', 'Kim Marshall', False],
#  '934': ['attorney', 'Maya Kobersy', ['23-1011', 'Lawyers', 'Attorney']],
#  '935': ['technical support manager', 'Dan Tick', False],
#  '936': ['11-year-old', 'Ivan Kleinfeld', False],
#  '937': ['10-year-old', 'Sara Jansson', False],
#  '938': ['12-year-old', 'Brian Cunningham', False],
#  '939': ['12-year-old', 'Alex Stambaugh', False],
#  '94': ['graduate student',
#         'Dave Oosterhuis',
#         ['GradStu', 'Graduate student', 'Graduate student']],
#  '940': ['10-year-old', 'Neha Gokhale', False],
#  '941': ['12-year-old', 'Michael Blake', False],
#  '942': ['12-year-old', 'Kristin Frankhouser', False],
#  '943': ['12-year-old', 'Kate Dzurilla', False],
#  '944': ['12-year-old', 'Dan Amboy', False],
#  '945': ['assistant professor', 'Pam Richardson', False],
#  '946': ['medical student', 'Richard Sowalsky', False],
#  '947': ['restaurant owner', 'Bill Warren', False],
#  '948': ['real estate agent', 'Lea Hall', False],
#  '949': ['writer', 'Harris Peet', False],
#  '95': ['graduate student',
#         'Jeff Hoppes',
#         ['GradStu', 'Graduate student', 'Graduate student']],
#  '950': ['physician', 'Avrom Simon', False],
#  '951': ['writer', 'Richard Boyce', False],
#  '952': ['telemarketing manager',
#          'Mary Barry',
#          ['41-1012',
#           'First-Line Supervisors of Non-Retail Sales Workers',
#           'Telemarketing Manager']],
#  '953': ['lawyer', 'Jeff Bandman', ['23-1011', 'Lawyers', 'Lawyer']],
#  '954': ['elementary school teacher',
#          'Hardy Watts',
#          ['25-MiscTeacher', 'Teacher', 'Teacher']],
#  '955': ['lawyer', 'Anne Reynolds', ['23-1011', 'Lawyers', 'Lawyer']],
#  '956': ['sales director',
#          'Roland Lange',
#          ['11-2022', 'Sales Managers', 'Sales Director']],
#  '957': ['high school history and government teacher',
#          'Carrie Pfeiffer',
#          ['25-MiscTeacher', 'Teacher', 'Teacher']],
#  '958': ['retired stagehand', 'Barry Molitch', False],
#  '959': ['model', 'Donna Grant', ['41-9012', 'Models', 'Model']],
#  '96': ['sophomore at the University of Maryland', 'Casey Retterer', False],
#  '960': ['maintenance planner', 'Barbara Skolaut', False],
#  '961': ['stockbroker', 'Andy Gould', False],
#  '962': ['dog walker', 'Holly Tooker', False],
#  '963': ['attorney', 'Mike Carter', ['23-1011', 'Lawyers', 'Attorney']],
#  '964': ['advertising manager',
#          'Wayne Perra',
#          ['11-2011',
#           'Advertising and Promotions Managers',
#           'Advertising Manager']],
#  '965': ['homemaker', 'Florence Livingston', False],
#  '966': ['distributor', 'Joe Haggerty', False],
#  '967': ['attorney', 'John Mackall', ['23-1011', 'Lawyers', 'Attorney']],
#  '968': ['hospitality specialist', 'Florence Shimano', False],
#  '969': ['columnist',
#          'Steven Kurtz',
#          ['27-3022', 'Reporters and Correspondents', 'Columnist']],
#  '97': ['freshman at Davidson College', 'Amory Jendrek', False],
#  '970': ['private school teacher',
#          'Andrew Connally',
#          ['25-MiscTeacher', 'Teacher', 'Teacher']],
#  '971': ['financial analyst', 'Adam Green', False],
#  '972': ['history teacher',
#          'Bev Schwartzberg',
#          ['25-MiscTeacher', 'Teacher', 'Teacher']],
#  '973': ['physician', 'Ira Schwartz', False],
#  '974': ['technical specialist', 'Bronwyn Noble', False],
#  '975': ['senior personnel specialist', 'Sue Agos', False],
#  '976': ['letter carrier',
#          'Dan Bowman',
#          ['43-5052', 'Postal Service Mail Carriers', 'Letter Carrier']],
#  '977': ['law student', 'Mike Yanochik', False],
#  '978': ['customer service representative', 'Kim Wells', False],
#  '979': ['certified public accountant',
#          'Jonathan Lowenberg',
#          ['13-2011',
#           'Accountants and Auditors',
#           'Certified Public Accountant']],
#  '98': ['junior at Carnegie Mellon University', 'Kermin Fleming', False],
#  '980': ['education administrator', 'Debbie Howe', False],
#  '981': ['humanities student', 'Rob Lasker', False],
#  '982': ['lawyer', 'Ray Baxter', ['23-1011', 'Lawyers', 'Lawyer']],
#  '983': ['homemaker', 'Terry Ragazzini', False],
#  '984': ['librarian', 'David Harris', False],
#  '985': ['musician',
#          'Keith Harrett',
#          ['27-2042', 'Musicians and Singers', 'Musician']],
#  '986': ['budget analyst',
#          'Mark Shrager',
#          ['13-2031', 'Budget Analysts', 'Budget Analyst']],
#  '987': ['typographer', 'Phil Leib', False],
#  '988': ['teacher', 'Nancy Austin', ['25-MiscTeacher', 'Teacher', 'Teacher']],
#  '989': ['law student', 'Bill Forman', False],
#  '99': ['sophomore at St. John\x92s University', 'Vicky Manos', False],
#  '990': ['medical research technician', 'Terry Swart', False],
#  '991': ['English teacher',
#          'Chris Mullins',
#          ['25-MiscTeacher', 'Teacher', 'Teacher']],
#  '992': ['law school graduate', 'Gretchen Radtke', False],
#  '993': ['senior', 'Wen Shen', False],
#  '994': ['senior', 'Beth Mullins', False],
#  '995': ['senior', 'Mike Grant', False],
#  '996': ['senior', 'Avi Stadler', False],
#  '997': ['senior', 'Richard Morris', False],
#  '998': ['senior', 'Sharon Kristal', False],
#  '999': ['junior', 'Jamie Weiss', False]}

# %%
onlyhits = {}
for key, value in playerdict.iteritems():
    if value[2] != False:
        onlyhits[key] = value[2]
    
pprint(onlyhits)
# Out:
# {'1002': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '1006': ['23-1011', 'Lawyers', 'Attorney'],
#  '1009': ['27-3043', 'Writers and Authors', 'Advertising Copywriter'],
#  '1013': ['43-9081', 'Proofreaders and Copy Markers', 'Proofreader'],
#  '1015': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '1023': ['27-3043', 'Writers and Authors', 'Advertising Copywriter'],
#  '1025': ['GradStu', 'Graduate student', 'Graduate student'],
#  '1026': ['23-1011', 'Lawyers', 'Attorney'],
#  '1029': ['23-1011', 'Lawyers', 'Attorney'],
#  '1030': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '1031': ['13-2011', 'Accountants and Auditors', 'Accountant'],
#  '1035': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '1038': ['23-1011', 'Lawyers', 'Attorney'],
#  '1040': ['23-1011', 'Lawyers', 'Lawyer'],
#  '1041': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '1042': ['GradStu', 'Graduate student', 'Graduate student'],
#  '1044': ['11-9051', 'Food Service Managers', 'Food Service Director'],
#  '1056': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '1059': ['27-2042', 'Musicians and Singers', 'Musician'],
#  '1060': ['53-5011', 'Sailors and Marine Oilers', 'Sailor'],
#  '1064': ['11-2031',
#           'Public Relations and Fundraising Managers',
#           'Public Relations Director'],
#  '1065': ['25-4021', 'Librarians', 'High School Librarian'],
#  '1071': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '1077': ['23-1011', 'Lawyers', 'Lawyer'],
#  '1078': ['27-3011', 'Radio and Television Announcers', 'Radio Host'],
#  '1079': ['GradStu', 'Graduate student', 'Graduate student'],
#  '1080': ['13-1111', 'Management Analysts', 'Management Consultant'],
#  '1088': ['15-1131', 'Computer Programmers', 'Computer Programmer'],
#  '1090': ['GradStu', 'Graduate student', 'Graduate student'],
#  '1097': ['43-3031',
#           'Bookkeeping, Accounting, and Auditing Clerks',
#           'Bookkeeper'],
#  '1099': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '11': ['23-1011', 'Lawyers', 'Attorney'],
#  '1100': ['23-1011', 'Lawyers', 'Attorney'],
#  '1102': ['23-1011', 'Lawyers', 'Attorney'],
#  '1103': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '1104': ['23-1011', 'Lawyers', 'Attorney'],
#  '1108': ['29-2052', 'Pharmacy Technicians', 'Pharmacy Technician'],
#  '1109': ['19-1023', 'Zoologists and Wildlife Biologists', 'Marine Biologist'],
#  '1111': ['23-1011', 'Lawyers', 'Trial Lawyer'],
#  '1113': ['GradStu', 'Graduate student', 'Graduate student'],
#  '1118': ['11-9141',
#           'Property, Real Estate, and Community Association Managers',
#           'Real Estate Manager'],
#  '1120': ['GradStu', 'Graduate student', 'Graduate student'],
#  '1123': ['GradStu', 'Graduate student', 'Graduate student'],
#  '1126': ['23-1011', 'Lawyers', 'Attorney'],
#  '1128': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '1136': ['GradStu', 'Graduate student', 'Graduate student'],
#  '1139': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '1141': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '1147': ['29-1181', 'Audiologists', 'Audiologist'],
#  '1155': ['23-1011', 'Lawyers', 'Attorney'],
#  '1156': ['13-1151',
#           'Training and Development Specialists',
#           'Training Specialist'],
#  '116': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '1160': ['25-4021', 'Librarians', 'Law Librarian'],
#  '1165': ['43-3071', 'Tellers', 'Bank Teller'],
#  '1166': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '1167': ['25-4021', 'Librarians', 'Law Librarian'],
#  '1168': ['23-1011', 'Lawyers', 'Attorney'],
#  '1172': ['13-1151',
#           'Training and Development Specialists',
#           'Training Specialist'],
#  '1173': ['23-1011', 'Lawyers', 'Attorney'],
#  '1174': ['11-9032',
#           'Education Administrators, Elementary and Secondary School',
#           'Elementary School Principal'],
#  '1175': ['43-9061', 'Office Clerks, General', 'Office Assistant'],
#  '1180': ['43-9061', 'Office Clerks, General', 'Office Clerk'],
#  '1183': ['23-1011', 'Lawyers', 'Attorney'],
#  '1185': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '1189': ['23-1011', 'Lawyers', 'Attorney'],
#  '1195': ['29-1066', 'Psychiatrists', 'Psychiatrist'],
#  '1196': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '1199': ['23-1011', 'Lawyers', 'Attorney'],
#  '12': ['19-1021', 'Biochemists and Biophysicists', 'Biochemist'],
#  '1200': ['21-2011', 'Clergy', 'Pastor'],
#  '1202': ['GradStu', 'Graduate student', 'Graduate student'],
#  '1204': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '1205': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '1206': ['43-4121', 'Library Assistants, Clerical', 'Library Aide'],
#  '1212': ['11-3061', 'Purchasing Managers', 'Procurement Manager'],
#  '1214': ['GradStu', 'Graduate student', 'Graduate student'],
#  '1216': ['23-1011', 'Lawyers', 'Attorney'],
#  '1220': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '1223': ['23-1011', 'Lawyers', 'Attorney'],
#  '1228': ['27-2012', 'Producers and Directors', 'Television Producer'],
#  '1230': ['13-2011', 'Accountants and Auditors', 'Accountant'],
#  '1234': ['19-3039', 'Psychologists, All Other', 'Psychotherapist'],
#  '1245': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '1251': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '1255': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '126': ['29-1061', 'Anesthesiologists', 'Anesthesiologist'],
#  '1263': ['23-1011', 'Lawyers', 'Attorney'],
#  '1264': ['23-1011', 'Lawyers', 'Attorney'],
#  '1268': ['23-1011', 'Lawyers', 'Attorney'],
#  '1269': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '127': ['GradStu', 'Graduate student', 'Graduate student'],
#  '1273': ['27-4014', 'Sound Engineering Technicians', 'Recording Engineer'],
#  '1276': ['23-1011', 'Lawyers', 'Attorney'],
#  '1277': ['15-1111',
#           'Computer and Information Research Scientists',
#           'Computer Scientist'],
#  '1280': ['GradStu', 'Graduate student', 'Graduate student'],
#  '1285': ['23-1011', 'Lawyers', 'Attorney'],
#  '129': ['47-2141', 'Painters, Construction and Maintenance', 'House Painter'],
#  '1296': ['27-3042', 'Technical Writers', 'Technical Writer'],
#  '1299': ['23-1011', 'Lawyers', 'Attorney'],
#  '130': ['43-4121', 'Library Assistants, Clerical', 'Library Assistant'],
#  '1303': ['27-3041', 'Editors', 'Book Editor'],
#  '1305': ['43-4121', 'Library Assistants, Clerical', 'Library Assistant'],
#  '1308': ['23-1011', 'Lawyers', 'Attorney'],
#  '1318': ['39-9031',
#           'Fitness Trainers and Aerobics Instructors',
#           'Personal Trainer'],
#  '1320': ['GradStu', 'Graduate student', 'Graduate student'],
#  '1322': ['43-9061', 'Office Clerks, General', 'Office Assistant'],
#  '1328': ['23-1011', 'Lawyers', 'Attorney'],
#  '1331': ['19-3031',
#           'Clinical, Counseling, and School Psychologists',
#           'School Psychologist'],
#  '1334': ['GradStu', 'Graduate student', 'Graduate student'],
#  '1337': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '134': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '1345': ['41-9021', 'Real Estate Brokers', 'Real Estate Broker'],
#  '1348': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '1364': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '137': ['27-3043', 'Writers and Authors', 'Playwright'],
#  '1379': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '1382': ['53-3041', 'Taxi Drivers and Chauffeurs', 'Limousine Driver'],
#  '1383': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '1392': ['17-2011', 'Aerospace Engineers', 'Aerospace Engineer'],
#  '1403': ['GradStu', 'Graduate student', 'Graduate student'],
#  '1405': ['19-3094', 'Political Scientists', 'Political Consultant'],
#  '1408': ['29-1141', 'Registered Nurses', 'Registered Nurse'],
#  '1416': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '142': ['GradStu', 'Graduate student', 'Graduate student'],
#  '1424': ['23-1011', 'Lawyers', 'Attorney'],
#  '1427': ['GradStu', 'Graduate student', 'Graduate student'],
#  '1429': ['27-2042', 'Musicians and Singers', 'Musician'],
#  '1430': ['23-1011', 'Lawyers', 'Attorney'],
#  '1432': ['23-1011', 'Lawyers', 'Attorney'],
#  '1435': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '1437': ['33-3012',
#           'Correctional Officers and Jailers',
#           'Correction Officer'],
#  '1438': ['25-4021', 'Librarians', "Children's Librarian"],
#  '144': ['23-2011', 'Paralegals and Legal Assistants', 'Legal Assistant'],
#  '1440': ['13-2011', 'Accountants and Auditors', 'Accountant'],
#  '1443': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '1446': ['27-1011', 'Art Directors', 'Art Director'],
#  '1451': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '1452': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '1456': ['27-4032', 'Film and Video Editors', 'Film Editor'],
#  '1460': ['GradStu', 'Graduate student', 'Graduate student'],
#  '1470': ['13-1111', 'Management Analysts', 'Management Consultant'],
#  '1473': ['13-1161',
#           'Market Research Analysts and Marketing Specialists',
#           'Marketing Consultant'],
#  '1476': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '1477': ['23-1011', 'Lawyers', 'Attorney'],
#  '1479': ['GradStu', 'Graduate student', 'Graduate student'],
#  '1481': ['41-3041', 'Travel Agents', 'Travel Agent'],
#  '1484': ['GradStu', 'Graduate student', 'Graduate student'],
#  '149': ['23-1011', 'Lawyers', 'Attorney'],
#  '1496': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '1498': ['23-1011', 'Lawyers', 'Attorney'],
#  '1504': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '1510': ['GradStu', 'Graduate student', 'Graduate student'],
#  '1511': ['27-3041', 'Editors', 'Index Editor'],
#  '1520': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '1523': ['27-3041', 'Editors', 'Copy Editor'],
#  '1528': ['23-1011', 'Lawyers', 'Attorney'],
#  '153': ['23-1011', 'Lawyers', 'Lawyer'],
#  '1530': ['23-1011', 'Lawyers', 'Deputy Attorney General'],
#  '1534': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '1542': ['23-1011', 'Lawyers', 'Attorney'],
#  '1546': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '1547': ['13-2011', 'Accountants and Auditors', 'Accountant'],
#  '1548': ['23-1011', 'Lawyers', 'Attorney'],
#  '1551': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '1552': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '1553': ['23-1011', 'Lawyers', 'Lawyer'],
#  '1557': ['11-2011',
#           'Advertising and Promotions Managers',
#           'Advertising Executive'],
#  '1558': ['17-3022',
#           'Civil Engineering Technicians',
#           'Civil Engineering Technician'],
#  '1564': ['23-1011', 'Lawyers', 'Attorney'],
#  '1568': ['11-2031',
#           'Public Relations and Fundraising Managers',
#           'Public Affairs Director'],
#  '1577': ['23-2011', 'Paralegals and Legal Assistants', 'Paralegal'],
#  '158': ['25-3099', 'Teachers and Instructors, All Other', 'Tutor'],
#  '1587': ['23-1011', 'Lawyers', 'Attorney'],
#  '1590': ['27-3042', 'Technical Writers', 'Technical Writer'],
#  '1591': ['23-1011', 'Lawyers', 'Attorney'],
#  '1593': ['23-1011', 'Lawyers', 'Attorney'],
#  '1596': ['19-1021', 'Biochemists and Biophysicists', 'Biochemist'],
#  '1597': ['23-1011', 'Lawyers', 'Attorney'],
#  '1598': ['27-3031', 'Public Relations Specialists', 'Lobbyist'],
#  '1605': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '1606': ['17-2081', 'Environmental Engineers', 'Environmental Engineer'],
#  '161': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '1612': ['21-2011', 'Clergy', 'Minister'],
#  '1613': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '1615': ['27-3031', 'Public Relations Specialists', 'Publicist'],
#  '162': ['43-6011',
#          'Executive Secretaries and Executive Administrative Assistants',
#          'Executive Assistant'],
#  '1620': ['29-1011', 'Chiropractors', 'Chiropractor'],
#  '1622': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '1625': ['23-1011', 'Lawyers', 'Attorney'],
#  '1626': ['13-2011', 'Accountants and Auditors', 'Tax Accountant'],
#  '163': ['23-1012', 'Judicial Law Clerks', 'Judicial Clerk'],
#  '1631': ['21-2011', 'Clergy', 'Rabbi'],
#  '1632': ['GradStu', 'Graduate student', 'Graduate student'],
#  '1633': ['23-1011', 'Lawyers', 'Attorney'],
#  '1639': ['27-3042', 'Technical Writers', 'Technical Writer'],
#  '1642': ['35-3011', 'Bartenders', 'Bartender'],
#  '1648': ['23-1011', 'Lawyers', 'Attorney'],
#  '1650': ['17-2081', 'Environmental Engineers', 'Environmental Engineer'],
#  '1654': ['27-3042', 'Technical Writers', 'Technical Writer'],
#  '1656': ['43-3031',
#           'Bookkeeping, Accounting, and Auditing Clerks',
#           'Bookkeeper'],
#  '1668': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '167': ['13-1071', 'Human Resources Specialists', 'Personnel Specialist'],
#  '1673': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '1678': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '1682': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '1687': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '1688': ['GradStu', 'Graduate student', 'Graduate student'],
#  '1689': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '1691': ['23-1011', 'Lawyers', 'Attorney'],
#  '1696': ['15-1131', 'Computer Programmers', 'Computer Programmer'],
#  '1699': ['23-1011', 'Lawyers', 'Attorney'],
#  '170': ['23-1011', 'Lawyers', 'Attorney'],
#  '1703': ['27-2042', 'Musicians and Singers', 'Musician'],
#  '1704': ['GradStu', 'Graduate student', 'Graduate student'],
#  '1706': ['41-3041', 'Travel Agents', 'Travel Consultant'],
#  '1708': ['27-3042', 'Technical Writers', 'Technical Writer'],
#  '171': ['23-1011', 'Lawyers', 'Lawyer'],
#  '1719': ['GradStu', 'Graduate student', 'Graduate student'],
#  '172': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '1723': ['GradStu', 'Graduate student', 'Graduate student'],
#  '1726': ['GradStu', 'Graduate student', 'Graduate student'],
#  '1729': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '1735': ['35-3011', 'Bartenders', 'Bartender'],
#  '1737': ['GradStu', 'Graduate student', 'Graduate student'],
#  '1738': ['13-1011',
#           'Agents and Business Managers of Artists, Performers, and Athletes',
#           'Talent Manager'],
#  '174': ['27-1026',
#          'Merchandise Displayers and Window Trimmers',
#          'Visual Merchandiser'],
#  '1741': ['19-1021', 'Biochemists and Biophysicists', 'Biochemist'],
#  '1746': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '1749': ['17-2141', 'Mechanical Engineers', 'Mechanical Engineer'],
#  '1757': ['23-2011', 'Paralegals and Legal Assistants', 'Paralegal'],
#  '1759': ['23-1011', 'Lawyers', 'Lawyer'],
#  '1762': ['23-1011', 'Lawyers', 'Lawyer'],
#  '1763': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '1764': ['43-6011',
#           'Executive Secretaries and Executive Administrative Assistants',
#           'Executive Assistant'],
#  '1765': ['23-1011', 'Lawyers', 'Attorney'],
#  '1767': ['33-9032', 'Security Guards', 'Security Officer'],
#  '1768': ['23-2011', 'Paralegals and Legal Assistants', 'Legal Assistant'],
#  '1769': ['17-2071', 'Electrical Engineers', 'Electrical Engineer'],
#  '1770': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '1771': ['GradStu', 'Graduate student', 'Graduate student'],
#  '1772': ['23-1011', 'Lawyers', 'Lawyer'],
#  '1778': ['GradStu', 'Graduate student', 'Graduate student'],
#  '1779': ['23-1011', 'Lawyers', 'Attorney'],
#  '178': ['27-3041', 'Editors', 'Index Editor'],
#  '1780': ['27-2011', 'Actors', 'Actress'],
#  '1782': ['11-3061', 'Purchasing Managers', 'Contract Administrator'],
#  '179': ['35-3011', 'Bartenders', 'Bartender'],
#  '18': ['25-4021', 'Librarians', 'Medical Librarian'],
#  '180': ['GradStu', 'Graduate student', 'Graduate student'],
#  '1800': ['GradStu', 'Graduate student', 'Graduate student'],
#  '1804': ['19-2021', 'Atmospheric and Space Scientists', 'Meteorologist'],
#  '1807': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '1811': ['GradStu', 'Graduate student', 'Graduate student'],
#  '1817': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '1818': ['39-9011', 'Childcare Workers', 'Nanny'],
#  '1823': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '1824': ['17-2051', 'Civil Engineers', 'Civil Engineer'],
#  '183': ['27-1024', 'Graphic Designers', 'Graphic Artist'],
#  '1832': ['27-3041', 'Editors', 'Copy Editor'],
#  '1835': ['43-5052', 'Postal Service Mail Carriers', 'Letter Carrier'],
#  '1838': ['17-2081', 'Environmental Engineers', 'Environmental Engineer'],
#  '1843': ['GradStu', 'Graduate student', 'Graduate student'],
#  '1845': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '1851': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '1861': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '1862': ['27-3041', 'Editors', 'Copy Editor'],
#  '1863': ['43-5061',
#           'Production, Planning, and Expediting Clerks',
#           'Production Scheduler'],
#  '1864': ['25-1052',
#           'Chemistry Teachers, Postsecondary',
#           'Chemistry Professor'],
#  '1865': ['23-1011', 'Lawyers', 'Attorney'],
#  '1868': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '1871': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '1872': ['19-2042',
#           'Geoscientists, Except Hydrologists and Geographers',
#           'Environmental Geologist'],
#  '1877': ['GradStu', 'Graduate student', 'Graduate student'],
#  '1884': ['GradStu', 'Graduate student', 'Graduate student'],
#  '1887': ['35-3011', 'Bartenders', 'Bartender'],
#  '1888': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '1893': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '1894': ['39-6012', 'Concierges', 'Hotel Concierge'],
#  '1898': ['21-2011', 'Clergy', 'Minister'],
#  '19': ['19-3051', 'Urban and Regional Planners', 'Urban Planner'],
#  '190': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '1900': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '1907': ['17-2011', 'Aerospace Engineers', 'Aerospace Engineer'],
#  '1910': ['23-1011', 'Lawyers', 'Attorney'],
#  '1912': ['21-2011', 'Clergy', 'Rabbi'],
#  '1914': ['23-1011', 'Lawyers', 'Attorney'],
#  '192': ['19-3011', 'Economists', 'Economist'],
#  '1924': ['13-2072', 'Loan Officers', 'Loan Officer'],
#  '1926': ['27-3043', 'Writers and Authors', 'Copywriter'],
#  '1927': ['GradStu', 'Graduate student', 'Graduate student'],
#  '1929': ['27-2042', 'Musicians and Singers', 'Musician'],
#  '193': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '1931': ['29-1126', 'Respiratory Therapists', 'Respiratory Therapist'],
#  '1933': ['23-1011', 'Lawyers', 'Attorney'],
#  '1940': ['29-1141', 'Registered Nurses', 'Registered Nurse'],
#  '1943': ['33-3011', 'Bailiffs', 'Court Officer'],
#  '1945': ['25-1124',
#           'Foreign Language and Literature Teachers, Postsecondary',
#           'French Professor'],
#  '1946': ['13-2072', 'Loan Officers', 'Loan Officer'],
#  '1949': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '1955': ['23-1011', 'Lawyers', 'Lawyer'],
#  '1957': ['29-1141', 'Registered Nurses', 'Registered Nurse'],
#  '1958': ['39-1011', 'Gaming Supervisors', 'Casino Supervisor'],
#  '1960': ['29-2052', 'Pharmacy Technicians', 'Pharmacy Technician'],
#  '1961': ['13-1161',
#           'Market Research Analysts and Marketing Specialists',
#           'Marketing Analyst'],
#  '1964': ['19-2021', 'Atmospheric and Space Scientists', 'Meteorologist'],
#  '1967': ['19-2011', 'Astronomers', 'Astronomer'],
#  '1968': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '197': ['15-2041', 'Statisticians', 'Mathematical Statistician'],
#  '1971': ['23-1011', 'Lawyers', 'Attorney'],
#  '1973': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '1974': ['GradStu', 'Graduate student', 'Graduate student'],
#  '1979': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '198': ['13-1161',
#          'Market Research Analysts and Marketing Specialists',
#          'Marketing Analyst'],
#  '1983': ['23-1011', 'Lawyers', 'Lawyer'],
#  '199': ['GradStu', 'Graduate student', 'Graduate student'],
#  '1991': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '1993': ['GradStu', 'Graduate student', 'Graduate student'],
#  '1994': ['23-1011', 'Lawyers', 'Attorney'],
#  '1997': ['27-3043', 'Writers and Authors', 'Copywriter'],
#  '20': ['23-1011', 'Lawyers', 'Lawyer'],
#  '2000': ['41-3041', 'Travel Agents', 'Travel Agent'],
#  '2005': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2006': ['27-1024', 'Graphic Designers', 'Graphic Designer'],
#  '2007': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2008': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '201': ['23-1011', 'Lawyers', 'Attorney'],
#  '2017': ['27-2012', 'Producers and Directors', 'Stage Manager'],
#  '202': ['15-1131', 'Computer Programmers', 'Computer Programmer'],
#  '2031': [
# '25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2039': ['23-1011', 'Lawyers', 'Attorney'],
#  '2040': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '205': ['GradStu', 'Graduate student', 'Graduate student'],
#  '2055': ['43-6011',
#           'Executive Secretaries and Executive Administrative Assistants',
#           'Executive Assistant'],
#  '2057': ['11-1021', 'General and Operations Managers', 'Operations Manager'],
#  '2058': ['13-1111', 'Management Analysts', 'Business Analyst'],
#  '2063': ['23-1011', 'Lawyers', 'Attorney'],
#  '2065': ['23-1011', 'Lawyers', 'Attorney'],
#  '2067': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2071': ['29-1069', 'Physicians and Surgeons, All Other', 'Dermatologist'],
#  '2074': ['23-1011', 'Lawyers', 'Lawyer'],
#  '2076': ['GradStu', 'Graduate student', 'Graduate student'],
#  '2079': ['29-2041',
#           'Emergency Medical Technicians and Paramedics',
#           'Paramedic'],
#  '208': ['13-2011', 'Accountants and Auditors', 'Accountant'],
#  '2085': ['13-1111', 'Management Analysts', 'Management Analyst'],
#  '21': ['29-1141', 'Registered Nurses', 'Registered Nurse'],
#  '210': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2105': ['23-1011', 'Lawyers', 'Attorney'],
#  '2108': ['15-1131', 'Computer Programmers', 'Computer Programmer'],
#  '2113': ['15-1134', 'Web Developers', 'Web Developer'],
#  '2114': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2115': ['35-3011', 'Bartenders', 'Bartender'],
#  '2120': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2127': ['43-6011',
#           'Executive Secretaries and Executive Administrative Assistants',
#           'Executive Assistant'],
#  '213': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2130': ['GradStu', 'Graduate student', 'Graduate student'],
#  '2132': ['13-2011', 'Accountants and Auditors', 'Accountant'],
#  '2136': ['23-1011', 'Lawyers', 'Attorney'],
#  '2138': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2139': ['27-2041', 'Music Directors and Composers', 'Music Director'],
#  '214': ['13-1161',
#          'Market Research Analysts and Marketing Specialists',
#          'Marketing Consultant'],
#  '2140': ['33-1012',
#           'First-Line Supervisors of Police and Detectives',
#           'Police Lieutenant'],
#  '2146': ['27-2041', 'Music Directors and Composers', 'Music Director'],
#  '2147': ['23-1011', 'Lawyers', 'Assistant Attorney General'],
#  '2151': ['27-3043', 'Writers and Authors', 'Copywriter'],
#  '2154': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2155': ['23-1011', 'Lawyers', 'Lawyer'],
#  '2156': ['27-1014', 'Multimedia Artists and Animators', 'Multimedia Artist'],
#  '2158': ['19-2041',
#           'Environmental Scientists and Specialists, Including Health',
#           'Environmental Scientist'],
#  '2163': ['23-1011', 'Lawyers', 'Attorney'],
#  '217': ['GradStu', 'Graduate student', 'Graduate student'],
#  '2179': ['25-1191', 'Graduate Teaching Assistants', 'Teaching Fellow'],
#  '2181': ['13-1111', 'Management Analysts', 'Business Analyst'],
#  '2185': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2191': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2192': ['19-3091', 'Anthropologists and Archeologists', 'Archaeologist'],
#  '2193': ['11-2011',
#           'Advertising and Promotions Managers',
#           'Advertising Executive'],
#  '2196': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2199': ['23-1011', 'Lawyers', 'Attorney'],
#  '2202': ['27-4031',
#           'Camera Operators, Television, Video, and Motion Picture',
#           'Cinematographer'],
#  '2203': ['GradStu', 'Graduate student', 'Graduate student'],
#  '2204': ['GradStu', 'Graduate student', 'Graduate student'],
#  '2206': ['GradStu', 'Graduate student', 'Graduate student'],
#  '2207': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2212': ['17-2051', 'Civil Engineers', 'Civil Engineer'],
#  '2214': ['GradStu', 'Graduate student', 'Graduate student'],
#  '2218': ['15-2031',
#           'Operations Research Analysts',
#           'Operations Research Analyst'],
#  '222': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2221': ['11-9141',
#           'Property, Real Estate, and Community Association Managers',
#           'Apartment Manager'],
#  '2225': ['13-2011', 'Accountants and Auditors', 'Internal Auditor'],
#  '2228': ['23-1011', 'Lawyers', 'Lawyer'],
#  '2229': ['27-1024', 'Graphic Designers', 'Graphic Designer'],
#  '2230': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2235': ['41-3031',
#           'Securities, Commodities, and Financial Services Sales Agents',
#           'Investment Banker'],
#  '2236': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2241': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2245': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2248': ['11-9081', 'Lodging Managers', 'Hotel Manager'],
#  '2254': ['39-6012', 'Concierges', 'Hotel Concierge'],
#  '2263': ['23-1011', 'Lawyers', 'Attorney'],
#  '2264': ['27-3041', 'Editors', 'Index Editor'],
#  '2267': ['23-1011', 'Lawyers', 'Attorney'],
#  '2269': ['17-2081', 'Environmental Engineers', 'Environmental Engineer'],
#  '227': ['GradStu', 'Graduate student', 'Graduate student'],
#  '2275': ['23-1011', 'Lawyers', 'Lawyer'],
#  '229': ['13-1161',
#          'Market Research Analysts and Marketing Specialists',
#          'Marketing Consultant'],
#  '2298': ['17-2051', 'Civil Engineers', 'Civil Engineer'],
#  '2299': ['11-2031',
#           'Public Relations and Fundraising Managers',
#           'Public Affairs Director'],
#  '23': ['GradStu', 'Graduate student', 'Graduate student'],
#  '230': ['23-1011', 'Lawyers', 'Lawyer'],
#  '2300': ['GradStu', 'Graduate student', 'Graduate student'],
#  '2303': ['27-1024', 'Graphic Designers', 'Graphic Designer'],
#  '2307': ['15-1121', 'Computer Systems Analysts', 'Programmer Analyst'],
#  '232': ['43-6011',
#          'Executive Secretaries and Executive Administrative Assistants',
#          'Executive Assistant'],
#  '2320': ['23-1011', 'Lawyers', 'Attorney'],
#  '2322': ['23-1011', 'Lawyers', 'Attorney'],
#  '233': ['GradStu', 'Graduate student', 'Graduate student'],
#  '2330': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2332': ['17-2011', 'Aerospace Engineers', 'Aerospace Engineer'],
#  '2333': ['GradStu', 'Graduate student', 'Graduate student'],
#  '2335': ['43-4121', 'Library Assistants, Clerical', 'Library Assistant'],
#  '2336': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2338': ['23-1011', 'Lawyers', 'Lawyer'],
#  '2339': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '234': ['25-4021', 'Librarians', 'Reference Librarian'],
#  '235': ['23-1011', 'Lawyers', 'Attorney'],
#  '2352': ['GradStu', 'Graduate student', 'Graduate student'],
#  '2356': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2365': ['29-1141', 'Registered Nurses', 'Registered Nurse'],
#  '2366': ['23-1011', 'Lawyers', 'Attorney'],
#  '2368': ['23-1011', 'Lawyers', 'Lawyer'],
#  '2373': ['11-2011',
#           'Advertising and Promotions Managers',
#           'Advertising Executive'],
#  '2377': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2379': ['27-2012', 'Producers and Directors', 'Television Producer'],
#  '238': ['23-1011', 'Lawyers', 'Attorney'],
#  '2383': ['43-4121', 'Library Assistants, Clerical', 'Library Assistant'],
#  '2384': ['15-1131', 'Computer Programmers', 'Computer Programmer'],
#  '2386': ['19-3041', 'Sociologists', 'Sociologist'],
#  '2389': ['27-2042', 'Musicians and Singers', 'Musician'],
#  '2391': ['43-5051', 'Postal Service Clerks', 'Postal Clerk'],
#  '2394': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2397': ['11-1021', 'General and Operations Managers', 'Operations Manager'],
#  '2402': ['13-1111', 'Management Analysts', 'Management Consultant'],
#  '2405': ['GradStu', 'Graduate student', 'Graduate student'],
#  '2409': ['GradStu', 'Graduate student', 'Graduate student'],
#  '2410': ['29-2081', 'Opticians, Dispensing', 'Optician'],
#  '2412': ['39-2011', 'Animal Trainers', 'Animal Trainer'],
#  '2413': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2414': ['27-3043', 'Writers and Authors', 'Copywriter'],
#  '2416': ['43-3031',
#           'Bookkeeping, Accounting, and Auditing Clerks',
#           'Bookkeeper'],
#  '2423': ['23-1011', 'Lawyers', 'Lawyer'],
#  '243': ['23-1011', 'Lawyers', 'Attorney'],
#  '2432': ['GradStu', 'Graduate student', 'Graduate student'],
#  '2433': ['29-1141', 'Registered Nurses', 'Registered Nurse'],
#  '2435': ['23-1011', 'Lawyers', 'Lawyer'],
#  '2436': ['11-2011',
#           'Advertising and Promotions Managers',
#           'Advertising Executive'],
#  '2437': ['29-1141', 'Registered Nurses', 'Registered Nurse'],
#  '2441': ['GradStu', 'Graduate student', 'Graduate student'],
#  '2442': ['GradStu', 'Graduate student', 'Graduate student'],
#  '2444': ['27-2011', 'Actors', 'Actress'],
#  '2446': ['27-2011', 'Actors', 'Actress'],
#  '2453': ['11-9141',
#           'Property, Real Estate, and Community Association Managers',
#           'Property Manager'],
#  '2455': ['15-1131', 'Computer Programmers', 'Computer Programmer'],
#  '2460': ['23-1011', 'Lawyers', 'Attorney'],
#  '2463': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2469': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2470': ['GradStu', 'Graduate student', 'Graduate student'],
#  '2472': ['GradStu', 'Graduate student', 'Graduate student'],
#  '2475': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2477': ['GradStu', 'Graduate student', 'Graduate student'],
#  '2478': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2484': ['15-1143', 'Computer Network Architects', 'Network Engineer'],
#  '2485': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2487': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2489': ['23-1011', 'Lawyers', 'Attorney'],
#  '2491': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2496': ['29-1141', 'Registered Nurses', 'Registered Nurse'],
#  '2498': ['23-1011', 'Lawyers', 'Trial Lawyer'],
#  '2501': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2503': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2508': ['13-1161',
#           'Market Research Analysts and Marketing Specialists',
#           'Market Research Analyst'],
#  '251': ['GradStu', 'Graduate student', 'Graduate student'],
#  '2511': ['17-2051', 'Civil Engineers', 'Structural Engineer'],
#  '2516': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2517': ['11-2011',
#           'Advertising and Promotions Managers',
#           'Advertising Manager'],
#  '252': ['19-2032', 'Materials Scientists', 'Materials Scientist'],
#  '2521': ['23-1011', 'Lawyers', 'Attorney'],
#  '2522': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2524': ['19-1029', 'Biological Scientists, All Other', 'Biologist'],
#  '2525': ['GradStu', 'Graduate student', 'Graduate student'],
#  '2530': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2531': ['19-3094', 'Political Scientists', 'Political Consultant'],
#  '2532': ['17-2051', 'Civil Engineers', 'Civil Engineer'],
#  '2538': ['23-1011', 'Lawyers', 'Lawyer'],
#  '2541': ['23-1011', 'Lawyers', 'Attorney'],
#  '2544': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2546': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2548': ['23-1011', 'Lawyers', 'Lawyer'],
#  '2549': ['17-2051', 'Civil Engineers', 'Civil Engineer'],
#  '2550': ['23-2011', 'Paralegals and Legal Assistants', 'Paralegal'],
#  '2558': ['23-1011', 'Lawyers', 'Attorney'],
#  '256': ['23-1011', 'Lawyers', 'Lawyer'],
#  '2581': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '260': ['GradStu', 'Graduate student', 'Graduate student'],
#  '2601': ['23-1011', 'Lawyers', 'Attorney'],
#  '2602': ['23-1011', 'Lawyers', 'Attorney'],
#  '2604': ['GradStu', 'Graduate student', 'Graduate student'],
#  '2606': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2607': ['23-1011', 'Lawyers', 'Attorney'],
#  '261': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2613': ['23-1011', 'Lawyers', 'Attorney'],
#  '2614': ['23-2011', 'Paralegals and Legal Assistants', 'Legal Assistant'],
#  '2616': ['GradStu', 'Graduate student', 'Graduate student'],
#  '2617': ['35-2014', 'Cooks, Restaurant', 'Line Cook'],
#  '2619': ['17-2011', 'Aerospace Engineers', 'Aerospace Engineer'],
#  '2626': ['43-5052', 'Postal Service Mail Carriers', 'Letter Carrier'],
#  '2629': ['GradStu', 'Graduate student', 'Graduate student'],
#  '2635': ['43-4121', 'Library Assistants, Clerical', 'Library Assistant'],
#  '2636': ['11-2021', 'Marketing Managers', 'Marketing Director'],
#  '2641': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2649': ['GradStu', 'Graduate student', 'Graduate student'],
#  '2655': ['23-1011', 'Lawyers', 'Attorney'],
#  '2656': ['25-4011', 'Archivists', 'Archivist'],
#  '2664': ['GradStu', 'Graduate student', 'Graduate student'],
#  '267': ['11-2022', 'Sales Managers', 'Regional Sales Manager'],
#  '2671': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2672': ['29-1066', 'Psychiatrists', 'Psychiatrist'],
#  '2676': ['29-1127', 'Speech-Language Pathologists', 'Speech Pathologist'],
#  '268': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2682': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2686': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2687': ['GradStu', 'Graduate student', 'Graduate student'],
#  '2690': ['27-3041', 'Editors', 'Copy Editor'],
#  '2691': ['GradStu', 'Graduate student', 'Graduate student'],
#  '2694': ['13-1111', 'Management Analysts', 'Management Consultant'],
#  '2695': ['11-2021', 'Marketing Managers', 'Marketing Director'],
#  '2696': ['29-1141', 'Registered Nurses', 'Registered Nurse'],
#  '2697': ['GradStu', 'Graduate student', 'Graduate student'],
#  '2698': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2699': ['23-1011', 'Lawyers', 'Attorney'],
#  '2700': ['23-1011', 'Lawyers', 'Attorney'],
#  '2701': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2704': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2705': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2712': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2715': ['GradStu', 'Graduate student', 'Graduate student'],
#  '2718': ['23-1012', 'Judicial Law Clerks', 'Judicial Clerk'],
#  '2719': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2721': ['43-9081', 'Proofreaders and Copy Markers', 'Proofreader'],
#  '2723': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2724': ['23-1011', 'Lawyers', 'Attorney'],
#  '2734': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2738': ['27-2042', 'Musicians and Singers', 'Musician'],
#  '2740': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2741': ['25-4011', 'Archivists', 'Archivist'],
#  '2743': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2744': ['11-1021', 'General and Operations Managers', 'Operations Manager'],
#  '2745': ['25-4021', 'Librarians', 'Law Librarian'],
#  '2746': ['27-2042', 'Musicians and Singers', 'Opera Singer'],
#  '2748': ['23-1011', 'Lawyers', 'Lawyer'],
#  '275': ['27-3043', 'Writers and Authors', 'Copywriter'],
#  '2752': ['11-9033',
#           'Education Administrators, Postsecondary',
#           'University Administrator'],
#  '2755': ['29-1069', 'Physicians and Surgeons, All Other', 'Cardiologist'],
#  '2757': ['11-9141',
#           'Property, Real Estate, and Community Association Managers',
#           'Apartment Manager'],
#  '2760': ['13-1111', 'Management Analysts', 'Management Analyst'],
#  '2772': ['27-2011', 'Actors', 'Actress'],
#  '2781': ['27-2011', 'Actors', 'Actress'],
#  '2785': ['23-1011', 'Lawyers', 'Attorney'],
#  '2788': ['27-2042', 'Musicians and Singers', 'Musician'],
#  '2789': ['23-1011', 'Lawyers', 'Lawyer'],
#  '2790': ['27-2041', 'Music Directors and Composers', 'Composer'],
#  '2792': ['23-1011', 'Lawyers', 'Attorney'],
#  '2793': ['GradStu', 'Graduate student', 'Graduate student'],
#  '2795': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2798': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2802': ['15-2021', 'Mathematicians', 'Mathematician'],
#  '2806': ['27-2011', 'Actors', 'Actress'],
#  '2809': ['27-1022', 'Fashion Designers', 'Fashion Designer'],
#  '2816': ['27-2011', 'Actors', 'Actress'],
#  '2818': ['27-2011', 'Actors', 'Actress'],
#  '2822': ['27-2011', 'Actors', 'Actress'],
#  '2826': ['GradStu', 'Graduate student', 'Graduate student'],
#  '2828': ['23-1011', 'Lawyers', 'Attorney'],
#  '2830': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2833': ['11-9141',
#           'Property, Real Estate, and Community Association Managers',
#           'Property Manager'],
#  '2834': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2837': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2841': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2842': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2843': ['25-4021', 'Librarians', 'Medical Librarian'],
#  '2844': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2845': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2850': ['23-1011', 'Lawyers', 'Lawyer'],
#  '2852': ['25-4011', 'Archivists', 'Archivist'],
#  '2854': ['11-2021', 'Marketing Managers', 'Marketing Director'],
#  '2855': ['23-2011', 'Paralegals and Legal Assistants', 'Paralegal'],
#  '2860': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2862': ['11-3061', 'Purchasing Managers', 'Procurement Manager'],
#  '287': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2871': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2873': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2879': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '288': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2898': ['29-1141', 'Registered Nurses', 'Registered Nurse'],
#  '2899': ['17-2011', 'Aerospace Engineers', 'Aerospace Engineer'],
#  '2907': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '291': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2911': ['25-4011', 'Archivists', 'Archivist'],
#  '2914': ['GradStu', 'Graduate student', 'Graduate student'],
#  '2916': ['13-2011', 'Accountants and Auditors', 'Auditor'],
#  '2917': ['23-1011', 'Lawyers', 'Attorney'],
#  '2918': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '292': ['23-1011', 'Lawyers', 'Lawyer'],
#  '2920': ['27-1024', 'Graphic Designers', 'Graphic Artist'],
#  '2924': ['29-1141', 'Registered Nurses', 'Registered Nurse'],
#  '2926': ['23-1011', 'Lawyers', 'Attorney'],
#  '2928': ['GradStu', 'Graduate student', 'Graduate student'],
#  '2930': ['13-1161',
#           'Market Research Analysts and Marketing Specialists',
#           'Market Research Analyst'],
#  '2935': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2937': ['21-2011', 'Clergy', 'Pastor'],
#  '294': ['29-1062', 'Family and General Practitioners', 'Family Physician'],
#  '2942': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2946': ['GradStu', 'Graduate student', 'Graduate student'],
#  '2947': ['15-1143',
#           'Computer Network Architects',
#           'Computer Network Engineer'],
#  '2950': ['27-3042', 'Technical Writers', 'Technical Writer'],
#  '2952': ['23-1011', 'Lawyers', 'Lawyer'],
#  '2954': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2958': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2972': ['GradStu', 'Graduate student', 'Graduate student'],
#  '2975': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '2977': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '298': ['27-3043', 'Writers and Authors', 'Author'],
#  '2994': ['25-4021', 'Librarians', 'High School Librarian'],
#  '2997': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '3000':
# ['11-9032',
#           'Education Administrators, Elementary and Secondary School',
#           'Elementary School Principal'],
#  '3001': ['23-1011', 'Lawyers', 'Attorney'],
#  '3008': ['29-1067', 'Surgeons', 'Orthopedic Surgeon'],
#  '3010': ['23-1011', 'Lawyers', 'Attorney'],
#  '3013': ['GradStu', 'Graduate student', 'Graduate student'],
#  '3018': ['27-3041', 'Editors', 'Publications Editor'],
#  '3019': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '302': ['29-1069', 'Physicians and Surgeons, All Other', 'Radiologist'],
#  '3021': ['23-1011', 'Lawyers', 'Lawyer'],
#  '3023': ['25-4021', 'Librarians', 'Medical Librarian'],
#  '3029': ['23-1011', 'Lawyers', 'Attorney'],
#  '3030': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '3034': ['GradStu', 'Graduate student', 'Graduate student'],
#  '3035': ['29-1061', 'Anesthesiologists', 'Anesthesiologist'],
#  '3037': ['27-2042', 'Musicians and Singers', 'Opera Singer'],
#  '3041': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '3047': ['27-2042', 'Musicians and Singers', 'Musician'],
#  '3048': ['23-1011', 'Lawyers', 'Lawyer'],
#  '3057': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '306': ['43-9031', 'Desktop Publishers', 'Desktop Publisher'],
#  '3060': ['23-1011', 'Lawyers', 'Attorney'],
#  '3063': ['23-1011', 'Lawyers', 'Attorney'],
#  '3067': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '3075': ['47-4011',
#           'Construction and Building Inspectors',
#           'Construction Inspector'],
#  '3078': ['21-2011', 'Clergy', 'Minister'],
#  '3081': ['25-1066',
#           'Psychology Teachers, Postsecondary',
#           'Psychology Professor'],
#  '3083': ['GradStu', 'Graduate student', 'Graduate student'],
#  '3085': ['27-2011', 'Actors', 'Actress'],
#  '309': ['23-1011', 'Lawyers', 'Attorney'],
#  '3090': ['29-1061', 'Anesthesiologists', 'Anesthesiologist'],
#  '3091': ['GradStu', 'Graduate student', 'Graduate student'],
#  '3092': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '3093': ['13-1151',
#           'Training and Development Specialists',
#           'Training Coordinator'],
#  '3095': ['23-1011', 'Lawyers', 'Attorney'],
#  '3096': ['27-2012', 'Producers and Directors', 'Television Producer'],
#  '3098': ['13-1151',
#           'Training and Development Specialists',
#           'Training Specialist'],
#  '31': ['GradStu', 'Graduate student', 'Graduate student'],
#  '3115': ['23-1011', 'Lawyers', 'Attorney'],
#  '3119': ['23-1011', 'Lawyers', 'Attorney'],
#  '3126': ['35-3011', 'Bartenders', 'Bartender'],
#  '3127': ['23-1011', 'Lawyers', 'Attorney'],
#  '3128': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '3132': ['23-1011', 'Lawyers', 'Lawyer'],
#  '3135': ['23-1011', 'Lawyers', 'Attorney'],
#  '3149': ['15-1131', 'Computer Programmers', 'Computer Programmer'],
#  '3150': ['29-1141', 'Registered Nurses', 'Registered Nurse'],
#  '3156': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '3157': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '3158': ['25-1066',
#           'Psychology Teachers, Postsecondary',
#           'Psychology Professor'],
#  '3161': ['17-2081', 'Environmental Engineers', 'Environmental Engineer'],
#  '3162': ['23-1012', 'Judicial Law Clerks', 'Judicial Clerk'],
#  '3163': ['27-2042', 'Musicians and Singers', 'Musician'],
#  '3164': ['23-1011', 'Lawyers', 'Attorney'],
#  '3167': ['23-1011', 'Lawyers', 'Public Defender'],
#  '3170': ['GradStu', 'Graduate student', 'Graduate student'],
#  '3172': ['23-1011', 'Lawyers', 'Attorney'],
#  '3176': ['GradStu', 'Graduate student', 'Graduate student'],
#  '3177': ['13-1111', 'Management Analysts', 'Business Analyst'],
#  '3181': ['25-4021', 'Librarians', "Children's Librarian"],
#  '3187': ['11-1021', 'General and Operations Managers', 'Operations Manager'],
#  '3188': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '3193': ['27-2011', 'Actors', 'Actress'],
#  '3195': ['11-9033',
#           'Education Administrators, Postsecondary',
#           'University Administrator'],
#  '3196': ['27-3043', 'Writers and Authors', 'Advertising Copywriter'],
#  '3197': ['23-1011', 'Lawyers', 'Attorney'],
#  '3205': ['15-1131', 'Computer Programmers', 'Computer Programmer'],
#  '3208': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '3210': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '3211': ['23-1011', 'Lawyers', 'Attorney'],
#  '3212': ['GradStu', 'Graduate student', 'Graduate student'],
#  '3216': ['GradStu', 'Graduate student', 'Graduate student'],
#  '3217': ['27-2012', 'Producers and Directors', 'Television Producer'],
#  '3222': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '3226': ['27-2042', 'Musicians and Singers', 'Musician'],
#  '3227': ['23-1011', 'Lawyers', 'Attorney'],
#  '3230': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '3236': ['GradStu', 'Graduate student', 'Graduate student'],
#  '3237': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '3239': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '3245': ['13-2099',
#           'Financial Specialists, All Other',
#           'Foreign Exchange Trader'],
#  '3249': ['13-1111', 'Management Analysts', 'Management Consultant'],
#  '3250': ['25-4021', 'Librarians', 'Law Librarian'],
#  '3252': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '3258': ['35-3011', 'Bartenders', 'Bartender'],
#  '3259': ['27-3042', 'Technical Writers', 'Technical Writer'],
#  '3262': ['23-1011', 'Lawyers', 'Attorney'],
#  '3266': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '3267': ['GradStu', 'Graduate student', 'Graduate student'],
#  '3268': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '3273': ['29-1062',
#           'Family and General Practitioners',
#           'Family Practice Physician'],
#  '3286': ['35-1011', 'Chefs and Head Cooks', 'Sous Chef'],
#  '3287': ['35-3011', 'Bartenders', 'Bartender'],
#  '3292': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '3301': ['13-1151',
#           'Training and Development Specialists',
#           'Corporate Trainer'],
#  '3304': ['27-3041', 'Editors', 'Copy Editor'],
#  '3306': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '3308': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '3309': ['35-1011', 'Chefs and Head Cooks', 'Pastry Chef'],
#  '332': ['29-1069', 'Physicians and Surgeons, All Other', 'Radiologist'],
#  '3320': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '3321': ['13-2011', 'Accountants and Auditors', 'Cost Accountant'],
#  '3322': ['27-3041', 'Editors', 'Book Editor'],
#  '3323': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '3327': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '3328': ['23-1011', 'Lawyers', 'Attorney'],
#  '3332': ['27-1024', 'Graphic Designers', 'Graphic Designer'],
#  '3338': ['41-3021', 'Insurance Sales Agents', 'Insurance Broker'],
#  '3343': ['GradStu', 'Graduate student', 'Graduate student'],
#  '3346': ['25-4011', 'Archivists', 'Archivist'],
#  '3348': ['23-1011', 'Lawyers', 'Attorney'],
#  '3350': ['13-2011', 'Accountants and Auditors', 'Accountant'],
#  '3353': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '3356': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '3357': ['23-1011', 'Lawyers', 'Attorney'],
#  '3358': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '3361': ['GradStu', 'Graduate student', 'Graduate student'],
#  '3366': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '3367': ['11-2031',
#           'Public Relations and Fundraising Managers',
#           'Public Relations Director'],
#  '3373': ['19-1042',
#           'Medical Scientists, Except Epidemiologists',
#           'Pharmacologist'],
#  '3374': ['GradStu', 'Graduate student', 'Graduate student'],
#  '3376': ['13-1111', 'Management Analysts', 'Management Consultant'],
#  '3377': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '3378': ['23-1011', 'Lawyers', 'Lawyer'],
#  '338': ['23-1011', 'Lawyers', 'Attorney'],
#  '3380': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '3383': ['GradStu', 'Graduate student', 'Graduate student'],
#  '3386': ['41-3041', 'Travel Agents', 'Travel Agent'],
#  '3388': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '339': ['23-1011', 'Lawyers', 'Attorney'],
#  '3394': ['GradStu', 'Graduate student', 'Graduate student'],
#  '340': ['23-1011', 'Lawyers', 'Attorney'],
#  '3423': ['23-2011', 'Paralegals and Legal Assistants', 'Legal Assistant'],
#  '3425': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '3427': ['21-2011', 'Clergy', 'Rabbi'],
#  '344': ['19-3011', 'Economists', 'Economist'],
#  '3445': ['13-2082', 'Tax Preparers', 'Tax Consultant'],
#  '345': ['35-9031',
#          'Hosts and Hostesses, Restaurant, Lounge, and Coffee Shop',
#          "Maitre D'"],
#  '3452': ['23-1011', 'Lawyers', 'Attorney'],
#  '3453': ['25-4021', 'Librarians', 'School Librarian'],
#  '3461': ['GradStu', 'Graduate student', 'Graduate student'],
#  '3466': ['23-1011', 'Lawyers', 'Attorney'],
#  '3467': ['13-2031', 'Budget Analysts', 'Budget Analyst'],
#  '3469': ['53-2021', 'Air Traffic Controllers', 'Air Traffic Controller'],
#  '3471': ['27-1024', 'Graphic Designers', 'Graphic Artist'],
#  '3472': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '3474': ['GradStu', 'Graduate student', 'Graduate student'],
#  '3478': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '3485': ['19-2031', 'Chemists', 'Analytical Chemist'],
#  '3487': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '3488': ['35-3011', 'Bartenders', 'Bartender'],
#  '349': ['17-2011', 'Aerospace Engineers', 'Aerospace Engineer'],
#  '3494': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '3503': ['23-1011', 'Lawyers', 'Attorney'],
#  '3504': ['13-2011', 'Accountants and Auditors', 'Accountant'],
#  '3505': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '3507': ['21-2099', 'Religious Workers, All Other', 'Missionary'],
#  '3509': ['23-1011', 'Lawyers', 'Attorney'],
#  '3511': ['GradStu', 'Graduate student', 'Graduate student'],
#  '3512': ['GradStu', 'Graduate student', 'Graduate student'],
#  '3514': ['27-3042', 'Technical Writers', 'Technical Writer'],
#  '3517': ['47-2031', 'Carpenters', 'Finish Carpenter'],
#  '3518': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '3521': ['23-1011', 'Lawyers', 'Attorney'],
#  '3524': ['GradStu', 'Graduate student', 'Graduate student'],
#  '3526': ['23-1011', 'Lawyers', 'Attorney'],
# ...
#  '8335': ['39-6012', 'Concierges', 'Concierge'],
#  '8336': ['15-1131', 'Computer Programmers', 'Computer Programmer'],
#  '8345': ['23-1011', 'Lawyers', 'Attorney'],
#  '8349': ['GradStu', 'Graduate student', 'Graduate student'],
#  '8351': ['39-6012', 'Concierges', 'Hotel Concierge'],
#  '8352': ['19-2099', 'Physical Scientists, All Other', 'Physical Scientist'],
#  '8362': ['23-2011', 'Paralegals and Legal Assistants', 'Paralegal'],
#  '8367': ['11-9032',
#           'Education Administrators, Elementary and Secondary School',
#           'Elementary School Principal'],
#  '8370': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '8374': ['29-1141', 'Registered Nurses', 'Registered Nurse'],
#  '8376': ['23-1011', 'Lawyers', 'Lawyer'],
#  '8381': ['23-1011', 'Lawyers', 'Lawyer'],
#  '8383': ['23-1011', 'Lawyers', 'Attorney'],
#  '8384': ['GradStu', 'Graduate student', 'Graduate student'],
#  '8391': ['23-1011', 'Lawyers', 'Attorney'],
#  '84': ['27-1024', 'Graphic Designers', 'Graphic Designer'],
#  '8411': ['15-1134', 'Web Developers', 'Web Designer'],
#  '8417': ['GradStu', 'Graduate student', 'Graduate student'],
#  '8418': ['23-1011', 'Lawyers', 'Attorney'],
#  '8420': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '8425': ['11-9141',
#           'Property, Real Estate, and Community Association Managers',
#           'Property Manager'],
#  '8427': ['17-2071', 'Electrical Engineers', 'Electrical Engineer'],
#  '8429': ['GradStu', 'Graduate student', 'Graduate student'],
#  '843': ['27-4013', 'Radio Operators', 'Radio Operator'],
#  '8430': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '8434': ['11-9141',
#           'Property, Real Estate, and Community Association Managers',
#           'Property Manager'],
#  '8435': ['17-2051', 'Civil Engineers', 'Structural Engineer'],
#  '8438': ['25-4021', 'Librarians', 'High School Librarian'],
#  '8439': ['11-1021', 'General and Operations Managers', 'Operations Manager'],
#  '8440': ['23-1011', 'Lawyers', 'Attorney'],
#  '8447': ['27-1025', 'Interior Designers', 'Interior Designer'],
#  '8448': ['43-9081', 'Proofreaders and Copy Markers', 'Proofreader'],
#  '845': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '8450': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '8454': ['17-2071', 'Electrical Engineers', 'Electrical Engineer'],
#  '8460': ['23-1011', 'Lawyers', 'Public Defender'],
#  '8464': ['29-1011', 'Chiropractors', 'Chiropractor'],
#  '8465': ['29-2021', 'Dental Hygienists', 'Dental Hygienist'],
#  '8470': ['17-2051', 'Civil Engineers', 'Structural Engineer'],
#  '8473': ['27-3043', 'Writers and Authors', 'Playwright'],
#  '8474': ['15-1131', 'Computer Programmers', 'Computer Programmer'],
#  '8483': ['23-1011', 'Lawyers', 'Attorney'],
#  '8497': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '8498': ['21-1092',
#           'Probation Officers and Correctional Treatment Specialists',
#           'Probation Officer'],
#  '8504': ['23-1011', 'Lawyers', 'Attorney'],
#  '8505': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '8510': ['GradStu', 'Graduate student', 'Graduate student'],
#  '8514': ['23-1011', 'Lawyers', 'Attorney'],
#  '8517': ['19-3011', 'Economists', 'Economist'],
#  '8519': ['23-1011', 'Lawyers', 'Attorney'],
#  '8523': ['23-1011', 'Lawyers', 'Attorney'],
#  '853': ['23-1011', 'Lawyers', 'Attorney'],
#  '8532': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '8539': ['43-5052', 'Postal Service Mail Carriers', 'Letter Carrier'],
#  '854': ['23-1011', 'Lawyers', 'Attorney'],
#  '8540': ['13-1081', 'Logisticians', 'Logistician'],
#  '8541': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '8544': ['11-3021',
#           'Computer and Information Systems Managers',
#           'Data Processing Manager'],
#  '8547': ['13-1161',
#           'Market Research Analysts and Marketing Specialists',
#           'Marketing Consultant'],
#  '855': ['23-1011', 'Lawyers', 'Attorney'],
#  '8552': ['43-5032',
#           'Dispatchers, Except Police, Fire, and Ambulance',
#           'Train Dispatcher'],
#  '8553': ['23-1011', 'Lawyers', 'Tax Attorney'],
#  '8556': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '8559': ['25-4011', 'Archivists', 'Archivist'],
#  '8569': ['23-1011', 'Lawyers', 'Attorney'],
#  '8574': ['13-1111', 'Management Analysts', 'Management Consultant'],
#  '8579': ['13-2011', 'Accountants and Auditors', 'Accountant'],
#  '8584': ['23-1011', 'Lawyers', 'Lawyer'],
#  '8586': ['13-1111', 'Management Analysts', 'Management Consultant'],
#  '8597': ['19-3094', 'Political Scientists', 'Political Consultant'],
#  '860': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '8608': ['GradStu', 'Graduate student', 'Graduate student'],
#  '862': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '8623': ['23-1011', 'Lawyers', 'Attorney'],
#  '8624': ['GradStu', 'Graduate student', 'Graduate student'],
#  '8625': ['27-1024', 'Graphic Designers', 'Graphic Artist'],
#  '863': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '864': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '8641': ['23-1011', 'Lawyers', 'Attorney'],
#  '8643': ['GradStu', 'Graduate student', 'Graduate student'],
#  '8646': ['23-1011', 'Lawyers', 'Public Defender'],
#  '865': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '8650': ['27-1024', 'Graphic Designers', 'Graphic Designer'],
#  '8653': ['23-1011', 'Lawyers', 'Attorney'],
#  '8658': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '866': ['13-2011', 'Accountants and Auditors', 'Accountant'],
#  '8664': ['27-2023',
#           'Umpires, Referees, and Other Sports Officials',
#           'Baseball Umpire'],
#  '8665': ['19-3051', 'Urban and Regional Planners', 'City Planner'],
#  '8666': ['23-1011', 'Lawyers', 'Lawyer'],
#  '8668': ['13-1161',
#           'Market Research Analysts and Marketing Specialists',
#           'Marketing Analyst'],
#  '867': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '8672': ['29-1041', 'Optometrists', 'Optometrist'],
#  '8681': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '8683': ['27-3042', 'Technical Writers', 'Technical Writer'],
#  '8685': ['23-1011', 'Lawyers', 'Attorney'],
#  '8688': ['29-1069', 'Physicians and Surgeons, All Other', 'Radiologist'],
#  '869': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '8690': ['19-3091', 'Anthropologists and Archeologists', 'Archaeologist'],
#  '8691': ['GradStu', 'Graduate student', 'Graduate student'],
#  '8692': ['23-1011', 'Lawyers', 'Lawyer'],
#  '8694': ['11-3011',
#           'Administrative Services Managers',
#           'Administrative Services Manager'],
#  '8696': ['GradStu', 'Graduate student', 'Graduate student'],
#  '8704': ['23-1011', 'Lawyers', 'Attorney'],
#  '8711': ['13-2011', 'Accountants and Auditors', 'Accountant'],
#  '8712': ['23-1011', 'Lawyers', 'Attorney'],
#  '8713': ['GradStu', 'Graduate student', 'Graduate student'],
#  '8714': ['25-4021', 'Librarians', 'College Librarian'],
#  '8717': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '8718': ['19-3091', 'Anthropologists and Archeologists', 'Anthropologist'],
#  '872': ['23-1011', 'Lawyers', 'Attorney'],
#  '8720': ['23-1011', 'Lawyers', 'Attorney'],
#  '8724': ['27-3043', 'Writers and Authors', 'Novelist'],
#  '8726': ['GradStu', 'Graduate student', 'Graduate student'],
#  '8731': ['29-1066', 'Psychiatrists', 'Psychiatrist'],
#  '8734': ['27-2042', 'Musicians and Singers', 'Opera Singer'],
#  '8735': ['GradStu', 'Graduate student', 'Graduate student'],
#  '8739': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '8743': ['23-1011', 'Lawyers', 'Attorney'],
#  '8744': ['25-3099', 'Teachers and Instructors, All Other', 'Tutor'],
#  '8747': ['GradStu', 'Graduate student', 'Graduate student'],
#  '8748': ['27-3041', 'Editors', 'Technical Editor'],
#  '875': ['23-1011', 'Lawyers', 'Attorney'],
#  '8751': ['23-1011', 'Lawyers', 'Lawyer'],
#  '8753': ['23-1011', 'Lawyers', 'Attorney'],
#  '8761': ['13-2011', 'Accountants and Auditors', 'Accountant'],
#  '8763': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '8768': ['23-1011', 'Lawyers', 'Attorney'],
#  '8769': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '877': ['17-2051', 'Civil Engineers', 'Structural Engineer'],
#  '8770': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '8771': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '8772': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '8773': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '8774': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '8775': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '8776': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '8777': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '8778': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '8779': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '8780': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '8781': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '8782': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '8783': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '8788': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '8795': ['23-1011', 'Lawyers', 'Tax Attorney'],
#  '8799': ['25-9041', 'Teacher Assistants', 'Paraeducator'],
#  '8802': ['11-1021', 'General and Operations Managers', 'Operations Manager'],
#  '8803': ['GradStu', 'Graduate student', 'Graduate student'],
#  '8806': ['23-1011', 'Lawyers', 'Attorney'],
#  '881': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '8811': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '8816': ['GradStu', 'Graduate student', 'Graduate student'],
#  '8818': ['23-1011', 'Lawyers', 'Attorney'],
#  '882': ['GradStu', 'Graduate student', 'Graduate student'],
#  '8821': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '8833': ['GradStu', 'Graduate student', 'Graduate student'],
#  '8834': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '8843': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '8849': ['23-1011', 'Lawyers', 'Attorney'],
#  '885': ['27-2041', 'Music Directors and Composers', 'Composer'],
#  '8852': ['15-2041', 'Statisticians', 'Statistician'],
#  '8853': ['GradStu', 'Graduate student', 'Graduate student'],
#  '8854': ['GradStu', 'Graduate student', 'Graduate student'],
#  '8856': ['31-9097', 'Phlebotomists', 'Phlebotomist'],
#  '886': ['19-2042',
#          'Geoscientists, Except Hydrologists and Geographers',
#          'Geologist'],
#  '8860': ['23-1011', 'Lawyers', 'Attorney'],
#  '8861': ['GradStu', 'Graduate student', 'Graduate student'],
#  '8864': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '8868': ['19-2041',
#           'Environmental Scientists and Specialists, Including Health',
#           'Environmental Scientist'],
#  '8869': ['27-2042', 'Musicians and Singers', 'Musician'],
#  '887': ['23-1011', 'Lawyers', 'Attorney'],
#  '8874': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '888': ['41-9021', 'Real Estate Brokers', 'Real Estate Broker'],
#  '8882': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '8883': ['13-1161',
#           'Market Research Analysts and Marketing Specialists',
#           'Marketing Consultant'],
#  '8886': ['25-1124',
#           'Foreign Language and Literature Teachers, Postsecondary',
#           'French Professor'],
#  '8893': ['27-2012', 'Producers and Directors', 'Stage Manager'],
#  '8899': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '8901': ['23-1011', 'Lawyers', 'Attorney'],
#  '8903': ['27-3041', 'Editors', 'Copy Editor'],
#  '8906': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '8912': ['23-1011', 'Lawyers', 'Attorney'],
#  '8915': ['23-1011', 'Lawyers', 'Attorney'],
#  '8931': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '8932': ['27-3031',
#           'Public Relations Specialists',
#           'Public Relations Officer'],
#  '8933': ['31-1011', 'Home Health Aides', 'Home Health Aide'],
#  '8937': ['33-9032', 'Security Guards', 'Security Officer'],
#  '8939': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '8940': ['23-2011', 'Paralegals and Legal Assistants', 'Paralegal'],
#  '8946': ['GradStu', 'Graduate student', 'Graduate student'],
#  '8949': ['29-1069', 'Physicians and Surgeons, All Other', 'Radiologist'],
#  '895': ['23-1011', 'Lawyers', 'Lawyer'],
#  '8956': ['GradStu', 'Graduate student', 'Graduate student'],
#  '8958': ['15-1141', 'Database Administrators', 'Database Coordinator'],
#  '8962': ['GradStu', 'Graduate student', 'Graduate student'],
#  '8965': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '8966': ['11-9033',
#           'Education Administrators, Postsecondary',
#           'University Administrator'],
#  '8973': ['17-2011', 'Aerospace Engineers', 'Aerospace Engineer'],
#  '8975': ['GradStu', 'Graduate student', 'Graduate student'],
#  '8977': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '8979': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '8983': ['23-1011', 'Lawyers', 'Attorney'],
#  '8985': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '8987': ['23-1011', 'Lawyers', 'Attorney'],
#  '8992': ['53-2021', 'Air Traffic Controllers', 'Air Traffic Controller'],
#  '8994': ['23-1011', 'Lawyers', 'Attorney'],
#  '9002': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '9007': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '9009': ['23-1011', 'Lawyers', 'Attorney'],
#  '9011': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '9013': ['13-1141',
#           'Compensation, Benefits, and Job Analysis Specialists',
#           'Benefits Analyst'],
#  '9019': ['23-1021',
#           'Administrative Law Judges, Adjudicators, and Hearing Officers',
#           'Justice of The Peace'],
#  '902': ['23-1011', 'Lawyers', 'Attorney'],
#  '9020': ['39-9011', 'Childcare Workers', 'Nanny'],
#  '9021': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '9025': ['27-3041', 'Editors', 'Copy Editor'],
#  '9027': ['43-5051', 'Postal Service Clerks',
# 'Postal Clerk'],
#  '903': ['23-1011', 'Lawyers', 'Attorney'],
#  '9045': ['19-2042',
#           'Geoscientists, Except Hydrologists and Geographers',
#           'Geophysicist'],
#  '9046': ['23-1011', 'Lawyers', 'Lawyer'],
#  '9047': ['25-1122',
#           'Communications Teachers, Postsecondary',
#           'Journalism Professor'],
#  '9049': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '9051': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '9057': ['43-4121', 'Library Assistants, Clerical', 'Library Assistant'],
#  '906': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '9062': ['11-2011',
#           'Advertising and Promotions Managers',
#           'Advertising Executive'],
#  '9064': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '907': ['23-1011', 'Lawyers', 'Attorney'],
#  '9075': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '9086': ['23-1011', 'Lawyers', 'Attorney'],
#  '9099': ['23-1011', 'Lawyers', 'Attorney'],
#  '91': ['GradStu', 'Graduate student', 'Graduate student'],
#  '9100': ['17-2011', 'Aerospace Engineers', 'Aerospace Engineer'],
#  '9104': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '9105': ['23-2011', 'Paralegals and Legal Assistants', 'Legal Assistant'],
#  '9110': ['13-1081', 'Logisticians', 'Logistics Coordinator'],
#  '9111': ['25-4021', 'Librarians', 'University Librarian'],
#  '921': ['25-3021',
#          'Self-Enrichment Education Teachers',
#          'Horseback Riding Instructor'],
#  '922': ['27-3043', 'Writers and Authors', 'Advertising Copywriter'],
#  '928': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '93': ['27-1014', 'Multimedia Artists and Animators', 'Animator'],
#  '934': ['23-1011', 'Lawyers', 'Attorney'],
#  '94': ['GradStu', 'Graduate student', 'Graduate student'],
#  '95': ['GradStu', 'Graduate student', 'Graduate student'],
#  '952': ['41-1012',
#          'First-Line Supervisors of Non-Retail Sales Workers',
#          'Telemarketing Manager'],
#  '953': ['23-1011', 'Lawyers', 'Lawyer'],
#  '954': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '955': ['23-1011', 'Lawyers', 'Lawyer'],
#  '956': ['11-2022', 'Sales Managers', 'Sales Director'],
#  '957': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '959': ['41-9012', 'Models', 'Model'],
#  '963': ['23-1011', 'Lawyers', 'Attorney'],
#  '964': ['11-2011',
#          'Advertising and Promotions Managers',
#          'Advertising Manager'],
#  '967': ['23-1011', 'Lawyers', 'Attorney'],
#  '969': ['27-3022', 'Reporters and Correspondents', 'Columnist'],
#  '970': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '972': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '976': ['43-5052', 'Postal Service Mail Carriers', 'Letter Carrier'],
#  '979': ['13-2011', 'Accountants and Auditors', 'Certified Public Accountant'],
#  '982': ['23-1011', 'Lawyers', 'Lawyer'],
#  '985': ['27-2042', 'Musicians and Singers', 'Musician'],
#  '986': ['13-2031', 'Budget Analysts', 'Budget Analyst'],
#  '988': ['25-MiscTeacher', 'Teacher', 'Teacher'],
#  '991': ['25-MiscTeacher', 'Teacher', 'Teacher']}

# %%
        
pprint(soccores)
# Out:
# {'11': 'Chief Executives',
#  '13': 'Agents and Business Managers of Artists, Performers, and Athletes',
#  '15': 'Computer and Information Research Scientists',
#  '17': 'Architects, Except Landscape and Naval',
#  '19': 'Animal Scientists',
#  '21': 'Substance Abuse and Behavioral Disorder Counselors',
#  '23': 'Lawyers',
#  '25': 'Business Teachers, Postsecondary',
#  '27': 'Art Directors',
#  '29': 'Chiropractors',
#  '31': 'Home Health Aides',
#  '33': 'First-Line Supervisors of Correctional Officers',
#  '35': 'Chefs and Head Cooks',
#  '37': 'First-Line Supervisors of Housekeeping and Janitorial Workers',
#  '39': 'Gaming Supervisors',
#  '41': 'First-Line Supervisors of Retail Sales Workers',
#  '43': 'First-Line Supervisors of Office and Administrative Support Workers',
#  '45': 'First-Line Supervisors of Farming, Fishing, and Forestry Workers',
#  '47': 'First-Line Supervisors of Construction Trades and Extraction Workers',
#  '49': 'First-Line Supervisors of Mechanics, Installers, and Repairers',
#  '51': 'First-Line Supervisors of Production and Operating Workers',
#  '53': 'Aircraft Cargo Handling Supervisors',
#  '55': 'Air Crew Officers',
#  'GradStu': 'Graduate student',
#  'Undergrad': 'Undergraduate',
#  'Unemployed': 'Unemployed'}

# %%
corecounts = {}

for key, value in onlyhits.iteritems():
    core = value[0].split("-")[0]
    if core not in corecounts:
        corecounts[core] = 1
    else:
        corecounts[core] += 1
    
for key, value in corecounts.iteritems():
    print key,":",soccores[key], "seen", value, "times"
# Out:
# 51 : First-Line Supervisors of Production and Operating Workers seen 2 times
# 29 : Chiropractors seen 96 times
# 53 : Aircraft Cargo Handling Supervisors seen 10 times
# 25 : Business Teachers, Postsecondary seen 786 times
# 27 : Art Directors seen 250 times
# 21 : Substance Abuse and Behavioral Disorder Counselors seen 31 times
# 23 : Lawyers seen 477 times
# 47 : First-Line Supervisors of Construction Trades and Extraction Workers seen 6 times
# 43 : First-Line Supervisors of Office and Administrative Support Workers seen 85 times
# 41 : First-Line Supervisors of Retail Sales Workers seen 26 times
# 39 : Gaming Supervisors seen 18 times
# GradStu : Graduate student seen 307 times
# 11 : Chief Executives seen 88 times
# 13 : Agents and Business Managers of Artists, Performers, and Athletes seen 125 times
# 15 : Computer and Information Research Scientists seen 61 times
# 17 : Architects, Except Landscape and Naval seen 61 times
# 19 : Animal Scientists seen 77 times
# 55 : Air Crew Officers seen 2 times
# 31 : Home Health Aides seen 5 times
# 49 : First-Line Supervisors of Mechanics, Installers, and Repairers seen 1 times
# 37 : First-Line Supervisors of Housekeeping and Janitorial Workers seen 2 times
# 35 : Chefs and Head Cooks seen 30 times
# 33 : First-Line Supervisors of Correctional Officers seen 13 times
